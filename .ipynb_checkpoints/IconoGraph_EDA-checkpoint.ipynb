# %% [markdown]
# **RESEARCH QUESTION**
#
# ## What role does detailed artwork description play in enriching our understanding of art history and its various contexts?
#
# ---
#
# ### This notebook goes through a basic exploratory data analysis of the **Iconology Dataset** and **Zeri Photo Archive RDF Dataset** using Python.
#
# I will perform different kinds of exploratory data analysis to gain an exhaustive understanding of the data represented in the two original datasets.
#
# The various phases of the EDA will be:
# 1. Acquire and parse
# 2. Filter and mine
# 3. Represent
# 4. Refine
# 5. Interact

# %% [markdown]
# # 0. Why EDA?
#
# **Data**, in their raw form, gain meaning through relational connections, transforming into **information**. Information answers questions starting with interrogative words like *who, what, when, where,* and *how many*. However, information truly becomes valuable when it evolves into **knowledge**. Knowledge represents a purposeful collection of information, intended for utility. As knowledge accumulates, it enables reflection, potentially leading to **wisdom**.
#
# To achieve this progression, understanding serves as a continuum that begins with data, transitions through information and knowledge, and culminates in wisdom. This concept is encapsulated in the ***"DIKW Pyramid"*** (Ackoff, 1989), where data forms the foundational layer, leading to wisdom, the ultimate tier.
#
# Data represent abstractions of concepts and real-world entities (such as people, paintings, or places) with their associated attributes or features, forming classes of objects. These data are then collated and stored in datasets, often represented in tabular format, where rows denote entities and columns represent their attributes.
#
# Given the variability in such abstractions, **Exploratory Data Analysis (EDA)** becomes crucial in unraveling these structures. EDA aids in uncovering insights about the data, deciphering their representations and implications.
#
# This is an iterative process since datasets consistently unveil features that might have been initially overlooked.
#
# Let's embark on this journey!

# %% [markdown]
# # 1. Acquire and Parse
#
# For this project, two primary sources of data will be utilized: the ***[Iconology Dataset](https://iconology-dataset.streamlit.app/)*** and the ***[Zeri Photo Archive RDF dataset](https://data.fondazionezeri.unibo.it/)***.
#
# ## Iconology Dataset
# The first RDF dataset originated as part of a PhD project in Digital Humanities at the University of Bologna, led by *Sofia Baroncini*. It presents structured content comprising interpretations by art historian Erwin Panofsky and other esteemed art historians. The dataset is currently published under the CC-BY-SA 4.0 license and is accessible at ***[https://w3id.org/icon/data/](https://w3id.org/icon/data/)***.
#
# ## Zeri Photo Archive Collection
# The second dataset, the Zeri Photo Archive RDF, is a substantial subset of the data available at the Zeri Catalog website and discoverable through the Europeana Portal. The Federico Zeri Foundation was established in 1999 by the University of Bologna with the intention of honoring Federico Zeri's life, preserving his legacy, and maximizing its potential. It encompasses an Art Library consisting of 46,000 volumes, 37,000 auction catalogs, and 60 periodicals, alongside a Photo Archive containing 290,000 photographs of monuments and artworks. The SPARQL endpoint is currently under maintenance ([http://data.fondazionezeri.unibo.it/sparql](http://data.fondazionezeri.unibo.it/sparql)), thus the data utilized will be sourced from ***[https://amsacta.unibo.it/id/eprint/5497/](https://amsacta.unibo.it/id/eprint/5497/)***.

# %% [markdown]
# ### Installations and Imports
#
# The following script installs and imports the necessary libraries utilized in this documentation. Uncomment the packages that you require for the imports.

# %%
# Install the packages needed in the Notebook

#!pip install rdflib
#!pip install SPARQLWrapper
#!pip install pandas
#!pip install sparql-dataframe
#!pip install prettyprinter
#!pip install matplotlib
#!pip install seaborn
#!pip install ipyleaflet #this package nee also to be registered with: jupyter nbextension enable --py --sys-prefix ipyleaflet
#!pip install folium
#!pip install nltk
#!pip install mlxtend

# %%
# Import necessary libraries

# RDFlib
from rdflib import Graph, URIRef, Namespace
from rdflib.plugins.sparql import prepareQuery
from rdflib.namespace import CSVW, DC, DCAT, DCTERMS, DOAP, FOAF, ODRL2, ORG, OWL, \
                           PROF, PROV, RDF, RDFS, SDO, SH, SKOS, SOSA, SSN, TIME, \
                           VOID, XMLNS, XSD, NamespaceManager

# SPARQLWrapper
from SPARQLWrapper import SPARQLWrapper, JSON

# pandas
import pandas as pd

# sparql_dataframe
import sparql_dataframe

# prettyprinter
from prettyprinter import pprint

# matplotlib
import matplotlib.pyplot as plt

# seaborn
import seaborn as sns

# datatime
from datetime import datetime

# json
import json

# datatime
from datetime import datetime

# os
import os

# regular expressions
import re

# ipyleaflet
from ipyleaflet import Map, basemaps, Marker, MarkerCluster

# folium
import folium
from folium.plugins import MarkerCluster

# nltk
import nltk
from nltk.corpus import stopwords
# Download NLTK stopwords (run this line the first time)
#nltk.download('stopwords')

# mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %% [markdown]
# ## 1.1. Parse Iconology Dataset
# Firstly, we parsed the Iconology RDF data into a graph to enable SPARQL queries for exploring the content.

# %%
# Initialize an RDF graph
iconology_graph = Graph()

# Define the endpoint URL
endpoint_url = 'https://w3id.org/icon/data/'

# Load the RDF data from the endpoint into the graph, specifying the format
try:
    iconology_graph.parse(endpoint_url, format='turtle')
    print("RDF data successfully loaded from the endpoint.")
except Exception as e:
    print("Failed to load RDF data from the endpoint:", e)
# Out:
# RDF data successfully loaded from the endpoint.

# %% [markdown]
# ## 1.2. Parse Zeri Photo Archive Collection
#
# Next, we proceed to parse the Zeri Photo Archive RDF downloaded from the provided link.
# Ensure that you replace `directory` in the script with the actual directory path where the folder containing the downloaded data is located.

# %%
# Dataset local path
directory = '/Users/stefano_renzetti/Library/CloudStorage/Dropbox/DHDK/INFORMATION VISUALIZATION/_sources/FONDAZIONE-ZERI-RDF/dump-complete'

# Initialize an RDF graph
zeri_graph = Graph()

try:
    # Iterate through files in the directory, parse each file into a separate graph
    for filename in os.listdir(directory):
        if filename.endswith('.rdf'):  # Adjust the file extension if needed
            file_path = os.path.join(directory, filename)
            zeri_graph.parse(file_path, format='xml', strict=False)  # Allow parsing with invalid URIs

    print("RDF data successfully loaded from the directory.")

    # Determine the number of triples in the graph
    number_of_triples = len(zeri_graph)
    
    print(f"The graph contains {number_of_triples} triples.")

except Exception as e:
    print("Failed to load RDF data from the directory:", e)
# Out:
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Cataloguer's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title typescript on verso of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title typescript on verso of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Cataloguer's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Author's choice does not look like a valid URI, trying to serialize this will break.
# https://w3id.org/zericatalog/criterion/Title printed on recto of photograph does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Washington does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Washington does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Normandie does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Normandie does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Virginia does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Virginia does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Mells does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Mells does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"College_Green does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"College_Green does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Urbania does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Urbania does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Force does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Force does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Helena does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Helena does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Correggio does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Correggio does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Cori does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Cori does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Thornhill does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Thornhill does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Chatsworth does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Chatsworth does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Argenta does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Argenta does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Vinci does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Vinci does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Serina does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Serina does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Henbury does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Henbury does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Cesi does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Cesi does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Essex does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Essex does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Eaton_Hall does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Eaton_Hall does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Scorton does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Scorton does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Quarto does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Quarto does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Carona does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Carona does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Marino does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Marino does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Auteuil does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Auteuil does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Bure_(Gojjam) does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Bure_(Gojjam) does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"Castile does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"Castile does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"New_Britain does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"New_Britain does not look like a valid URI, trying to serialize this will break.
# http://it.wikipedia.org/wiki/"New_Britain does not look like a valid URI, trying to serialize this will break.
# http://dbpedia.org/resource/"New_Britain does not look like a valid URI, trying to serialize this will break.
# RDF data successfully loaded from the directory.
# The graph contains 11992953 triples.

# %% [markdown]
# The RDF file is substantial in size, and its parsing might take a considerable amount of time. It should be noted that some URIs might result in errors due to incorrect formatting, leading to issues during RDF parsing.
# It's important to note that we initially attempted to upload the graph into Blazegraph considering the file extension. However, during testing, the upload process was slow and encountered various issues, leading to performance and usability concerns. Consequently, we found RDFlib parsing to be more suitable for handling the data within the Jupyter environment.

# %% [markdown]
# # 2. Filter and mine

# %% [markdown]
# ## 2.1. - Filter Iconology Dataset
# Understanding how data are structured in the datasets involves studying the ontology attached to them. The ***ICON ontology***, developed by *Bruno Sartini* and *Sofia Baroncini*, was created to formally represent interpretations about the content and meaning of artworks. It is based on Erwin Panofsky's theoretical approach, which subdivides each act of interpretation into three levels of understanding.
#
# The ontology plays a crucial role in defining the structure, relationships, and entities within the dataset. In RDF datasets, ontologies establish the vocabulary and relationships used to describe the data. They provide the meaning of terms, properties, and classes, essential for correctly interpreting and querying the data.
#
# To grasp the structure of the RDF, it's vital to consult the dataset documentation available [here](https://br0ast.github.io/ICON/ICONOntologyDocumentation/index-en.html). This step helps us identify the necessary prefixes for each query.
#
# For a deeper exploration, we can inspect the list of classes available within our RDF dataset. The following code snippet demonstrates how we can retrieve this information using a SPARQL query.

# %%
# Define the SPARQL query
query = """
SELECT DISTINCT ?class_uri
WHERE {
    # ?anything a ?class_uri .
}
"""

# Prepare the SPARQL query
query_obj = prepareQuery(query)

# Execute the query and retrieve the results
lists_classes = iconology_graph.query(query_obj)

# Uncomment the two following lines to see the list of classes
for row in lists_classes:
    print(row['class_uri'])
# Out:
# http://www.cidoc-crm.org/cidoc-crm/E74_Group
# http://www.cidoc-crm.org/cidoc-crm/E35_Title
# http://www.cidoc-crm.org/cidoc-crm/E22_Human_Made_Object
# http://www.cidoc-crm.org/cidoc-crm/E65_Creation
# http://www.cidoc-crm.org/cidoc-crm/E12_Production
# http://www.cidoc-crm.org/cidoc-crm/E13_Attribute_Assignment
# http://www.cidoc-crm.org/cidoc-crm/E78_Curated_Holding
# https://w3id.org/icon/ontology/Character
# https://w3id.org/icon/ontology/Story
# http://www.cidoc-crm.org/cidoc-crm/E57_Material
# http://www.cidoc-crm.org/cidoc-crm/E4_Period
# http://www.cidoc-crm.org/cidoc-crm/E53_Place
# http://www.cidoc-crm.org/cidoc-crm/E73_Information_Object
# http://www.cidoc-crm.org/cidoc-crm/E55_Type
# http://dati.gov.it/onto/dcatapitAgent
# http://www.cidoc-crm.org/cidoc-crm/E52_Time_Span
# https://w3id.org/icon/ontology/Image
# https://w3id.org/icon/ontology/IntrinsicMeaning
# https://w3id.org/icon/ontology/InterpretationDescription
# https://w3id.org/icon/ontology/Artwork
# https://w3id.org/icon/ontology/ArtisticMotif
# https://w3id.org/icon/ontology/IconographicalRecognition
# http://www.cidoc-crm.org/cidoc-crm/E25_Human_Made_Feature
# http://dati.gov.it/onto/dcatapitDistribution
# https://w3id.org/simulation/ontology/Simulacrum
# https://w3id.org/simulation/ontology/RealityCounterpart
# http://www.cidoc-crm.org/cidoc-crm/E42_Identifier
# https://w3id.org/icon/ontology/CompositionalStructure
# http://purl.org/spar/pro/Role
# http://purl.org/spar/pro/RoleInTime
# http://www.cidoc-crm.org/cidoc-crm/E21_Person
# http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Quality
# http://www.w3.org/ns/dcat#Role
# https://w3id.org/icon/ontology/IconologicalRecognition
# https://w3id.org/icon/ontology/PreiconographicalRecognition
# https://w3id.org/icon/ontology/FormalMotifRecognition
# https://w3id.org/icon/ontology/Composition
# https://w3id.org/icon/ontology/CulturalPhenomenon
# http://www.cidoc-crm.org/cidoc-crm/E28_Conceptual_Object
# https://w3id.org/icon/ontology/NaturalElement
# https://w3id.org/icon/ontology/Action
# https://w3id.org/icon/ontology/Event
# https://w3id.org/icon/ontology/ExpressionalQuality
# https://w3id.org/icon/ontology/Allegory
# https://w3id.org/icon/ontology/Symbol
# https://w3id.org/simulation/ontology/Simulation
# https://w3id.org/icon/ontology/NamedObject
# http://www.cidoc-crm.org/cidoc-crm/E33_Linguistic_Object
# https://w3id.org/icon/ontology/Personification
# http://www.cidoc-crm.org/cidoc-crm/E39_Group
# https://w3id.org/icon/ontology/Place
# https://w3id.org/icon/ontology/Invenzione
# http://www.cidoc-crm.org/cidoc-crm/E62_String
# http://dati.gov.it/onto/dcatapitDataset
# http://www.w3.org/ns/dcat#Dataset

# %% [markdown]
# We embark on our data exploration by seeking quantitative measures related to the dataset. Our initial step involves determining **the total number of artworks represented within the dataset.**
# We've commenced our first query to collect essential statistics.

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/>
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?object
WHERE {
    # ?object crm:P65_shows_visual_item ?artwork.
}
"""

# Prepare the SPARQL query
query_obj = prepareQuery(query)

# Execute the query and retrieve the results
results = iconology_graph.query(query_obj)

# Calculate the number of distinct artworks
artworks = len(set(results))

print(f"Number of distinct artworks: {artworks}")
# Out:
# Number of distinct artworks: 642

# %% [markdown]
# Let's count **how many, of the 642 artworks described, do have an artist specified.**

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?object ?artistLabel
WHERE {
    # ?object crm:P65_shows_visual_item ?artwork ;
         ^crm:P108_has_produced / crm:P14_carried_out_by ?artist .
    # ?artist rdfs:label ?artistLabel .
}
"""

# Prepare the SPARQL query
query_obj = prepareQuery(query)

# Execute the query and retrieve the results
results = iconology_graph.query(query_obj)

# Calculate the number of distinct artworks
artists_artworks = len(set(results))

print(f"Number of artworks with artist specified: {artists_artworks}")
# Out:
# Number of artworks with artist specified: 267

# %% [markdown]
# As our focus lies on the iconography depicted in the artworks, it's essential that these artworks have descriptions. Therefore, let's determine **the total count of artworks that have been described within the dataset.**

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?object
WHERE {
    # ?object crm:P65_shows_visual_item ?artwork . 
    # ?recognition icon:aboutWorkOfArt ?artwork . 
}
"""

# Prepare the SPARQL query
query_obj = prepareQuery(query)

# Execute the query and retrieve the results
results = iconology_graph.query(query_obj)

# Calculate the number of distinct artworks
descripted_artworks = len(set(results))

print(f"Number of distinct described artworks: {descripted_artworks}")
# Out:
# Number of distinct described artworks: 428

# %% [markdown]
# As we can read in the Iconology documentation:
# > Not all the artworks have a description. This is because the described artwork can have a relationship with a cultural object not described. In come cases, only a specific part of the artwork (e.g. a scene of a fresco, a relief on a church wall) is described. In other cases, there are other types of relations between the described artwork and another one (e.g. is companion piece of, is a copy of).

# %% [markdown]
# We are now interest into the different kind of artworks that are represented. So let's explore **how many artworks out of the described ones do have a type specified.**

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?object ?typeLabel
WHERE {
    # ?object crm:P65_shows_visual_item ?artwork ;
            crm:P2_has_type ?type .
    # ?type rdfs:label ?typeLabel .
    # ?recognition icon:aboutWorkOfArt ?artwork. 
} 
"""

# Prepare the SPARQL query
query_obj = prepareQuery(query)

# Execute the query and retrieve the results
results = iconology_graph.query(query_obj)

# Calculate the number of distinct artworks
typed_artworks = len(set(results))

# Display the number of artworks with specified types
print(f"Number of artworks with type specified: {typed_artworks}")
# Out:
# Number of artworks with type specified: 342

# %% [markdown]
# The dataset comprises recognitions made by various art historians.
# **Let's explore the number of art historians included in the dataset.**

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX cito: <http://purl.org/spar/cito/>

SELECT DISTINCT ?personLabel
WHERE {

    # ?person a crm:E21_Person ;
            rdfs:label ?personLabel .
    # ?recognition a icon:IconologicalRecognition ;
                 icon:aboutWorkOfArt ?artwork ;
                 crm:P14_carried_out_by ?person . 
}
"""

# Prepare the SPARQL query
query_obj = prepareQuery(query)

# Execute the query and retrieve the results
results = iconology_graph.query(query_obj)

df = pd.DataFrame(results, columns=results.vars)

df
# Out:
#           personLabel
# 0  Roelof van Straten
# 1        Irving Lavin
# 2      Walter Liedtke
# 3      Franco Cardini
# 4  Keith Christiansen
# 5    Rudolf Wittkower
# 6     Sofia Baroncini
# 7          Fritz Saxl
# 8      Erwin Panofsky

# %% [markdown]
# Exploring the various levels of interpretation conducted by art historians for an artwork is worthwhile. For instance, conducting a query on a specific artwork—let's consider examining the different levels of interpretation for ***"La Primavera"*** by ***Sandro Botticelli (d:ART1203)***.
#
# Our aim is to retrieve information about **how many distinct levels of interpretation exist for this artwork.** Additionally, for each level of interpretation, we intend to print or display the subjects recognized at that particular level.

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/>

SELECT DISTINCT ?artwork ?subj1 ?subj2 ?subj3
WHERE {
    VALUES ?artwork {d:ART1203}
    
    { ?artwork icon:preiconographicallyDepicts ?subj1 }
    UNION
    { ?artwork icon:iconographicallyDepicts ?subj2 }
    UNION
    { ?artwork icon:iconologicallyRepresents ?subj3 }
} 
"""

# Prepare the SPARQL query
query_obj = prepareQuery(query)

# Execute the query and retrieve the results
results = iconology_graph.query(query_obj)

df = pd.DataFrame(results, columns=results.vars)

print(f"Number of descriptions: {len(df)}")
df
# Out:
# Number of descriptions: 31
#                                artwork  \
# 0   https://w3id.org/icon/data/ART1203
# 1   https://w3id.org/icon/data/ART1203
# 2   https://w3id.org/icon/data/ART1203
# 3   https://w3id.org/icon/data/ART1203
# 4   https://w3id.org/icon/data/ART1203
# 5   https://w3id.org/icon/data/ART1203
# 6   https://w3id.org/icon/data/ART1203
# 7   https://w3id.org/icon/data/ART1203
# 8   https://w3id.org/icon/data/ART1203
# 9   https://w3id.org/icon/data/ART1203
# 10  https://w3id.org/icon/data/ART1203
# 11  https://w3id.org/icon/data/ART1203
# 12  https://w3id.org/icon/data/ART1203
# 13  https://w3id.org/icon/data/ART1203
# 14  https://w3id.org/icon/data/ART1203
# 15  https://w3id.org/icon/data/ART1203
# 16  https://w3id.org/icon/data/ART1203
# 17  https://w3id.org/icon/data/ART1203
# 18  https://w3id.org/icon/data/ART1203
# 19  https://w3id.org/icon/data/ART1203
# 20  https://w3id.org/icon/data/ART1203
# 21  https://w3id.org/icon/data/ART1203
# 22  https://w3id.org/icon/data/ART1203
# 23  https://w3id.org/icon/data/ART1203
# 24  https://w3id.org/icon/data/ART1203
# 25  https://w3id.org/icon/data/ART1203
# 26  https://w3id.org/icon/data/ART1203
# 27  https://w3id.org/icon/data/ART1203
# 28  https://w3id.org/icon/data/ART1203
# 29  https://w3id.org/icon/data/ART1203
# 30  https://w3id.org/icon/data/ART1203
#
#                                                 subj1  \
# 0                    https://w3id.org/icon/data/arrow
# 1                      https://w3id.org/icon/data/bow
# 2                  https://w3id.org/icon/data/clothes
# 3                  https://w3id.org/icon/data/dancing
# 4   https://w3id.org/icon/data/endeavoring-to-disp...
# 5                     https://w3id.org/icon/data/fire
# 6             https://w3id.org/icon/data/indifference
# 7                      https://w3id.org/icon/data/man
# 8                     https://w3id.org/icon/data/mist
# 9              https://w3id.org/icon/data/orange-tree
# 10                   https://w3id.org/icon/data/putto
# 11  https://w3id.org/icon/data/raising-the-right-hand
# 12  https://w3id.org/icon/data/stick-with-two-coil...
# 13              https://w3id.org/icon/data/taking-aim
# 14                   https://w3id.org/icon/data/wings
# 15                   https://w3id.org/icon/data/woman
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
#
#                                                 subj2  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                https://w3id.org/icon/data/caduceus
# 17                   https://w3id.org/icon/data/cupid
# 18  https://w3id.org/icon/data/inv/the-realm-of-th...
# 19                 https://w3id.org/icon/data/mercury
# 20  https://w3id.org/icon/data/mercury-discursive-...
# 21  https://w3id.org/icon/data/mercury-discursive-...
# 22  https://w3id.org/icon/data/mercury-turning-his...
# 23           https://w3id.org/icon/data/natural-venus
# 24  https://w3id.org/icon/data/natural-venus-amor-...
# 25              https://w3id.org/icon/data/pers/flora
# 26             https://w3id.org/icon/data/pers/spring
# 27             https://w3id.org/icon/data/pers/zephir
# 28        https://w3id.org/icon/data/the-three-graces
# 29                                               None
# 30                                               None
#
#                                 subj3
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                None
# 5                                None
# 6                                None
# 7                                None
# 8                                None
# 9                                None
# 10                               None
# 11                               None
# 12                               None
# 13                               None
# 14                               None
# 15                               None
# 16                               None
# 17                               None
# 18                               None
# 19                               None
# 20                               None
# 21                               None
# 22                               None
# 23                               None
# 24                               None
# 25                               None
# 26                               None
# 27                               None
# 28                               None
# 29  https://w3id.org/icon/data/CF1009
# 30  https://w3id.org/icon/data/CF1287

# %% [markdown]
# The recognition of an artwork is a fundamental aspect in our study. The ontology associated with the dataset categorizes various recognitions made by art historians into three distinct levels.
#
# As detailed in the [documentation](https://br0ast.github.io/ICON/ICONOntologyDocumentation/index-en.html#Recognition), there are four subclasses within the "Recognition" class:
#
# 1. **Preiconographical Recognition (Level 1)**
# 2. **Iconographical Recognition (Level 2)**
# 3. **Iconological Recognition (Level 3)**
# 4. **Formal Motif Recognition**: This subclass was introduced to describe instances where certain subjects serve as prototypes for others. This includes preliminary drawings and cases in which an artist reproduces only the composition or gestures from another artwork. This recognition can establish links between specific elements of a representation and their prototypes. The relationship exists between Level 1 objects, namely Artistic Motifs and Composition, as it pertains to formal aspects.
#
# For example, if "Hercules carrying the Boar" is the prototype for a "Christ carrying a deer," symbolizing human souls, it becomes possible to directly relate the boar represented in the former artwork to the deer represented in the latter.
#
# In the following code snippet, we can determine the total number of recognitions present within the dataset.

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/>

SELECT DISTINCT ?artwork ?subj1 ?subj2 ?subj3
WHERE {
    # ?artwork icon:preiconographicallyDepicts ?subj1 .
    OPTIONAL { ?artwork icon:iconographicallyDepicts ?subj2 . }
    OPTIONAL { ?artwork icon:iconologicallyRepresents ?subj3 . }
}
"""

# Prepare the SPARQL query
query_obj = prepareQuery(query)

# Execute the query and retrieve the results
results = iconology_graph.query(query_obj)

df = pd.DataFrame(results, columns=results.vars)

print(f"Number of descriptions: {len(df)}")
df.info()
df.head()
# Out:
# Number of descriptions: 35333
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35333 entries, 0 to 35332
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   artwork  35333 non-null  object
#  1   subj1    35333 non-null  object
#  2   subj2    34929 non-null  object
#  3   subj3    34313 non-null  object
# dtypes: object(4)
# memory usage: 1.1+ MB
#                                   artwork                              subj1  \
# 0  https://w3id.org/icon/data/ART1001type  https://w3id.org/icon/data/figure
# 1      https://w3id.org/icon/data/ART1172  https://w3id.org/icon/data/figure
# 2      https://w3id.org/icon/data/ART1368  https://w3id.org/icon/data/figure
# 3      https://w3id.org/icon/data/ART1080  https://w3id.org/icon/data/figure
# 4      https://w3id.org/icon/data/ART1080  https://w3id.org/icon/data/figure
#
#                                           subj2  \
# 0                                          None
# 1                                          None
# 2  https://w3id.org/icon/data/pers/four-seasons
# 3                                          None
# 4                                          None
#
#                                subj3
# 0                               None
# 1                               None
# 2                               None
# 3  https://w3id.org/icon/data/CF1240
# 4  https://w3id.org/icon/data/CF1275

# %% [markdown]
# We can further delve into our exploration by examining the date feature associated with the artworks, whenever available. In our research, we are specifically interested in the time span of the Italian Renaissance, which spans the 15th and 16th centuries. Let's query the dataset to determine **the count of artworks, and their type, that fall within the specified time span: 1400-1600.**

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?artwork ?title ?typeLabel ?startDate ?endDate
WHERE {
    # ?object crm:P65_shows_visual_item ?artwork ; 
            crm:P102_has_title ?title ; 
            ^crm:P108_has_produced / crm:P4_has_time_span ?time . 

    # ?time crm:P82a_begin_of_the_begin ?startDate ; 
          crm:P82b_end_of_the_end ?endDate .

    OPTIONAL {
            # ?object crm:P2_has_type ?type .
            # ?type rdfs:label ?typeLabel .
    }

    FILTER (xsd:dateTime(?startDate) >= "1400-01-01T00:00:00"^^xsd:dateTime &&
                xsd:dateTime(?startDate) <= "1600-12-31T23:59:59"^^xsd:dateTime)
}
ORDER BY ?startDate
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)
    
    if results:
        # Retrieve the count of distinct artworks within the specified time span
        count_artworks = sum(1 for _ in results)
        
        if count_artworks > 0:
            print(f"Number of artworks within the Italian Renaissance period: {count_artworks}")
        else:
            print("No artworks found within the Italian Renaissance period")

        # Convert SPARQL results to a pandas DataFrame
        icon_artwork_renaissance_df = pd.DataFrame(results, columns=results.vars)

except Exception as e:
    print("An error occurred:", e)

icon_artwork_renaissance_df.info()
icon_artwork_renaissance_df
# Out:
# Number of artworks within the Italian Renaissance period: 167
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   artwork    167 non-null    object
#  1   title      167 non-null    object
#  2   typeLabel  139 non-null    object
#  3   startDate  167 non-null    object
#  4   endDate    167 non-null    object
# dtypes: object(5)
# memory usage: 6.7+ KB
#                                    artwork  \
# 0       https://w3id.org/icon/data/ART1117
# 1       https://w3id.org/icon/data/ART1118
# 2       https://w3id.org/icon/data/ART1173
# 3    https://w3id.org/icon/data/ART1191ext
# 4    https://w3id.org/icon/data/ART1202ext
# ..                                     ...
# 162     https://w3id.org/icon/data/ART1258
# 163     https://w3id.org/icon/data/ART1426
# 164     https://w3id.org/icon/data/ART1322
# 165     https://w3id.org/icon/data/ART1389
# 166     https://w3id.org/icon/data/ART1308
#
#                                                  title     typeLabel  \
# 0    https://w3id.org/icon/data/title/apollo-minerv...  illumination
# 1    https://w3id.org/icon/data/title/orpheus-charm...  illumination
# 2    https://w3id.org/icon/data/title/siege-of-a-ci...  illumination
# 3    https://w3id.org/icon/data/title/french-miniature          None
# 4    https://w3id.org/icon/data/title/the-medal-of-...         medal
# ..                                                 ...           ...
# 162  https://w3id.org/icon/data/title/allegory-of-a...     engraving
# 163  https://w3id.org/icon/data/title/mater-miseric...      painting
# 164  https://w3id.org/icon/data/title/platonic-love...     engraving
# 165          https://w3id.org/icon/data/title/ganymede     engraving
# 166  https://w3id.org/icon/data/title/eros-and-anteros       woodcut
#
#                startDate              endDate
# 0    1400-01-01T00:00:00  1400-12-31T23:59:59
# 1    1400-01-01T00:00:00  1400-12-31T23:59:59
# 2    1400-01-01T00:00:00  1400-12-31T23:59:59
# 3    1400-01-01T00:00:00  1400-12-31T23:59:59
# 4    1400-01-01T00:00:00  1400-12-31T23:59:59
# ..                   ...                  ...
# 162  1569-01-01T00:00:00  1569-12-31T23:59:59
# 163  1573-01-01T00:00:00  1573-12-31T23:59:59
# 164  1574-01-01T00:00:00  1574-12-31T23:59:59
# 165  1574-01-01T00:00:00  1574-12-31T23:59:59
# 166  1584-01-01T00:00:00  1584-12-31T23:59:59
#
# [167 rows x 5 columns]

# %% [markdown]
# It's worth noting that executing the same query on the [SPARQL online interface](https://projects.dharc.unibo.it/icondataset/sparql) of the ***Iconology Dataset*** isn't yielding any results. This issue seems to arise from the filtering mechanism. To perform a similar query on the online endpoint, we may need to filter the data using strings instead of the datetime type.
#
# ```SPARQL
#     PREFIX d: <https://w3id.org/icon/data/>
#     PREFIX icon: <https://w3id.org/icon/ontology/>
#     PREFIX sim: <https://w3id.org/simulation/ontology/>
#     PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
#     PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
#
#     SELECT DISTINCT ?artwork ?title ?typeLabel ?startDate ?endDate
#     WHERE {
#         ?object crm:P65_shows_visual_item ?artwork ;
#                 crm:P102_has_title ?title ;
#                 ^crm:P108_has_produced / crm:P4_has_time_span ?time .
#
#         ?time crm:P82a_begin_of_the_begin ?startDate ;
#               crm:P82b_end_of_the_end ?endDate .
#
#     OPTIONAL {
#             ?object crm:P2_has_type ?type .
#             ?type rdfs:label ?typeLabel .
#     }
#
#     BIND(REPLACE(STR(?startDateTime), "T.*", "") AS ?startDate)
#     # we convert also "endDate" but we will use only "startDate" as filter.
#     BIND(REPLACE(STR(?endDateTime), "T.*", "") AS ?endDate)
#
#     FILTER (?startDate >= "1400-01-01" && ?startDate <= "1600-12-31")
#     }
#     ORDER BY ?startDate
# ```

# %% [markdown]
# To gain a clearer insight into **the distribution of each artwork type within the selected timeframe,** we can create visual representations using Matplotlib.

# %%
# Check if results exist
if results:
    # Create a dictionary to store the counts of each type
    type_counts = {}
    none_count = 0  # Counter for instances where typeLabel is None
    for row in results:
        type_label = row['typeLabel']
        if type_label is None:
            none_count += 1
        elif type_label not in type_counts:
            type_counts[type_label] = 1
        else:
            type_counts[type_label] += 1

    # Include the count of instances where typeLabel is None
    if none_count > 0:
        type_counts['not specified'] = none_count

    # Sort the type counts from the highest to the lowest
    sorted_type_counts = sorted(type_counts.items(), key=lambda x: x[1], reverse=True)

    # Extract the labels and counts for plotting
    type_labels, type_values = zip(*sorted_type_counts)

    # Plotting
    plt.figure(figsize=(10, 8))
    sns.barplot(x=list(type_values), y=list(type_labels), hue=list(type_labels), palette='viridis', order=list(type_labels), dodge=False, legend=False)

    # Customize the plot
    plt.xlabel('Count')
    plt.ylabel('Type Label')
    plt.title('Number of Artworks with Specified Types')
    plt.show()
else:
    print("No results returned from the SPARQL query")

# %% [markdown]
# Let's examine **which artists are most represented within the time span from 1400 to 1600.**

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/>
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT ?artistLabel (COUNT(DISTINCT ?object) AS ?count)
WHERE {
    # ?production crm:P108_has_produced ?object ;
                crm:P14_carried_out_by ?artist .

    # ?object crm:P65_shows_visual_item ?artwork ; 
            crm:P102_has_title ?title ; 
            ^crm:P108_has_produced / crm:P4_has_time_span ?time . 

    # ?time crm:P82a_begin_of_the_begin ?startDate .

    FILTER (xsd:dateTime(?startDate) >= "1400-01-01T00:00:00"^^xsd:dateTime &&
            xsd:dateTime(?startDate) <= "1600-12-31T23:59:59"^^xsd:dateTime)

    # ?artist a crm:E21_Person ;
            rdfs:label ?artistLabel .
}
GROUP BY ?artist ?artistLabel
ORDER BY DESC(?count)
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)
    
    if results:
        # Retrieve the count of distinct artworks within the specified time span
        count_artworks = sum(1 for _ in results)
        
        if count_artworks > 0:
            print(f"The count of artists during the Renaissance period: {count_artworks}")
        else:
            print("There are no artists found within the Renaissance period.")

        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results, columns=results.vars)

except Exception as e:
    print("An error occurred:", e)

df.info()
df
# Out:
# The count of artists during the Renaissance period: 43
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artistLabel  43 non-null     object
#  1   count        43 non-null     object
# dtypes: object(2)
# memory usage: 820.0+ bytes
#                                           artistLabel count
# 0                                        Michelangelo    16
# 1                                      Albrecht Dürer    14
# 2                                             Raphael     6
# 3                                     Piero di Cosimo     4
# 4                                     Andrea Mantegna     3
# 5                                   Sandro Botticelli     3
# 6                                     Agnolo Bronzino     3
# 7                                    Tiziano Vecellio     3
# 8                                           Donatello     2
# 9                                   Florentine Master     2
# 10         Maitre des Heures du Maréchal de Boucicaut     2
# 11                                           Masaccio     2
# 12                                       Jan van Eyck     2
# 13                          Albrecht Dürer (workshop)     1
# 14                                Andrea del Castagno     1
# 15                              Apollonio di Giovanni     1
# 16                                 Cyriacus of Ancona     1
# 17                                    Filippino Lippi     1
# 18                                    Francesco Cossa     1
# 19                                        Giambologna     1
# 20                                    Giovanni Zacchi     1
# 21                                   Girolamo Olgiati     1
# 22                                      Giulio Romano     1
# 23                                Giuseppe Arcimboldo     1
# 24                                    Jacopo Caraglio     1
# 25                                    Jan Collaert II     1
# 26                                  Limbourg brothers     1
# 27                                      Lorenzo Lotto     1
# 28                            Lucas Cranach the Elder     1
# 29                             Maerten van Heemskerck     1
# 30  Maitre des Heures du Maréchal de Boucicaut (wo...     1
# 31                                  Nicolas Béatrizet     1
# 32                               North Italian Master     1
# 33                          Pieter Brueghel the Elder     1
# 34                              Rogier van der Weyden     1
# 35                     Tiziano Vecellio (and helpers)     1
# 36                                    Tommaso Laureti     1
# 37                                 Antonio Pollaiuolo     1
# 38                               Filippo Brunelleschi     1
# 39                               Marcantonio Raimondi     1
# 40                              Leon Battista Alberti     1
# 41                                    Benozzo Gozzoli     1
# 42                                          Correggio     1

# %% [markdown]
# Since the dataset also accompanies artworks with evaluations of cultural phenomena by art historians, we thought it would be interesting to **search within those labels to identify instances where the term 'Renaissance' is mentioned and ascertain the artworks to which it refers.**

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX icon: <https://w3id.org/icon/ontology/>

SELECT ?artwork ?culturalPhenomenon ?label ?intrinsicMeaning
WHERE {
    # ?artwork a icon:Artwork ;
            icon:iconologicallyRepresents ?culturalPhenomenon .
            
    # ?culturalPhenomenon a icon:CulturalPhenomenon ;
                        rdfs:label ?label ;
                        icon:isCulturalPhenomenonOf ?intrinsicMeaning .
                          
    FILTER (REGEX(?label, "Renaissance", "i")) # "i" is case insensitive regex
}
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)
    
    if results:
        # Retrieve the count of distinct artworks within the specified time span
        count_culturalPhenomenon = sum(1 for _ in results)
        
        if count_culturalPhenomenon > 0:
            print(f"The total count of cultural phenomena referencing the word \"Renaissance\": {count_culturalPhenomenon}")
        else:
            print("No cultural phenomena referencing the word \"Renaissance\"")

        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results, columns=results.vars)

except Exception as e:
    print("An error occurred:", e)

df.info()
df
# Out:
# The total count of cultural phenomena referencing the word "Renaissance": 1129
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1129 entries, 0 to 1128
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   artwork             1129 non-null   object
#  1   culturalPhenomenon  1129 non-null   object
#  2   label               1129 non-null   object
#  3   intrinsicMeaning    1129 non-null   object
# dtypes: object(4)
# memory usage: 35.4+ KB
#                                  artwork                 culturalPhenomenon  \
# 0     https://w3id.org/icon/data/ART1432  https://w3id.org/icon/data/CF1044
# 1     https://w3id.org/icon/data/ART1433  https://w3id.org/icon/data/CF1052
# 2     https://w3id.org/icon/data/ART1068  https://w3id.org/icon/data/CF1053
# 3     https://w3id.org/icon/data/ART1200  https://w3id.org/icon/data/CF1069
# 4     https://w3id.org/icon/data/ART1151  https://w3id.org/icon/data/CF1094
# ...                                  ...                                ...
# 1124  https://w3id.org/icon/data/ART1104  https://w3id.org/icon/data/CF1240
# 1125  https://w3id.org/icon/data/ART1104  https://w3id.org/icon/data/CF1240
# 1126  https://w3id.org/icon/data/ART1104  https://w3id.org/icon/data/CF1240
# 1127  https://w3id.org/icon/data/ART1104  https://w3id.org/icon/data/CF1240
# 1128  https://w3id.org/icon/data/ART1104  https://w3id.org/icon/data/CF1240
#
#                                                   label  \
# 0     Completing the existing structure with a gothi...
# 1     Cover the gothic shapes with more contemporary...
# 2     Crisis of the harmony conciliating the antique...
# 3     During Renaissance, Anteros is explicitly iden...
# 4     Example of anticipation of Renaissance in the ...
# ...                                                 ...
# 1124  Renascences of classical antiquity in Western ...
# 1125  Renascences of classical antiquity in Western ...
# 1126  Renascences of classical antiquity in Western ...
# 1127  Renascences of classical antiquity in Western ...
# 1128  Renascences of classical antiquity in Western ...
#
#                                    intrinsicMeaning
# 0     https://w3id.org/icon/data/ART1432-INTRINSIC1
# 1     https://w3id.org/icon/data/ART1433-INTRINSIC2
# 2     https://w3id.org/icon/data/ART1068-INTRINSIC1
# 3     https://w3id.org/icon/data/ART1200-INTRINSIC1
# 4     https://w3id.org/icon/data/ART1151-INTRINSIC1
# ...                                             ...
# 1124  https://w3id.org/icon/data/ART1111-INTRINSIC1
# 1125  https://w3id.org/icon/data/ART1113-INTRINSIC3
# 1126  https://w3id.org/icon/data/ART1114-INTRINSIC3
# 1127  https://w3id.org/icon/data/ART1151-INTRINSIC3
# 1128  https://w3id.org/icon/data/ART1523-INTRINSIC3
#
# [1129 rows x 4 columns]

# %% [markdown]
# This data reveals that Cultural Phenomena are associated with more than one Intrinsic Meaning, and these connections are established between the artwork and the recognized intrinsic meaning through iconological recognition.
#
# Let's do a step back to clarify how the dataset organized the data relative to the recognition of artworks.
# From [the web site of the project](https://iconology-dataset.streamlit.app/) we read:
#
# > **The interpretation act according to Panofsky**
# > Although a methodology for artwork comprehension was considered by Warburg, the prevailing theoretical approach in the discipline consists of the subdivision of the artwork’s interpretation into 3 or 4 levels, a framework first defined by Erwin Panofsky.
# According to him, there are different types of meaning that can be interpreted in an artwork subdivided in three layers. The depth to which the artwork can be understood depends on the background knowledge of the observer: the more he/she/they has knowledge about the artist, stylistic conventions, cultural context of him/her/them, the more the interpretation at each level is correct, including deeper insights on cultural meanings.
# >
# > **Level 1 (Pre-iconographical description)**
# > The first layer, namely the pre-iconographical description, requires the knowledge of the representational conventions to allow a correct recognition of factual (e.g. objects, people, actions) and emotional meanings, namely primary or natural subjects. In detail, this interpretation is achieved by the recognition of pure forms (i.e. combinations of forms and colours) as carriers of primary subjects. Pure forms such interpreted are called 'artistic motifs', and their combinations are 'compositions'. An enumeration of artistic motifs consistutes a pre-iconographical recognition of the artwork.
# >
# > **Level 2 (Iconographical description)**
# > If the observer is familiar with the literary sources known by the artist, then the subjects already identified at level 1, viz. the artistic motifs or compositions, can be recognised at the second level by the combination of them with concepts and themes, obtaining for example characters (e.g. Venus), personifications (e.g. Virtue), or events (e.g. the Battle of Cascina). The artistic motifs such recognized are called images or Invenzioni, namely the term used by ancient teorists to identify stories and allegories. Allegories are defined in opposition to stories as 'combinations of personifications and/or symbols', although there are many intermediate possibilities between them.
# >
# > **Level 3 (Iconological analysis)**
# > By knowing and understanding the cultural and societal aspects of the artist’s time, it is possible to read the artwork and the subjects identified at the previous levels as symptoms of the contemporary society, of the artist’s beliefs and personality or as the expression of meanings voluntarily inserted. The scholar highlights that the first two levels are a description of facts and are under the domain of iconography, whereas the last level is in the domain of iconology, which is a synthetic intuition and interpretation rather than a description.
#
# We understand that the **Artistic Motif**, also known as the **Composition**, is associated with the initial recognition level, the **Pre-iconographical** phase. At this stage, it involves individual components of the subject displayed within a specific artwork under consideration. Conversely, the second level of recognition, **the Iconographical**,encompasses the entire image. To illustrate, while the Pre-iconographical level might identify elements such as wings, a bow, arrows, and a child, the iconographical recognition recognizes these components as representing Cupid. Moving further to the third level of recognition, **the Iconological** phase, we encounter the **Intrinsic Meaning**. Here, the **Composition**, **Image**, and **Artistic mMtif** (which has a **Factual Meaning**) form part of the intrinsic meaning, which can be identified within a **Cultural Phenomenon**.
#
# This examination aimed to enhance our understanding of the intricate structure of the dataset we are working with. Furthermore, following the same line of inquiry, **we could explore the relationship between artistic motifs and their factual meanings, for instance. They can be of class "Natural Element", "Action", "Expressional Quality", and "Linguistic Object".**

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX cito: <http://purl.org/spar/cito/>

SELECT DISTINCT ?artisticMotif ?typeLabel
WHERE {
    VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification crm:P138_represents}
    # ?iconograficalRecognition icon:recognizedImage ?image ;
                              icon:aboutWorkOfArt ?artwork ;
                              icon:refersToArtisticMotif ?composition .

    # ?image ?rel ?lev2 .
    # ?lev2 rdfs:label ?lev2Label .

    # ?iconograficalRecognition2 icon:recognizedImage ?image2 ; 
                               icon:aboutWorkOfArt ?artwork ;
                               icon:refersToArtisticMotif ?am .
    # ?image2 icon:hasSymbol ?simulation .
    # ?composition icon:hasPart ?artisticMotif . 
    # ?artisticMotif a icon:ArtisticMotif; 
                   icon:hasFactualMeaning | icon:hasExpressionalMeaning | crm:P138_represents ?lev1 .

    # ?lev1 a ?type.
    # ?type rdfs:label ?typeLabel.  

    FILTER(?image != ?image2)
    FILTER(?iconograficalRecognition != ?iconograficalRecognition2)        
}
"""

try:
    # Execute the query and retrieve the results
    print("Before executing SPARQL query")
    results = iconology_graph.query(query)
    print("After executing SPARQL query")
    
    print(results)
    
    # Check if results exist
    if results:
        df = pd.DataFrame(results)
        df = df.set_axis(['artistic_motif', 'type_label'], axis='columns')
        #print(df.head(10))  # Show the first 10 rows of the DataFrame
    else:
        print("No results returned from the SPARQL query")
        
except Exception as e:
    print("An error occurred:", e)

unique_values = df['type_label'].unique()
unique_values
# Out:
# Before executing SPARQL query
# After executing SPARQL query
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x487dac6d0>
#                                 artistic_motif            type_label
# 0  https://w3id.org/icon/data/ART1002test-AM10                Action
# 1  https://w3id.org/icon/data/ART1002test-AM23  Expressional Quality
# 2  https://w3id.org/icon/data/ART1003test-AM13       Natural Element
# 3  https://w3id.org/icon/data/ART1003test-AM18       Natural Element
# 4  https://w3id.org/icon/data/ART1003test-AM23       Natural Element
# 5   https://w3id.org/icon/data/ART1003test-AM3                Action
# 6   https://w3id.org/icon/data/ART1003test-AM8       Natural Element
# 7  https://w3id.org/icon/data/ART1009test-AM10       Natural Element
# 8   https://w3id.org/icon/data/ART1009test-AM4       Natural Element
# 9   https://w3id.org/icon/data/ART1013test-AM6                Action
# array([rdflib.term.Literal('Action'),
#        rdflib.term.Literal('Expressional Quality'),
#        rdflib.term.Literal('Natural Element'),
#        rdflib.term.Literal('Linguistic Object')], dtype=object)

# %% [markdown]
# Let's plot the result to see how many type of artistic motif are present in the dataset.

# %%
# Count the occurrences of each type_label
type_counts = df['type_label'].value_counts()

# Plotting the bar chart
plt.figure(figsize=(10, 8))
type_counts.plot(kind='bar', color='skyblue')

# Add background grid
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid lines on the x-axis
    

plt.xlabel('Type Label')
plt.ylabel('Count')
plt.title('Number of Artistic Motif with Specified Types')
plt.xticks(rotation=45)  # Rotate x-labels for better readability if needed
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.2. Filter Zeri Photo Archive Collection
# Representing the model developed by the Zeri Foundation to describe the complexity of the photographic archive, alongside the collection of auction catalogs and archival materials, required the collaboration of various professionals. The interdisciplinary team behind the ***[Zeri & LODE project](https://data.fondazionezeri.unibo.it/)*** involves art historians from the Zeri Foundation, as well as experts in digital humanities and knowledge organization from the Department of Classical Philology and Italian Studies and the Department of Computer Science, Science, and Engineering at the University of Bologna.
#
# As a best practice, the project chose to reuse existing and widely adopted ontologies in the Cultural Heritage domain, developing new models only for describing aspects that hadn’t been explored before. Ontologies like **[CIDOC-CRM](http://www.cidoc-crm.org/)**, used for describing art objects, and the **[SPAR Ontologies](http://www.sparontologies.net/)**, referencing the accompanying photographic and archival documentation, were accompanied by a specially designed model, HiCO, capable of representing the act of attribution. HiCO analyzes the methodologies employed by both the producing entity and the cataloger in selecting the attributed author for the works, whether they are sources, authoritative opinions, captions, or simple classifications of photos within the archive system.
#
# This depth of knowledge representation also required a careful semiotic analysis of the "photograph" object, in its dual nature as a document and a monument: conveying the reproduced artwork but also reflecting the photographer's intent, thus itself becoming an artwork deserving of proper valorization.
#
# The outcome of this conceptual analysis was the creation of two corresponding ontologies, the **[F Entry Ontology](http://www.essepuntato.it/2014/03/fentry)** and the **[OA Entry Ontology](http://purl.org/emmedi/oaentry)**, for respectively describing photographs and reproduced artworks. These ontologies aim to enhance this wealth of meta-information and ensure its proper reuse by researchers and other cultural institutions.
#
# In accordance with these models, the RDF dataset was developed, representing around 30,000 F entries and 19,000 objects documented by the photographs. The data is available online ([Zeri Catalog](https://w3id.org/zericatalog/)) for free browsing through the RDF LODView browser, querying via SPARQL endpoint ([Fondazione Zeri SPARQL Endpoint](http://data.fondazionezeri.unibo.it/query)), and downloading ([AMS Acta](http://amsacta.unibo.it/5497/)).
#
# Firstly, in the following code snippet, we perform a test query on the `zeri_graph` we parsed.

# %%
# Define the SPARQL query
query = """
SELECT DISTINCT ?class_uri
WHERE {
    # ?anything a ?class_uri .
} LIMIT 10
"""

# Prepare the SPARQL query
query_obj = prepareQuery(query)

# Execute the query and retrieve the results
lists_classes = zeri_graph.query(query_obj)

# Uncomment the two following lines to see the list of classes
for row in lists_classes:
    print(row['class_uri'])
# Out:
# http://purl.org/emmedi/oaentry/OAEntry
# http://www.cidoc-crm.org/cidoc-crm/E31_Document
# http://www.cidoc-crm.org/cidoc-crm/E35_Title
# http://www.cidoc-crm.org/cidoc-crm/E15_Identifier_Assignment
# http://www.cidoc-crm.org/cidoc-crm/E42_Identifier
# http://www.cidoc-crm.org/cidoc-crm/E55_Type
# http://www.cidoc-crm.org/cidoc-crm/E40_Legal_Body
# http://www.cidoc-crm.org/cidoc-crm/E65_Creation
# http://www.cidoc-crm.org/cidoc-crm/E21_Person
# http://purl.org/spar/fabio/MetadataDocument

# %% [markdown]
# Considering the usage of various namespaces within the Zeri's RDF dataset, we print them to enhance our comprehension.

# %%
# Get the namespace manager of the graph
namespace_manager = zeri_graph.namespace_manager

# Retrieve all prefixes used in the RDF graph
prefixes = {str(prefix): str(namespace_manager.store.namespace(prefix)) for prefix in namespace_manager.namespaces()}

# Display the prefixes and their corresponding URIs
for prefix, uri in prefixes.items():
    print(f"Prefix: {prefix}")
# Out:
# Prefix: ('brick', rdflib.term.URIRef('https://brickschema.org/schema/Brick#'))
# Prefix: ('csvw', rdflib.term.URIRef('http://www.w3.org/ns/csvw#'))
# Prefix: ('dc', rdflib.term.URIRef('http://purl.org/dc/elements/1.1/'))
# Prefix: ('dcat', rdflib.term.URIRef('http://www.w3.org/ns/dcat#'))
# Prefix: ('dcmitype', rdflib.term.URIRef('http://purl.org/dc/dcmitype/'))
# Prefix: ('dcterms', rdflib.term.URIRef('http://purl.org/dc/terms/'))
# Prefix: ('dcam', rdflib.term.URIRef('http://purl.org/dc/dcam/'))
# Prefix: ('doap', rdflib.term.URIRef('http://usefulinc.com/ns/doap#'))
# Prefix: ('foaf', rdflib.term.URIRef('http://xmlns.com/foaf/0.1/'))
# Prefix: ('geo', rdflib.term.URIRef('http://www.opengis.net/ont/geosparql#'))
# Prefix: ('odrl', rdflib.term.URIRef('http://www.w3.org/ns/odrl/2/'))
# Prefix: ('org', rdflib.term.URIRef('http://www.w3.org/ns/org#'))
# Prefix: ('prof', rdflib.term.URIRef('http://www.w3.org/ns/dx/prof/'))
# Prefix: ('prov', rdflib.term.URIRef('http://www.w3.org/ns/prov#'))
# Prefix: ('qb', rdflib.term.URIRef('http://purl.org/linked-data/cube#'))
# Prefix: ('schema', rdflib.term.URIRef('https://schema.org/'))
# Prefix: ('sh', rdflib.term.URIRef('http://www.w3.org/ns/shacl#'))
# Prefix: ('skos', rdflib.term.URIRef('http://www.w3.org/2004/02/skos/core#'))
# Prefix: ('sosa', rdflib.term.URIRef('http://www.w3.org/ns/sosa/'))
# Prefix: ('ssn', rdflib.term.URIRef('http://www.w3.org/ns/ssn/'))
# Prefix: ('time', rdflib.term.URIRef('http://www.w3.org/2006/time#'))
# Prefix: ('vann', rdflib.term.URIRef('http://purl.org/vocab/vann/'))
# Prefix: ('void', rdflib.term.URIRef('http://rdfs.org/ns/void#'))
# Prefix: ('wgs', rdflib.term.URIRef('https://www.w3.org/2003/01/geo/wgs84_pos#'))
# Prefix: ('owl', rdflib.term.URIRef('http://www.w3.org/2002/07/owl#'))
# Prefix: ('rdf', rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#'))
# Prefix: ('rdfs', rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#'))
# Prefix: ('xsd', rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#'))
# Prefix: ('xml', rdflib.term.URIRef('http://www.w3.org/XML/1998/namespace'))
# Prefix: ('hico', rdflib.term.URIRef('http://purl.org/emmedi/hico/'))
# Prefix: ('crm', rdflib.term.URIRef('http://www.cidoc-crm.org/cidoc-crm/'))
# Prefix: ('oaentry', rdflib.term.URIRef('http://purl.org/emmedi/oaentry/'))
# Prefix: ('fentry', rdflib.term.URIRef('http://www.essepuntato.it/2014/03/fentry/'))
# Prefix: ('frbr', rdflib.term.URIRef('http://purl.org/vocab/frbr/core#'))
# Prefix: ('fabio', rdflib.term.URIRef('http://purl.org/spar/fabio/'))
# Prefix: ('cito', rdflib.term.URIRef('http://purl.org/spar/cito/'))
# Prefix: ('zeri', rdflib.term.URIRef('https://w3id.org/zericatalog/'))
# Prefix: ('prism', rdflib.term.URIRef('http://prismstandard.org/namespaces/basic/2.0/'))
# Prefix: ('pro', rdflib.term.URIRef('http://purl.org/spar/pro/'))
# Prefix: ('time1', rdflib.term.URIRef('http://www.ontologydesignpatterns.org/cp/owl/timeindexedsituation.owl#'))
# Prefix: ('ti', rdflib.term.URIRef('http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#'))
# Prefix: ('tvc', rdflib.term.URIRef('http://www.essepuntato.it/2012/04/tvc/'))
# Prefix: ('prov1', rdflib.term.URIRef('http://www.w3.org/ns/prov-o#'))
# Prefix: ('zeri1', rdflib.term.URIRef('http://w3id.org/zericatalog/'))

# %% [markdown]
# As an initial query, we count **how many artists are classified as painters in the dataset.**

# %%
# Define the SPARQL query
query = """
PREFIX zeri1: <http://www.w3.org/ns/prov-o#>
PREFIX pro: <http://purl.org/spar/pro/>
PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT DISTINCT ?artist ?artistLabel
WHERE {
    # ?artist pro:withRole oaentry:painter ;
            rdfs:label ?artistLabel .
    FILTER(LANG(?artistLabel) = 'en')
}
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:

        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results, columns=results.vars)

        print("Number of painters:", len(df))

    else:
        
        print("No painters founded")

except Exception as e:
    
    print("An error occurred:", e)

df.info()
df
# Out:
# Number of painters: 4465
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4465 entries, 0 to 4464
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist       4465 non-null   object
#  1   artistLabel  4465 non-null   object
# dtypes: object(2)
# memory usage: 69.9+ KB
#                                                  artist  \
# 0     https://w3id.org/zericatalog/role/painter/bemb...
# 1     https://w3id.org/zericatalog/role/painter/pret...
# 2     https://w3id.org/zericatalog/role/painter/tucc...
# 3     https://w3id.org/zericatalog/role/painter/euse...
# 4     https://w3id.org/zericatalog/role/painter/giac...
# ...                                                 ...
# 4460  https://w3id.org/zericatalog/role/painter/erri...
# 4461  https://w3id.org/zericatalog/role/painter/capr...
# 4462  https://w3id.org/zericatalog/role/painter/pseu...
# 4463  https://w3id.org/zericatalog/role/painter/stro...
# 4464  https://w3id.org/zericatalog/role/painter/magi...
#
#                           artistLabel
# 0            Bembo Bonifacio, painter
# 1             Preti Gregorio, painter
# 2           Tuccari Giovanni, painter
# 3     Eusebio da San Giorgio, painter
# 4            Giacomo da Riva, painter
# ...                               ...
# 4460   Erri Bartolomeo degli, painter
# 4461       Caprioli Domenico, painter
# 4462           Pseudo Scacco, painter
# 4463         Stroifi Ermanno, painter
# 4464            Magini Carlo, painter
#
# [4465 rows x 2 columns]

# %% [markdown]
# Let's now see **how many titled artworks are presented in the catalog?**

# %%
# Define the SPARQL query
query_artwork = """
    PREFIX zeri1: <http://www.w3.org/ns/prov-o#>
    PREFIX pro: <http://purl.org/spar/pro/>
    PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
    PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX frbr: <http://purl.org/vocab/frbr/core#>
    PREFIX prov: <http://www.w3.org/ns/prov#>
    PREFIX fabio: <http://purl.org/spar/fabio/>

SELECT DISTINCT ?artwork ?artworkTitleLabel
WHERE { 
    # ?photographs frbr:subject ?artwork ;
                 fabio:hasSubjectTerm ?photoSubject ;
                 crm:P102_has_title ?artworkTitle .
                 
    # ?artworkTitle rdfs:label ?artworkTitleLabel .
    FILTER(LANG(?artworkTitleLabel) = 'en')
}

"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query_artwork)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:

        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results, columns=results.vars)

        print("Number of artworks:", len(df))

    else:
        
        print("No artworks founded")

except Exception as e:
    print("An error occurred:", e)

df.info()
df
# Out:
# Number of artworks: 25711
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25711 entries, 0 to 25710
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artwork            25711 non-null  object
#  1   artworkTitleLabel  25711 non-null  object
# dtypes: object(2)
# memory usage: 401.9+ KB
#                                                artwork  \
# 0      https://w3id.org/zericatalog/artwork/42605/item
# 1      https://w3id.org/zericatalog/artwork/16567/item
# 2      https://w3id.org/zericatalog/artwork/27111/item
# 3      https://w3id.org/zericatalog/artwork/37625/item
# 4      https://w3id.org/zericatalog/artwork/41044/item
# ...                                                ...
# 25706  https://w3id.org/zericatalog/artwork/29553/item
# 25707  https://w3id.org/zericatalog/artwork/48045/item
# 25708  https://w3id.org/zericatalog/artwork/27093/item
# 25709  https://w3id.org/zericatalog/artwork/36898/item
# 25710  https://w3id.org/zericatalog/artwork/40439/item
#
#                                        artworkTitleLabel
# 0      Attributed title "Negretti Iacopo - sec. XVI -...
# 1      Proper title "Roma. Cappella Sistina. Figura a...
# 2      Attributed title "Giovanni di Pietro - sec. XV...
# 3      Attributed title "Anonimo napoletano - sec. XV...
# 4      Proper title "A Portrait of a Gentleman wearin...
# ...                                                  ...
# 25706  Proper title "Spoleto - S. Maria delle Grazie ...
# 25707  Proper title "Lorenzo Lotto, Italian, Venetian...
# 25708  Attributed title "Giovanni di Pietro - sec. XV...
# 25709  Attributed title "Foschi Pier Francesco - sec....
# 25710  Proper title "Orazio Samacchini. Cherubini con...
#
# [25711 rows x 2 columns]

# %% [markdown]
# ### Data Organization and Ontologies Used in the Zeri Photo Archive Collection
#
# The Zeri Foundation cataloged Zeri's repository using two Italian metadata content standards: [Scheda F](http://www.iccd.beniculturali.it/index.php?it/473/standard-catalografici/Standard/10) (Scheda di fotografia) for photographs and [Scheda OA](http://www.iccd.beniculturali.it/index.php?it/473/standard-catalografici/Standard/29) (Scheda Opera d'Arte) for artworks. Will be used the original names Scheda F and Scheda OA and their English translations, F Entry and OA Entry, to refer to the metadata documents.
#
# Both standards are part of the ICCD (Istituto Centrale per il Catalogo e la Documentazione), an institute under the Italian Ministry of Cultural Heritage overseeing cataloging standards for various cultural objects.
#
# To complement the CIDOC-CRM model, the F Entry Ontology and the OA Entry Ontology were developed to address scenarios not covered by CIDOC-CRM.
#
# The dataset begins with the photo as the catalog entry, potentially making the data structure appear complex initially. For a deeper understanding of the artwork-photo relationship, refer to the paper *"[Enhancing Semantic Expressivity in the Cultural Heritage Domain: Exposing the Zeri Photo Archive as Linked Open Data](https://essepuntato.it/papers/zeri-and-lode-jocch.html)."*
#
# ### Exploring Work-Expression-Manifestation-Item Relationship in FaBiO Ontology
#
# - **oaentry:OAEntry**: A document containing metadata about an artwork and the object portrayed.
# - **crm:E65_Creation**: Refers to the creation of the OA Entry document.
# - **fabio:MetadataDocument**: Expresses the content of the OA Entry.
# - **fabio:ArtisticWork**: Represents works of art using FRBR Work, Manifestation, and Item terms, considering aspects like essence, physical features, legal aspects, and location.
# - **crm:E65_Creation**: Manifestation level describing the act of creation, including the creation's time span, artist/author details, and group attribution.
# - **fabio:AnalogManifestation**: Item level describing material details (e.g., material composition).
# - **fabio:AnalogItem**: Indicates the location of the Item.

# %%
# Define the SPARQL query
query = """
PREFIX zeri1: <http://www.w3.org/ns/prov-o#>
PREFIX pro: <http://purl.org/spar/pro/>
PREFIX : <http://www.essepuntato.it/2014/03/fentry-abox/>
PREFIX fentry: <http://www.essepuntato.it/2014/03/fentry/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX frbr: <http://purl.org/vocab/frbr/core#>
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX emmedi: <http://purl.org/emmedi/>
PREFIX hico: <http://purl.org/emmedi/hico/>
PREFIX terms: <http://purl.org/dc/terms/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?oaEntry ?artisticArtwork ?manifestation ?analogItem
WHERE {

    # ?oaEntry a oaentry:OAEntry .

    # ?artisticArtwork a fabio:ArtisticWork;
                     fabio:hasManifestation ?manifestation.
    
    # ?analogItem a fabio:AnalogItem .
    
    # ?manifestation ?p ?analogItem .

} LIMIT 10
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:
        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results.bindings)


except Exception as e:
    print("An error occurred:", e)

df
# Out:
#                                         analogItem  \
# 0  https://w3id.org/zericatalog/artwork/18157/item
# 1  https://w3id.org/zericatalog/artwork/18157/item
# 2  https://w3id.org/zericatalog/artwork/18157/item
# 3  https://w3id.org/zericatalog/artwork/18157/item
# 4  https://w3id.org/zericatalog/artwork/18157/item
# 5  https://w3id.org/zericatalog/artwork/18157/item
# 6  https://w3id.org/zericatalog/artwork/18157/item
# 7  https://w3id.org/zericatalog/artwork/18157/item
# 8  https://w3id.org/zericatalog/artwork/18157/item
# 9  https://w3id.org/zericatalog/artwork/18157/item
#
#                               artisticArtwork  \
# 0  https://w3id.org/zericatalog/artwork/18157
# 1  https://w3id.org/zericatalog/artwork/18157
# 2  https://w3id.org/zericatalog/artwork/18157
# 3  https://w3id.org/zericatalog/artwork/18157
# 4  https://w3id.org/zericatalog/artwork/18157
# 5  https://w3id.org/zericatalog/artwork/18157
# 6  https://w3id.org/zericatalog/artwork/18157
# 7  https://w3id.org/zericatalog/artwork/18157
# 8  https://w3id.org/zericatalog/artwork/18157
# 9  https://w3id.org/zericatalog/artwork/18157
#
#                                        manifestation  \
# 0  https://w3id.org/zericatalog/artwork/18157/man...
# 1  https://w3id.org/zericatalog/artwork/18157/man...
# 2  https://w3id.org/zericatalog/artwork/18157/man...
# 3  https://w3id.org/zericatalog/artwork/18157/man...
# 4  https://w3id.org/zericatalog/artwork/18157/man...
# 5  https://w3id.org/zericatalog/artwork/18157/man...
# 6  https://w3id.org/zericatalog/artwork/18157/man...
# 7  https://w3id.org/zericatalog/artwork/18157/man...
# 8  https://w3id.org/zericatalog/artwork/18157/man...
# 9  https://w3id.org/zericatalog/artwork/18157/man...
#
#                                       oaEntry
# 0  https://w3id.org/zericatalog/oaentry/16885
# 1  https://w3id.org/zericatalog/oaentry/35919
# 2  https://w3id.org/zericatalog/oaentry/38690
# 3  https://w3id.org/zericatalog/oaentry/45093
# 4  https://w3id.org/zericatalog/oaentry/45646
# 5  https://w3id.org/zericatalog/oaentry/36800
# 6  https://w3id.org/zericatalog/oaentry/47269
# 7  https://w3id.org/zericatalog/oaentry/41648
# 8  https://w3id.org/zericatalog/oaentry/41946
# 9  https://w3id.org/zericatalog/oaentry/30693

# %% [markdown]
# This comprehension was essential for conducting complex queries that aim to determine **the number of artworks, within the selected timeframe, with specified type and location.**

# %%
# Define the SPARQL query
query = """
PREFIX zeri1: <http://www.w3.org/ns/prov-o#>
PREFIX pro: <http://purl.org/spar/pro/>
PREFIX : <http://www.essepuntato.it/2014/03/fentry-abox/>
PREFIX fentry: <http://www.essepuntato.it/2014/03/fentry/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX frbr: <http://purl.org/vocab/frbr/core#>
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX emmedi: <http://purl.org/emmedi/>
PREFIX hico: <http://purl.org/emmedi/hico/>
PREFIX terms: <http://purl.org/dc/terms/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?artwork ?artworkLabel ?artworkTypeLabel ?startDate ?keeperLabel ?locationLabel
WHERE {

    # ?artwork a fabio:ArtisticWork  ;
             rdfs:label ?artworkLabel ;
             crm:P94i_was_created_by ?creation ;
             fabio:hasManifestation ?manifestation ;
             crm:P2_has_type ?artworkType .
                 
    # ?artworkType rdfs:label ?artworkTypeLabel .
    FILTER(LANG(?artworkTypeLabel) = 'en')
                 
    # ?creation crm:P4_has_time_span ?timeSpan .
    # ?timeSpan ti:hasIntervalStartDate ?startDate .

    # ?manifestation frbr:exemplar ?analogItem .

    # ?analogItem crm:P50_has_current_keeper ?keeper .
    # ?keeper rdfs:label ?keeperLabel .

    # ?keeper crm:P74_has_current_or_former_residence ?location .
    # ?location rdfs:label ?locationLabel .
    
    FILTER(
    xsd:dateTime(?startDate) >= xsd:dateTime("1400-01-01T00:00:00Z") &&
    xsd:dateTime(?startDate) <= xsd:dateTime("1600-12-31T23:59:59Z")
    )

}
ORDER BY ?startDate
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:

        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results, columns=results.vars)

        df = df.set_axis(['artwork','artworkLabel', 'artworkTypeLabel', 'startDate', 'keeperLabel', 'locationLabel'], axis='columns')
                
        # Modify the regex pattern to drop two capital letters at the end of 'locationLabel' with the last space
        df['locationLabel'] = df['locationLabel'].str.replace(r'\s+[A-Z]{2}$', '', regex=True)

except Exception as e:
    print("An error occurred:", e)

filtered_df = df.drop_duplicates(['artwork'])

# Reindex the DataFrame to create a continuous index sequence
filtered_df = filtered_df.reset_index(drop=True)

filtered_df.info()
filtered_df.head(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15944 entries, 0 to 15943
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artwork           15944 non-null  object
#  1   artworkLabel      15944 non-null  object
#  2   artworkTypeLabel  15944 non-null  object
#  3   startDate         15944 non-null  object
#  4   keeperLabel       15944 non-null  object
#  5   locationLabel     15944 non-null  object
# dtypes: object(6)
# memory usage: 747.5+ KB
#                                        artwork  \
# 0   https://w3id.org/zericatalog/artwork/29205
# 1   https://w3id.org/zericatalog/artwork/29470
# 2   https://w3id.org/zericatalog/artwork/29471
# 3   https://w3id.org/zericatalog/artwork/29473
# 4   https://w3id.org/zericatalog/artwork/29472
# 5   https://w3id.org/zericatalog/artwork/29489
# 6   https://w3id.org/zericatalog/artwork/29461
# 7   https://w3id.org/zericatalog/artwork/29449
# 8   https://w3id.org/zericatalog/artwork/29448
# 9   https://w3id.org/zericatalog/artwork/29451
# 10  https://w3id.org/zericatalog/artwork/29445
# 11  https://w3id.org/zericatalog/artwork/29487
# 12  https://w3id.org/zericatalog/artwork/29452
# 13  https://w3id.org/zericatalog/artwork/29480
# 14  https://w3id.org/zericatalog/artwork/29483
# 15  https://w3id.org/zericatalog/artwork/29454
# 16  https://w3id.org/zericatalog/artwork/29440
# 17  https://w3id.org/zericatalog/artwork/29468
# 18  https://w3id.org/zericatalog/artwork/29441
# 19  https://w3id.org/zericatalog/artwork/29437
# 20  https://w3id.org/zericatalog/artwork/29003
# 21  https://w3id.org/zericatalog/artwork/29567
# 22  https://w3id.org/zericatalog/artwork/29572
# 23  https://w3id.org/zericatalog/artwork/29566
# 24  https://w3id.org/zericatalog/artwork/29389
# 25  https://w3id.org/zericatalog/artwork/29364
# 26  https://w3id.org/zericatalog/artwork/29370
# 27  https://w3id.org/zericatalog/artwork/29378
# 28  https://w3id.org/zericatalog/artwork/29387
# 29  https://w3id.org/zericatalog/artwork/29392
# 30  https://w3id.org/zericatalog/artwork/29397
# 31  https://w3id.org/zericatalog/artwork/29410
# 32  https://w3id.org/zericatalog/artwork/29418
# 33  https://w3id.org/zericatalog/artwork/29421
# 34  https://w3id.org/zericatalog/artwork/29425
# 35  https://w3id.org/zericatalog/artwork/29362
# 36  https://w3id.org/zericatalog/artwork/29564
# 37  https://w3id.org/zericatalog/artwork/29565
# 38  https://w3id.org/zericatalog/artwork/29428
# 39  https://w3id.org/zericatalog/artwork/29562
# 40  https://w3id.org/zericatalog/artwork/28735
# 41  https://w3id.org/zericatalog/artwork/27878
# 42  https://w3id.org/zericatalog/artwork/27877
# 43  https://w3id.org/zericatalog/artwork/27844
# 44  https://w3id.org/zericatalog/artwork/27879
# 45  https://w3id.org/zericatalog/artwork/35477
# 46  https://w3id.org/zericatalog/artwork/19980
# 47  https://w3id.org/zericatalog/artwork/29314
# 48  https://w3id.org/zericatalog/artwork/27880
# 49  https://w3id.org/zericatalog/artwork/27869
#
#                                          artworkLabel artworkTypeLabel  \
# 0   Artwork "Anonimo umbro sec. XV , San Nicola di...           fresco
# 1   Artwork "Anonimo umbro sec. XV , Sant'Antonio ...           fresco
# 2   Artwork "Anonimo umbro sec. XV , Sant'Antonio ...           fresco
# 3   Artwork "Anonimo umbro sec. XV , Santi" , (fra...           fresco
# 4   Artwork "Anonimo umbro sec. XV , Cristo giudic...           fresco
# 5   Artwork "Anonimo umbro sec. XV , Santo" , (fra...           fresco
# 6   Artwork "Anonimo umbro sec. XV , Persona a tre...           fresco
# 7   Artwork "Anonimo umbro sec. XV , San Giorgio e...           fresco
# 8   Artwork "Anonimo umbro sec. XV , Sant'Antonio ...           fresco
# 9   Artwork "Anonimo umbro sec. XV , Testa d'uomo ...    mural drawing
# 10  Artwork "Anonimo umbro sec. XV , San Giorgio e...           fresco
# 11  Artwork "Anonimo umbro sec. XV , Santo cavalie...           fresco
# 12  Artwork "Anonimo umbro sec. XV , San Bartolome...           fresco
# 13  Artwork "Anonimo umbro sec. XV , Sant'Orsola e...           fresco
# 14  Artwork "Anonimo umbro sec. XV , Sant'Antonio ...           fresco
# 15  Artwork "Anonimo umbro sec. XV , Madonna con B...           fresco
# 16  Artwork "Anonimo umbro sec. XV , Sant'Ugo in t...           fresco
# 17  Artwork "Anonimo umbro sec. XV , Testa di santo"            fresco
# 18  Artwork "Anonimo umbro sec. XV , Crocifissione...           fresco
# 19  Artwork "Anonimo umbro sec. XV , Madonna con B...           fresco
# 20       Artwork "Anonimo umbro sec. XV , Dio Padre"           lunette
# 21  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 22  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 23  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 24  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 25  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 26  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 27  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 28  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 29  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 30  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 31  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 32  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 33  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 34  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 35  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 36  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 37  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 38  Artwork "Antonio del Massaro , Madonna con Bam...         painting
# 39  Artwork "Antonio del Massaro , Adorazione del ...         painting
# 40  Artwork "Anonimo umbro sec. XV/ XVI , Madonna ...         painting
# 41  Artwork "Maestro della Madonna di Liverpool , ...   polyptych wing
# 42  Artwork "Maestro della Madonna di Liverpool , ...   polyptych wing
# 43  Artwork "Maestro della Madonna di Liverpool , ...         painting
# 44  Artwork "Maestro della Madonna di Liverpool , ...         painting
# 45  Artwork "Anonimo lombardo sec. XV/ XVI , Visio...         painting
# 46     Artwork "Anonimo umbro sec. XV , Evangelisti"            fresco
# 47  Artwork "Antonio del Massaro , Orazione di Cri...           fresco
# 48  Artwork "Maestro della Madonna di Liverpool , ...         painting
# 49  Artwork "Maestro della Madonna di Liverpool , ...         painting
#
#                startDate                                        keeperLabel  \
# 0   1400-01-01T00:00:00Z                                Pinacoteca Comunale
# 1   1400-01-01T00:00:00Z                             Chiesa di S. Francesco
# 2   1400-01-01T00:00:00Z                             Chiesa di S. Francesco
# 3   1400-01-01T00:00:00Z                              Chiesa di S. Agostino
# 4   1400-01-01T00:00:00Z                              Chiesa di S. Agostino
# 5   1400-01-01T00:00:00Z                              Chiesa di S. Agostino
# 6   1400-01-01T00:00:00Z                             Chiesa di S. Francesco
# 7   1400-01-01T00:00:00Z                             Chiesa di S. Francesco
# 8   1400-01-01T00:00:00Z                             Chiesa di S. Francesco
# 9   1400-01-01T00:00:00Z                             Chiesa di S. Francesco
# 10  1400-01-01T00:00:00Z                         Chiesa di S. Domenico (ex)
# 11  1400-01-01T00:00:00Z                              Chiesa di S. Agostino
# 12  1400-01-01T00:00:00Z                             Chiesa di S. Francesco
# 13  1400-01-01T00:00:00Z                              Chiesa di S. Agostino
# 14  1400-01-01T00:00:00Z                              Chiesa di S. Agostino
# 15  1400-01-01T00:00:00Z                             Chiesa di S. Francesco
# 16  1400-01-01T00:00:00Z                         Chiesa di S. Domenico (ex)
# 17  1400-01-01T00:00:00Z                             Chiesa di S. Francesco
# 18  1400-01-01T00:00:00Z                         Chiesa di S. Domenico (ex)
# 19  1400-01-01T00:00:00Z                         Chiesa di S. Domenico (ex)
# 20  1450-01-01T00:00:00Z                                Pinacoteca Comunale
# 21  1450-01-01T00:00:00Z                                 Collezione Gentili
# 22  1450-01-01T00:00:00Z                                              Duits
# 23  1450-01-01T00:00:00Z                     The Metropolitan Museum of Art
# 24  1450-01-01T00:00:00Z                                    Asta Christie's
# 25  1450-01-01T00:00:00Z                      Chiesa di S. Maria del Riposo
# 26  1450-01-01T00:00:00Z                                 Mercato antiquario
# 27  1450-01-01T00:00:00Z         Museo di Belle Arti (Szépmüvészeti Múzeum)
# 28  1450-01-01T00:00:00Z                                 Mercato antiquario
# 29  1450-01-01T00:00:00Z                                     Museo Borgogna
# 30  1450-01-01T00:00:00Z          Museo e Gallerie Nazionali di Capodimonte
# 31  1450-01-01T00:00:00Z    Harvard University Art Museums, Fogg Art Museum
# 32  1450-01-01T00:00:00Z                                            Jandolo
# 33  1450-01-01T00:00:00Z                                           Salocchi
# 34  1450-01-01T00:00:00Z                                    Asta Christie's
# 35  1450-01-01T00:00:00Z                         Museo dell'Opera del Duomo
# 36  1450-01-01T00:00:00Z                         Philadelphia Museum of Art
# 37  1450-01-01T00:00:00Z                                           E. Volpi
# 38  1450-01-01T00:00:00Z                        Muzeum Narodowe w Warszawie
# 39  1450-01-01T00:00:00Z                                       Asta Tavazzi
# 40  1450-01-01T00:00:00Z                              Kleinberger Galleries
# 41  1450-01-01T00:00:00Z  Chiesa dei SS. Pietro Apostolo e Caterina V. e M.
# 42  1450-01-01T00:00:00Z  Chiesa dei SS. Pietro Apostolo e Caterina V. e M.
# 43  1450-01-01T00:00:00Z                      Alexander City Public Library
# 44  1450-01-01T00:00:00Z                                       Museo Civico
# 45  1450-01-01T00:00:00Z                                    Collezione Cini
# 46  1450-01-01T00:00:00Z                                 Chiesa di S. Maria
# 47  1450-01-01T00:00:00Z                                       Museo Civico
# 48  1450-01-01T00:00:00Z                                    Lindenau-Museum
# 49  1450-01-01T00:00:00Z                                 Collezione privata
#
#      locationLabel
# 0           Assisi
# 1            Narni
# 2            Narni
# 3            Narni
# 4            Narni
# 5            Narni
# 6            Narni
# 7            Narni
# 8            Narni
# 9            Narni
# 10           Narni
# 11           Narni
# 12           Narni
# 13           Narni
# 14           Narni
# 15           Narni
# 16           Narni
# 17           Narni
# 18           Narni
# 19           Narni
# 20          Gubbio
# 21          Parigi
# 22          Londra
# 23        New York
# 24          Londra
# 25        Tuscania
# 26         Brescia
# 27        Budapest
# 28          Parigi
# 29        Vercelli
# 30          Napoli
# 31       Cambridge
# 32            Roma
# 33         Firenze
# 34        New York
# 35         Orvieto
# 36    Philadelphia
# 37         Firenze
# 38        Varsavia
# 39            Roma
# 40          Parigi
# 41     Ronciglione
# 42     Ronciglione
# 43  Alexander City
# 44           Rieti
# 45         Venezia
# 46           Ponte
# 47         Viterbo
# 48       Altenburg
# 49            Oslo

# %% [markdown]
# The Zeri dataset also annotates the subjects depicted in the artworks. It doesn't adhere to a specific rule. However, if we compare it with the Iconology dataset regarding the level of iconography representation in the artworks, Zeri Archive utilizes the second level. This level recognizes and identifies iconographical objects such as women or men, labeled as "Maria vergine" or "Gesù Cristo," etc. The issue arises from the subjects being labeled in Italian and the lack of alignment between the classes in the two datasets.
#
# Here's an example query that describes **the subjects recognized in an artwork, for instance, the *"Creation of Adam"* by Michelangelo.**

# %%
# Define the SPARQL query
query = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX frbr: <http://purl.org/vocab/frbr/core#>
PREFIX fabio: <http://purl.org/spar/fabio/>

SELECT DISTINCT ?artworkLabel ?subjectLabel
WHERE {

    <https://w3id.org/zericatalog/artwork/16568> a fabio:ArtisticWork  ;
                                                 rdfs:label ?artworkLabel ;
                                                 fabio:hasSubjectTerm ?subject.
    FILTER(LANG(?artworkLabel) = 'en')        
             
    # ?subject rdfs:label ?subjectLabel.

}
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:

        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results, columns=results.vars)


except Exception as e:
    print("An error occurred:", e)

df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artworkLabel  1 non-null      object
#  1   subjectLabel  1 non-null      object
# dtypes: object(2)
# memory usage: 148.0+ bytes
#                                         artworkLabel        subjectLabel
# 0  Artwork "Buonarroti Michelangelo , Creazione d...  Creazione di Adamo

# %% [markdown]
# For our further analysis, it's crucial to consider this aspect, and we can explore it further by conducting some string-based searches.

# %% [markdown]
# # 3. Represent
# After filtering and initial mining, data is represented or visualized in a meaningful way using graphs, charts, or statistical summaries. This step aims to present the insights gained from the data in a format that is easy to understand and interpret.

# %% [markdown]
# ## 3.1. Represent Iconology Dataset
#
# Let's now try to ask the more specific question about our time span.
# **What are the most frequent subject represented at level 1 in Renaissance period?**

# %%
# Define the SPARQL query
query = """		
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT DISTINCT ?artisticMotif ?level1Label ?artwork ?startDate
WHERE {
    # ?production a crm:E12_Production ;
                crm:P108_has_produced ?producedObject ;
                crm:P4_has_time_span ?timeSpan .
    # ?timeSpan crm:P82a_begin_of_the_begin ?startDate .

    BIND (xsd:integer(SUBSTR(?startDate, 1, 4)) AS ?startYear) .
    FILTER (?startYear >= 1400 && ?startYear <= 1600)
  
    # ?producedObject crm:P65_shows_visual_item ?artwork .

    # ?preiconRecognition a icon:PreiconographicalRecognition ;
                        icon:aboutWorkOfArt ?artwork .
  
    # ?preiconRecognition icon:recognizedArtisticMotif ?artisticMotif .
  
    # ?artisticMotif icon:hasFactualMeaning | icon:hasExpressionalMeaning | crm:P138_represents ?level1 .
    # ?level1 rdfs:label ?level1Label .
    
} ORDER BY ?startDate
"""

try:
    # Execute the query and retrieve the results
    print("Before executing SPARQL query")
    results = iconology_graph.query(query)
    print("After executing SPARQL query")
    
    print(results)
    
    # Check if results exist
    if results:
        df_level1 = pd.DataFrame(results)
        df_level1 = df_level1.set_axis(['artistic_motif', 'level1_label', 'artwork', 'start_date'], axis='columns')
        #print(df_level1.head(10))  # Show the first 10 rows of the DataFrame
    else:
        print("No results returned from the SPARQL query")
        
except Exception as e:
    print(f"An error occurred: {str(e)}")

df_level1  # Uncomment for a better reading of the table
# Out:
# Before executing SPARQL query
# After executing SPARQL query
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x49a7c8a90>
#                               artistic_motif level1_label  \
# 0     https://w3id.org/icon/data/ART1331-AM1        woman
# 1     https://w3id.org/icon/data/ART1331-AM2        woman
# 2     https://w3id.org/icon/data/ART1331-AM3   sitting on
# 3     https://w3id.org/icon/data/ART1331-AM4     fountain
# 4     https://w3id.org/icon/data/ART1331-AM5        cross
# ...                                      ...          ...
# 1082  https://w3id.org/icon/data/ART1308-AM2        wings
# 1083  https://w3id.org/icon/data/ART1308-AM3     fighting
# 1084  https://w3id.org/icon/data/ART1308-AM4        putto
# 1085  https://w3id.org/icon/data/ART1308-AM5        wings
# 1086  https://w3id.org/icon/data/ART1308-AM6  palm branch
#
#                                  artwork           start_date
# 0     https://w3id.org/icon/data/ART1331  1400-01-01T00:00:00
# 1     https://w3id.org/icon/data/ART1331  1400-01-01T00:00:00
# 2     https://w3id.org/icon/data/ART1331  1400-01-01T00:00:00
# 3     https://w3id.org/icon/data/ART1331  1400-01-01T00:00:00
# 4     https://w3id.org/icon/data/ART1331  1400-01-01T00:00:00
# ...                                  ...                  ...
# 1082  https://w3id.org/icon/data/ART1308  1584-01-01T00:00:00
# 1083  https://w3id.org/icon/data/ART1308  1584-01-01T00:00:00
# 1084  https://w3id.org/icon/data/ART1308  1584-01-01T00:00:00
# 1085  https://w3id.org/icon/data/ART1308  1584-01-01T00:00:00
# 1086  https://w3id.org/icon/data/ART1308  1584-01-01T00:00:00
#
# [1087 rows x 4 columns]

# %%
# Check if DataFrame exists and has data
if not df_level1.empty:
    # Get the top 20 value counts of 'level1_label'
    top_level1_labels = df_level1['level1_label'].value_counts().head(20)

    # Plotting the horizontal bar chart
    plt.figure(figsize=(10, 8))
    top_level1_labels.sort_values().plot(kind='barh', color='skyblue')

    # Add background grid
    plt.grid(axis='x', linestyle='--', alpha=0.7)  # Add grid lines on the x-axis
    
    # Customize the plot
    plt.xlabel('Count')
    plt.ylabel('Level 1 Label')
    plt.title('Top 20 Level 1 Labels from 1400 to 1600')
    plt.show()
else:
    print("DataFrame is empty or doesn't exist.")

# %%
# Check if DataFrame exists and has data
if not df_level1.empty:
    # Get the top 10 value counts of 'level1_label'
    top_10_labels = df_level1['level1_label'].value_counts().head(10).index

    # Filter the DataFrame for the top 10 labels
    top_10_data = df_level1[df_level1['level1_label'].isin(top_10_labels)].copy()

    # Convert 'start_year' to numeric for proper sorting using .loc
    top_10_data['start_year'] = top_10_data['start_date'].str[:4].astype(int)

    # Group by 'level1_label' and 'start_year' and sum the counts
    grouped_by_decade = top_10_data.groupby(['level1_label', 'start_year']).size().reset_index(name='count')

    # Create a DataFrame with all possible combinations of labels and years
    all_labels = df_level1['level1_label'].unique()
    all_years = range(top_10_data['start_year'].min(), top_10_data['start_year'].max() + 1)

    label_year_combinations = pd.MultiIndex.from_product([all_labels, all_years], names=['level1_label', 'start_year'])
    full_data = pd.DataFrame(index=label_year_combinations).reset_index()

    # Merge with existing grouped data to fill missing values with 0
    merged_data = pd.merge(full_data, grouped_by_decade, how='left', on=['level1_label', 'start_year']).fillna(0)

    # Plotting for each top label
    plt.figure(figsize=(12, 8))

    for label in top_10_labels:
        label_data = merged_data[merged_data['level1_label'] == label]
        plt.plot(label_data['start_year'], label_data['count'], label=label)

    plt.title('Evolution of Top 10 Level 1 Labels Over Time (Aggregated by Decade)')
    plt.xlabel('Decade')
    plt.ylabel('Count')
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print("DataFrame is empty or doesn't exist.")

# %% [markdown]
# Before digging in the level two of Recognition, the Iconographical one, we need to introduce the concept of ***Invenzione**.
# As the authors of the *ICON ontology* states in the paper [ICON: An Ontology for Comprehensive Artistic Interpretations](https://dl.acm.org/doi/10.1145/3594724):
#
# The focus centers on Panofsky's second level of art interpretation, known as the iconographical interpretation. Within this level, interpreters recognize images and "invenzioni" within an artwork. An image represents a subject depicted in a specific artwork, linked to second-level subjects such as characters, places, events, named objects, symbols, and personifications, encapsulating iconographies from an abstract perspective. This distinction is crucial: the general subject level (e.g., characters, symbols) differs from the artwork-specific one (image). This differentiation aids in identifying subject variants concerning specific contexts; for instance, Thor depicted in a particular painting may differ from common portrayals.
#
# An "invenzione" signifies the subject matter formed by combining general subjects linked to individual recognized images. Consider an artwork where three images are identified: the first symbolizes the general subject of Mary, the second symbolizes the general subject of Angel Gabriel, and the third symbolizes the general subject of the Holy Dove. The amalgamation of Mary, Angel Gabriel, and the Holy Dove constitutes the Annunciation—an "invenzione" in ontology terms. While the same "invenzione" could exist across multiple artworks, each artwork maintains uniqueness by possessing distinct images.
#
# Subclasses like Story and Allegory are part of the Invenzione class. Stories are inclined towards characters, named objects, places, and events, whereas allegories focus more on symbols and personifications. Symbols can be expressed solely as symbolic meanings recognized or in more depth as Simulations.
#
# The classes Image and Invenzione are connected to the class IconographicalRecognition through recognizedImage and recognizedInvenzione properties (one image or invenzione per recognition). Artistic motifs belonging to a pre-iconographical level are linked to an image through the property refersToArtisticMotif (e.g., an image representing Mary Magdalene linked to the artistic motif signifying woman). This linkage preserves the connection between pre-iconographical elements and respective iconographical subjects.
#
# If an artistic motif primarily enables image recognition, it can be linked to that image using the hasRecAttribute property. Images are linked to the portrayed general subjects through specific properties based on the subject class (e.g., hasCharacter, hasEvent, hasPlace, hasNamedObject, hasSymbol, hasPersonification). The cited ICON classes encompass both real and fictional subjects (e.g., Medusa) in fictional representational spaces, in line with the modeling of subjects in narratology.
#
# Finally, multiple iconographic recognitions contributing to an artwork's interpretation are linked to the interpretation through the iconographicallyCompliesWith property.

# %% [markdown]
# **Let's find out how many images are represented**

# %%
# Define the SPARQL query
query = """		
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT ?image ?level2Label ?artwork ?startDate
WHERE {
    VALUES ?rel {icon:hasCharacter icon:hasEvent icon:hasNamedObject icon:hasPlace icon:hasPersonification icon:hasSymbol crm:P138_represents}
    # ?production a crm:E12_Production ;
                crm:P108_has_produced ?producedObject ;
                crm:P4_has_time_span ?timeSpan .
    # ?timeSpan crm:P82a_begin_of_the_begin ?startDate .

    # String transformation in order to perform the same query also on the online endpoint
    BIND (xsd:integer(SUBSTR(?startDate, 1, 4)) AS ?startYear) .
    FILTER (?startYear >= 1400 && ?startYear <= 1600)
  
    # ?producedObject crm:P65_shows_visual_item ?artwork .

    # ?iconRecognition a icon:IconographicalRecognition ;
                     icon:aboutWorkOfArt ?artwork ;
                     icon:recognizedImage ?image .

    # ?image a icon:Image ;
           # ?rel ?level2 .
    # ?level2 rdfs:label ?level2Label.
} ORDER BY ?startDate
"""

try:
    # Execute the query and retrieve the results
    print("Before executing SPARQL query")
    results = iconology_graph.query(query)
    print("After executing SPARQL query")
    
    print(results)
        
    # Check if results exist
    if results:
        df_level2_image = pd.DataFrame(results)
        df_level2_image = df_level2_image.set_axis(['image', 'level2_label', 'artwork', 'start_date'], axis='columns')
        #print(df_level2_image.head(10))  # Show the first 10 rows of the DataFrame
    else:
        print("No results returned from the SPARQL query")
        
except Exception as e:
    print(f"An error occurred: {str(e)}")

df_level2_image.info()
df_level2_image
# Out:
# Before executing SPARQL query
# After executing SPARQL query
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x198f32010>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   image         406 non-null    object
#  1   level2_label  406 non-null    object
#  2   artwork       406 non-null    object
#  3   start_date    406 non-null    object
# dtypes: object(4)
# memory usage: 12.8+ KB
#                                            image  \
# 0        https://w3id.org/icon/data/ART1331-IMG3
# 1        https://w3id.org/icon/data/ART1331-IMG2
# 2        https://w3id.org/icon/data/ART1331-IMG1
# 3    https://w3id.org/icon/data/ART1004test-IMG3
# 4    https://w3id.org/icon/data/ART1004test-IMG1
# ..                                           ...
# 401      https://w3id.org/icon/data/ART1322-IMG1
# 402      https://w3id.org/icon/data/ART1389-IMG3
# 403      https://w3id.org/icon/data/ART1389-IMG2
# 404      https://w3id.org/icon/data/ART1308-IMG1
# 405      https://w3id.org/icon/data/ART1308-IMG2
#
#                                           level2_label  \
# 0                                     Fountain of Life
# 1                                                Grace
# 2                                               Nature
# 3                                           Proserpina
# 4                                             Cerberus
# ..                                                 ...
# 401                                      Platonic love
# 402  Draped Ganymede raped by the eagle, so that he...
# 403                                      Ganymede-Mind
# 404                                              Cupid
# 405                                            Anteros
#
#                                     artwork           start_date
# 0        https://w3id.org/icon/data/ART1331  1400-01-01T00:00:00
# 1        https://w3id.org/icon/data/ART1331  1400-01-01T00:00:00
# 2        https://w3id.org/icon/data/ART1331  1400-01-01T00:00:00
# 3    https://w3id.org/icon/data/ART1004test  1401-01-01T00:00:00
# 4    https://w3id.org/icon/data/ART1004test  1401-01-01T00:00:00
# ..                                      ...                  ...
# 401      https://w3id.org/icon/data/ART1322  1574-01-01T00:00:00
# 402      https://w3id.org/icon/data/ART1389  1574-01-01T00:00:00
# 403      https://w3id.org/icon/data/ART1389  1574-01-01T00:00:00
# 404      https://w3id.org/icon/data/ART1308  1584-01-01T00:00:00
# 405      https://w3id.org/icon/data/ART1308  1584-01-01T00:00:00
#
# [406 rows x 4 columns]

# %%
# Check if DataFrame exists and has data
if not df_level2_image.empty:
    # Get the top 20 value counts of 'level1_label'
    top_level2_image_labels = df_level2_image['level2_label'].value_counts().head(20)

    # Plotting the horizontal bar chart
    plt.figure(figsize=(10, 8))
    top_level2_image_labels.sort_values().plot(kind='barh', color='skyblue')

    # Add background grid
    plt.grid(axis='x', linestyle='--', alpha=0.7)  # Add grid lines on the x-axis
    
    # Customize the plot
    plt.xlabel('Count')
    plt.ylabel('Level 2 Label')
    plt.title('Top 20 Level 2 Labels from 1400 to 1600')
    plt.show()
else:
    print("DataFrame is empty or doesn't exist.")

# %%
# Check if DataFrame exists and has data
if not df_level2_image.empty:
    # Get the top 10 value counts of 'level2_label'
    top_10_labels = df_level2_image['level2_label'].value_counts().head(10).index

    # Filter the DataFrame for the top 10 labels
    top_10_data = df_level2_image[df_level2_image['level2_label'].isin(top_10_labels)].copy()

    # Convert 'start_year' to numeric for proper sorting using .loc
    top_10_data['start_year'] = top_10_data['start_date'].str[:4].astype(int)

    # Group by 'level2_label' and 'start_year' and sum the counts
    grouped_by_decade = top_10_data.groupby(['level2_label', 'start_year']).size().reset_index(name='count')

    # Create a DataFrame with all possible combinations of labels and years
    all_labels = df_level2_image['level2_label'].unique()
    all_years = range(top_10_data['start_year'].min(), top_10_data['start_year'].max() + 1)

    label_year_combinations = pd.MultiIndex.from_product([all_labels, all_years], names=['level2_label', 'start_year'])
    full_data = pd.DataFrame(index=label_year_combinations).reset_index()

    # Merge with existing grouped data to fill missing values with 0
    merged_data = pd.merge(full_data, grouped_by_decade, how='left', on=['level2_label', 'start_year']).fillna(0)

    # Plotting for each top label
    plt.figure(figsize=(12, 8))

    for label in top_10_labels:
        label_data = merged_data[merged_data['level2_label'] == label]
        plt.plot(label_data['start_year'], label_data['count'], label=label)

    plt.title('Evolution of Top 10 Level 2 Labels Over Time (Aggregated by Decade)')
    plt.xlabel('Decade')
    plt.ylabel('Count')
    plt.legend()
    plt.grid(True)
    plt.show()
else:
    print("DataFrame is empty or doesn't exist.")

# %% [markdown]
# On this basis let's also see **how many different "invenzione" are in the timespan 1400-1600**.

# %%
# Define the SPARQL query
query = """		
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>

SELECT ?invenzione ?invenzioneLabel ?artwork ?startDate
WHERE {
    # ?production a crm:E12_Production ;
                crm:P108_has_produced ?producedObject ;
                crm:P4_has_time_span ?timeSpan .
    # ?timeSpan crm:P82a_begin_of_the_begin ?startDate .

    BIND (xsd:integer(SUBSTR(?startDate, 1, 4)) AS ?startYear) .
    FILTER (?startYear >= 1400 && ?startYear <= 1600)
  
    # ?producedObject crm:P65_shows_visual_item ?artwork .

    # ?iconRecognition a icon:IconographicalRecognition ;
                     icon:aboutWorkOfArt ?artwork ;
                     icon:recognizedInvenzione ?invenzione .

    # ?invenzione rdfs:label ?invenzioneLabel .         
} ORDER BY ?startDate
"""

try:
    # Execute the query and retrieve the results
    print("Before executing SPARQL query")
    results = iconology_graph.query(query)
    print("After executing SPARQL query")
    
    print(results)
        
    # Check if results exist
    if results:
        df_level2_invenzione = pd.DataFrame(results)
        df_level2_invenzione = df_level2_invenzione.set_axis(['invenzione', 'invenzioneLabel', 'artwork', 'start_date'], axis='columns')
        #print(df_level2_invenzione.head(10))  # Show the first 10 rows of the DataFrame
    else:
        print("No results returned from the SPARQL query")
        
except Exception as e:
    print(f"An error occurred: {str(e)}")

df_level2_invenzione.info()
df_level2_invenzione  # Uncomment for a better reading of the table
# Out:
# Before executing SPARQL query
# After executing SPARQL query
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x48b167cd0>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   invenzione       33 non-null     object
#  1   invenzioneLabel  33 non-null     object
#  2   artwork          33 non-null     object
#  3   start_date       33 non-null     object
# dtypes: object(4)
# memory usage: 1.2+ KB
#                                            invenzione  \
# 0   https://w3id.org/icon/data/story/the-rape-of-p...
# 1   https://w3id.org/icon/data/story/immaculate-co...
# 2   https://w3id.org/icon/data/story/the-annunciation
# 3   https://w3id.org/icon/data/story/hermes-aglaur...
# 4   https://w3id.org/icon/data/allegory/allegorica...
# 5   https://w3id.org/icon/data/story/the-annunciation
# 6   https://w3id.org/icon/data/story/immaculate-co...
# 7   https://w3id.org/icon/data/story/the-vision-of...
# 8   https://w3id.org/icon/data/story/abduction-of-...
# 9   https://w3id.org/icon/data/story/pygmalion-fal...
# 10  https://w3id.org/icon/data/inv/the-realm-of-th...
# 11  https://w3id.org/icon/data/inv/the-advent-of-t...
# 12  https://w3id.org/icon/data/inv/the-advent-of-t...
# 13    https://w3id.org/icon/data/story/birth-of-venus
# 14  https://w3id.org/icon/data/story/the-nymphs-he...
# 15  https://w3id.org/icon/data/story/the-calumny-o...
# 16  https://w3id.org/icon/data/story/the-abduction...
# 17  https://w3id.org/icon/data/story/bacchus-disco...
# 18  https://w3id.org/icon/data/allegory/human-life...
# 19  https://w3id.org/icon/data/story/perseus-and-m...
# 20  https://w3id.org/icon/data/story/saturn-devour...
# 21  https://w3id.org/icon/data/story/jupiter-rapes...
# 22  https://w3id.org/icon/data/story/story-of-tity...
# 23  https://w3id.org/icon/data/allegory/allegory-o...
# 24  https://w3id.org/icon/data/allegory/conflict-b...
# 25  https://w3id.org/icon/data/allegory/conflict-b...
# 26         https://w3id.org/icon/data/allegory/luxury
# 27  https://w3id.org/icon/data/story/the-descent-i...
# 28  https://w3id.org/icon/data/story/hermes-aglaur...
# 29  https://w3id.org/icon/data/allegory/the-choice...
# 30  https://w3id.org/icon/data/allegory/the-choice...
# 31  https://w3id.org/icon/data/story/story-of-quos...
# 32  https://w3id.org/icon/data/story/eros-and-ante...
#
#                                       invenzioneLabel  \
# 0                              The rape of Proserpina
# 1                               Immaculate Conception
# 2                                    The Annunciation
# 3                          Hermes, Aglauros and Herse
# 4   Allegorical explanation of the The three Grace...
# 5                                    The Annunciation
# 6                               Immaculate Conception
# 7                              The vision of the Magi
# 8                                  Abduction of Helen
# 9   Pygmalion falls in love with the statue he is ...
# 10                     The realm of the Natural Venus
# 11                  The Advent of the Celestial Venus
# 12                  The Advent of the Celestial Venus
# 13                                     Birth of Venus
# 14  The nymphs help Vulcan precipitated from Mount...
# 15                             The Calumny of Apelles
# 16                            The abduction of Europa
# 17                        Bacchus discovers the honey
# 18  Human life on earth with its defeats and victo...
# 19                                 Perseus and Medusa
# 20                      Saturn devouring his children
# 21  Jupiter rapes Ganymede and takes him to the Ol...
# 22  Story of Tityus, whose liver is devoured by a ...
# 23  Allegory of the tortures caused by immoderate ...
# 24                   Conflict between Lust and Reason
# 25                   Conflict between Lust and Reason
# 26                                             Luxury
# 27                             The descent into Limbo
# 28                         Hermes, Aglauros and Herse
# 29  The choice of Beauty between Blind Cupid and C...
# 30  The choice of Beauty between Blind Cupid and C...
# 31                                  Story of Quos Ego
# 32    Eros and Anteros struggling for the palm branch
#
#                                    artwork           start_date
# 0   https://w3id.org/icon/data/ART1004test  1401-01-01T00:00:00
# 1   https://w3id.org/icon/data/ART1008test  1401-01-01T00:00:00
# 2   https://w3id.org/icon/data/ART1008test  1401-01-01T00:00:00
# 3       https://w3id.org/icon/data/ART1315  1401-01-01T00:00:00
# 4       https://w3id.org/icon/data/ART1044  1420-01-01T00:00:00
# 5   https://w3id.org/icon/data/ART1009test  1434-01-01T00:00:00
# 6   https://w3id.org/icon/data/ART1009test  1434-01-01T00:00:00
# 7       https://w3id.org/icon/data/ART1232  1445-01-01T00:00:00
# 8       https://w3id.org/icon/data/ART1193  1460-01-01T00:00:00
# 9       https://w3id.org/icon/data/ART1120  1470-01-01T00:00:00
# 10      https://w3id.org/icon/data/ART1203  1478-01-01T00:00:00
# 11      https://w3id.org/icon/data/ART1202  1480-01-01T00:00:00
# 12      https://w3id.org/icon/data/ART1202  1480-01-01T00:00:00
# 13      https://w3id.org/icon/data/ART1202  1480-01-01T00:00:00
# 14      https://w3id.org/icon/data/ART1195  1485-01-01T00:00:00
# 15      https://w3id.org/icon/data/ART1204  1485-01-01T00:00:00
# 16      https://w3id.org/icon/data/ART1512  1495-01-01T00:00:00
# 17      https://w3id.org/icon/data/ART1197  1498-01-01T00:00:00
# 18      https://w3id.org/icon/data/ART1352  1505-01-01T00:00:00
# 19      https://w3id.org/icon/data/ART1019  1515-01-01T00:00:00
# 20      https://w3id.org/icon/data/ART1268  1526-01-01T00:00:00
# 21      https://w3id.org/icon/data/ART1378  1532-01-01T00:00:00
# 22      https://w3id.org/icon/data/ART1379  1532-01-01T00:00:00
# 23      https://w3id.org/icon/data/ART1379  1532-01-01T00:00:00
# 24      https://w3id.org/icon/data/ART1201  1545-01-01T00:00:00
# 25      https://w3id.org/icon/data/ART1201  1545-01-01T00:00:00
# 26      https://w3id.org/icon/data/ART1288  1546-01-01T00:00:00
# 27      https://w3id.org/icon/data/ART1537  1552-01-01T00:00:00
# 28      https://w3id.org/icon/data/ART1316  1554-01-01T00:00:00
# 29      https://w3id.org/icon/data/ART1339  1560-01-01T00:00:00
# 30      https://w3id.org/icon/data/ART1339  1560-01-01T00:00:00
# 31  https://w3id.org/icon/data/ART1011test  1563-01-01T00:00:00
# 32      https://w3id.org/icon/data/ART1308  1584-01-01T00:00:00

# %%
# Check if DataFrame exists and has data
if not df_level2_invenzione.empty:
    # Get the top 20 value counts of 'level1_label'
    top_level2_invenzione_labels = df_level2_invenzione['invenzioneLabel'].value_counts().head(20)

    # Plotting the horizontal bar chart
    plt.figure(figsize=(10, 8))
    top_level2_invenzione_labels.sort_values().plot(kind='barh', color='skyblue')

    # Add background grid
    plt.grid(axis='x', linestyle='--', alpha=0.7)  # Add grid lines on the x-axis
    
    # Customize the plot
    plt.xlabel('Count')
    plt.ylabel('Level 2 Invenzione Label')
    plt.title('Top 20 Level 2 Invenzione Labels from 1400 to 1600')
    plt.show()
else:
    print("DataFrame is empty or doesn't exist.")

# %% [markdown]
# ## 3.2. Represent Zeri Photo Archive Collection
#
# Using the extensive artwork data from the Zeri Collection dataset merged with Wikidata's geolocation, we'll **plot the distribution of artworks on a map.**

# %%
# Define the SPARQL query
query = """
PREFIX zeri1: <http://www.w3.org/ns/prov-o#>
PREFIX pro: <http://purl.org/spar/pro/>
PREFIX : <http://www.essepuntato.it/2014/03/fentry-abox/>
PREFIX fentry: <http://www.essepuntato.it/2014/03/fentry/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX frbr: <http://purl.org/vocab/frbr/core#>
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX emmedi: <http://purl.org/emmedi/>
PREFIX hico: <http://purl.org/emmedi/hico/>
PREFIX terms: <http://purl.org/dc/terms/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?artwork ?artworkLabel ?artworkTypeLabel (year(xsd:dateTime(?startDate)) AS ?year) ?keeperLabel ?locationLabel
WHERE {

    # ?artwork a fabio:ArtisticWork  ;
             rdfs:label ?artworkLabel ;
             crm:P94i_was_created_by ?creation ;
             fabio:hasManifestation ?manifestation ;
             crm:P2_has_type ?artworkType .
                 
    # ?artworkType rdfs:label ?artworkTypeLabel .
    FILTER(LANG(?artworkTypeLabel) = 'en')
                 
    # ?creation crm:P4_has_time_span ?timeSpan .
    # ?timeSpan ti:hasIntervalStartDate ?startDate .
    
    # ?manifestation frbr:exemplar ?analogItem .
    
    # ?analogItem crm:P50_has_current_keeper ?keeper .
    # ?keeper rdfs:label ?keeperLabel .
    
    # ?keeper crm:P74_has_current_or_former_residence ?location .
    # ?location rdfs:label ?locationLabel .
    
    FILTER(
    xsd:dateTime(?startDate) >= xsd:dateTime("1400-01-01T00:00:00Z") &&
    xsd:dateTime(?startDate) <= xsd:dateTime("1600-12-31T23:59:59Z")
    )

} ORDER BY ?startDate

"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:

        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results, columns=results.vars)

        df = df.set_axis(['artwork','artworkLabel', 'artworkTypeLabel', 'year', 'keeperLabel', 'locationLabel'], axis='columns')
                
        # Modify the regex pattern to drop two capital letters at the end of 'locationLabel' with the last space
        df['locationLabel'] = df['locationLabel'].str.replace(r'\s+[A-Z]{2}$', '', regex=True)

        # Extracting text within quotes from 'artworkTitleLabel' column
        df['artworkLabel'] = df['artworkLabel'].str.extract(r'"([^"]*)"')

    else:
        
        print("No results returned from the SPARQL query")

except Exception as e:
    print("An error occurred:", e)

filtered_df = df.drop_duplicates(['artwork'])

# Reindex the DataFrame to create a continuous index sequence
filtered_df = filtered_df.reset_index(drop=True)

filtered_df.info()
filtered_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15944 entries, 0 to 15943
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artwork           15944 non-null  object
#  1   artworkLabel      15944 non-null  object
#  2   artworkTypeLabel  15944 non-null  object
#  3   year              15944 non-null  object
#  4   keeperLabel       15944 non-null  object
#  5   locationLabel     15944 non-null  object
# dtypes: object(6)
# memory usage: 747.5+ KB
#                                       artwork  \
# 0  https://w3id.org/zericatalog/artwork/29205
# 1  https://w3id.org/zericatalog/artwork/29470
# 2  https://w3id.org/zericatalog/artwork/29471
# 3  https://w3id.org/zericatalog/artwork/29473
# 4  https://w3id.org/zericatalog/artwork/29472
# 5  https://w3id.org/zericatalog/artwork/29489
# 6  https://w3id.org/zericatalog/artwork/29461
# 7  https://w3id.org/zericatalog/artwork/29449
# 8  https://w3id.org/zericatalog/artwork/29448
# 9  https://w3id.org/zericatalog/artwork/29451
#
#                                         artworkLabel artworkTypeLabel  year  \
# 0         Anonimo umbro sec. XV , San Nicola di Bari           fresco  1400
# 1         Anonimo umbro sec. XV , Sant'Antonio Abate           fresco  1400
# 2         Anonimo umbro sec. XV , Sant'Antonio Abate           fresco  1400
# 3                      Anonimo umbro sec. XV , Santi           fresco  1400
# 4  Anonimo umbro sec. XV , Cristo giudice in tron...           fresco  1400
# 5                      Anonimo umbro sec. XV , Santo           fresco  1400
# 6  Anonimo umbro sec. XV , Persona a tre teste co...           fresco  1400
# 7     Anonimo umbro sec. XV , San Giorgio e il drago           fresco  1400
# 8         Anonimo umbro sec. XV , Sant'Antonio Abate           fresco  1400
# 9  Anonimo umbro sec. XV , Testa d'uomo e testa d...    mural drawing  1400
#
#               keeperLabel locationLabel
# 0     Pinacoteca Comunale        Assisi
# 1  Chiesa di S. Francesco         Narni
# 2  Chiesa di S. Francesco         Narni
# 3   Chiesa di S. Agostino         Narni
# 4   Chiesa di S. Agostino         Narni
# 5   Chiesa di S. Agostino         Narni
# 6  Chiesa di S. Francesco         Narni
# 7  Chiesa di S. Francesco         Narni
# 8  Chiesa di S. Francesco         Narni
# 9  Chiesa di S. Francesco         Narni

# %%
# Query all the Italian municipalities and their coordinates from Wikidata

wikidata_sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

wikidata_sparql.setQuery("""
SELECT ?location ?locationLabel ?lat ?long 

WHERE {
  # ?location wdt:P31 wd:Q747074 ;
        p:P625 ?coords_stmt .
  # ?coords_stmt ps:P625 ?coords ;
         psv:P625 [
           wikibase:geoLatitude ?lat ;
           wikibase:geoLongitude ?long ] .
     SERVICE wikibase:label {
     bd:serviceParam wikibase:language "it" .
   }
}
""")

wikidata_sparql.setReturnFormat(JSON)
results = wikidata_sparql.query().convert()

# Extracting the data into a DataFrame
data = []
for result in results['results']['bindings']:
    data.append({
        'location': result['location']['value'],
        'locationLabel': result['locationLabel']['value'],
        'lat': float(result['lat']['value']),
        'long': float(result['long']['value'])
    })

# Create DataFrame from the extracted data
wikidata_location_df = pd.DataFrame(data)

# Display the DataFrame
wikidata_location_df
# Out:
#                                       location         locationLabel  \
# 0         http://www.wikidata.org/entity/Q1449                Genova
# 1         http://www.wikidata.org/entity/Q2759                Urbino
# 2         http://www.wikidata.org/entity/Q1308                  Como
# 3         http://www.wikidata.org/entity/Q3501      Vignola-Falesina
# 4         http://www.wikidata.org/entity/Q6052              Allerona
# ...                                        ...                   ...
# 7857    http://www.wikidata.org/entity/Q496951             Roccamena
# 7858    http://www.wikidata.org/entity/Q498938  Santa Teresa di Riva
# 7859    http://www.wikidata.org/entity/Q500485                Visone
# 7860    http://www.wikidata.org/entity/Q504554                 Tubre
# 7861  http://www.wikidata.org/entity/Q21970572          Castel Ivano
#
#             lat       long
# 0     44.407186   8.933983
# 1     43.725239  12.637200
# 2     45.810250   9.086139
# 3     46.044360  11.277380
# 4     42.816667  11.966667
# ...         ...        ...
# 7857  37.835278  13.155556
# 7858  37.940000  15.362500
# 7859  44.662778   8.501667
# 7860  46.645612  10.464153
# 7861  46.066360  11.523570
#
# [7862 rows x 4 columns]

# %%
# Merge the two DataFrames based on the 'cityLabel' column
artwork_location_merged_df = pd.merge(filtered_df, wikidata_location_df, on='locationLabel', how='left')

# 'how='left'' ensures that all rows from filtered_df are retained
# 'on='locationLabel'' specifies the column to merge on

# Drop rows with NaN in the 'location' column since they are not in Italy
artwork_location_merged_df.dropna(subset=['location'], inplace=True)

# Reset the index
artwork_location_merged_df.reset_index(drop=True, inplace=True)

artwork_location_merged_df.info()

# Display the merged DataFrame
artwork_location_merged_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9504 entries, 0 to 9503
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artwork           9504 non-null   object
#  1   artworkLabel      9504 non-null   object
#  2   artworkTypeLabel  9504 non-null   object
#  3   year              9504 non-null   object
#  4   keeperLabel       9504 non-null   object
#  5   locationLabel     9504 non-null   object
#  6   location          9504 non-null   object
#  7   lat               9504 non-null   float64
#  8   long              9504 non-null   float64
# dtypes: float64(2), object(7)
# memory usage: 668.4+ KB
#                                          artwork  \
# 0     https://w3id.org/zericatalog/artwork/29205
# 1     https://w3id.org/zericatalog/artwork/29470
# 2     https://w3id.org/zericatalog/artwork/29471
# 3     https://w3id.org/zericatalog/artwork/29473
# 4     https://w3id.org/zericatalog/artwork/29472
# ...                                          ...
# 9499  https://w3id.org/zericatalog/artwork/35625
# 9500  https://w3id.org/zericatalog/artwork/47270
# 9501  https://w3id.org/zericatalog/artwork/44745
# 9502  https://w3id.org/zericatalog/artwork/44751
# 9503  https://w3id.org/zericatalog/artwork/33687
#
#                                            artworkLabel artworkTypeLabel  \
# 0            Anonimo umbro sec. XV , San Nicola di Bari           fresco
# 1            Anonimo umbro sec. XV , Sant'Antonio Abate           fresco
# 2            Anonimo umbro sec. XV , Sant'Antonio Abate           fresco
# 3                         Anonimo umbro sec. XV , Santi           fresco
# 4     Anonimo umbro sec. XV , Cristo giudice in tron...           fresco
# ...                                                 ...              ...
# 9499  Tassi Agostino , Predica di san Giovanni Battista         painting
# 9500  Anonimo lombardo sec. XVII , Gesù Bambino dorm...         painting
# 9501                Negretti Jacopo , Peccato originale         painting
# 9502  Negretti Jacopo , Trasporto di Cristo al sepolcro         painting
# 9503  Bellini Filippo , San Girolamo in preghiera ne...         painting
#
#       year                                        keeperLabel locationLabel  \
# 0     1400                                Pinacoteca Comunale        Assisi
# 1     1400                             Chiesa di S. Francesco         Narni
# 2     1400                             Chiesa di S. Francesco         Narni
# 3     1400                              Chiesa di S. Agostino         Narni
# 4     1400                              Chiesa di S. Agostino         Narni
# ...    ...                                                ...           ...
# 9499  1600  Palazzo Pitti, Galleria Palatina e Appartament...       Firenze
# 9500  1600                  Pinacoteca dell'Accademia Carrara       Bergamo
# 9501  1600                               Galleria Pallavicini          Roma
# 9502  1600                               Chiesa del Redentore       Venezia
# 9503  1600                        Chiesa della SS. Annunziata        Ancona
#
#                                    location        lat       long
# 0     http://www.wikidata.org/entity/Q20103  43.070000  12.617500
# 1     http://www.wikidata.org/entity/Q10866  42.516667  12.516667
# 2     http://www.wikidata.org/entity/Q10866  42.516667  12.516667
# 3     http://www.wikidata.org/entity/Q10866  42.516667  12.516667
# 4     http://www.wikidata.org/entity/Q10866  42.516667  12.516667
# ...                                     ...        ...        ...
# 9499   http://www.wikidata.org/entity/Q2044  43.771389  11.254167
# 9500    http://www.wikidata.org/entity/Q628  45.695000   9.670000
# 9501    http://www.wikidata.org/entity/Q220  41.893056  12.482778
# 9502    http://www.wikidata.org/entity/Q641  45.439722  12.331944
# 9503   http://www.wikidata.org/entity/Q3415  43.616667  13.516667
#
# [9504 rows x 9 columns]

# %% [markdown]
# After obtaining the longitude and latitude coordinates of the cities where the considered artworks are housed, we can generate a map displaying clustered locations.

# %%
# Creating the map
artwork_map = folium.Map(basemap=basemaps.CartoDB.Positron, location=[41.872, 12.567], zoom_start=5.5, scrollWheelZoom=False)

# Initialize marker cluster
marker_cluster = MarkerCluster().add_to(artwork_map)

for index, row in artwork_location_merged_df.iterrows():
    # Extract latitude and longitude from each row
    lat = row['lat']
    long = row['long']

    # Create marker location
    marker_location = (lat, long)

    # Create a marker and add it to the cluster
    folium.Marker(marker_location).add_to(marker_cluster)

# Display the map
display(artwork_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6056a065aeb0a1cd882750c64df10c35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6056a065aeb0a1cd882750c64df10c35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6056a065aeb0a1cd882750c64df10c35 = L.map(
#                 &quot;map_6056a065aeb0a1cd882750c64df10c35&quot;,
#                 {
#                     center: [41.872, 12.567],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     basemap: {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;, &quot;html_attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;CartoDB.Positron&quot;, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;url&quot;: &quot;https://{s}.basemaps.cartocdn.com/{variant}/{z}/{x}/{y}{r}.png&quot;, &quot;variant&quot;: &quot;light_all&quot;},
#                     scrollWheelZoom: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dee893dfb059db9775fefd008a9be94d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dee893dfb059db9775fefd008a9be94d.addTo(map_6056a065aeb0a1cd882750c64df10c35);
#
#
#             var marker_cluster_caea73928283e14191e9f842c5a06142 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_c5de3041a886798d3d9e2251e5c97071 = L.marker(
#                 [43.07, 12.6175],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_9ac5108b2f83a343adb27ad7b908ca06 = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_bdee64770b117a6181d30a1ee744d13c = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_45866de32757325315309331397d7f7b = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_b9b3915590c7f4b23b16441eeb159abb = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_d815df0cdabe710ec04177adde4876cc = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_fbb83196560b872c499bc92498482a17 = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_a91d33c287d93845c765e05fcbc1f31f = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_e21f8b750ff83c47fea11c595ad9d5e6 = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_570e209ca1ac9feffe8fbedc5bad4a48 = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_6b50e0bd2b4602b3bc681da77e1eee2f = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_78c7f6b4cb75e7994e51362eaa2343b2 = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_cbc227fc38f00c3e8b871b488cca2540 = L.marker(
#                 [42.516666666667, 12.516666666667],
#                 {}
#             ).addTo(marker_cluster_caea73928283e14191e9f842c5a06142);
#
#
#             var marker_202

# %% [markdown]
# We are currently charting the **artworks contained in the Zeri dataset along a timeline to visualize their distribution across time.** A notable surge appears around the year 1500, indicating an unusual concentration during that period. This spike might be attributed to the assignment or attribution of artworks around that specific time, potentially influencing this numerical peak.

# %%
# Create a DataFrame with all years in the range you're interested in
all_years = pd.DataFrame({'year': range(1400, 1601)})

# Count the number of artworks per year
artwork_counts = merged_df['year'].value_counts().reset_index()
artwork_counts.columns = ['year', 'count']

# Convert 'year' column in 'artwork_counts' DataFrame to int64
artwork_counts['year'] = artwork_counts['year'].astype('int64')

# Merge the 'all_years' DataFrame with 'artwork_counts' DataFrame
merged_df = pd.merge(all_years, artwork_counts, on='year', how='left')
merged_df['count'].fillna(0, inplace=True)

# Plotting the line chart
plt.figure(figsize=(10, 6))
plt.plot(merged_df['year'], merged_df['count'], color='skyblue')

# Add background grid
plt.grid(axis='y', linestyle='--', alpha=0.5)  # Add grid lines on the y-axis
plt.grid(axis='x', linestyle='--', alpha=0.5)  # Add grid lines on the x-axis

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Artwork Count')
plt.title('Artwork Count by Year')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's now examine **the subjects depicted in the artworks cataloged within the Zeri collection.**

# %%
# Define the SPARQL query
query = """
PREFIX zeri1: <http://www.w3.org/ns/prov-o#>
PREFIX pro: <http://purl.org/spar/pro/>
PREFIX : <http://www.essepuntato.it/2014/03/fentry-abox/>
PREFIX fentry: <http://www.essepuntato.it/2014/03/fentry/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX frbr: <http://purl.org/vocab/frbr/core#>
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX emmedi: <http://purl.org/emmedi/>
PREFIX hico: <http://purl.org/emmedi/hico/>
PREFIX terms: <http://purl.org/dc/terms/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?artwork ?artworkLabel ?subjectLabel ?artworkTypeLabel (year(xsd:dateTime(?startDate)) AS ?year)
WHERE {

    # ?artwork a fabio:ArtisticWork  ;
             rdfs:label ?artworkLabel ;
             crm:P94i_was_created_by ?creation ;
             fabio:hasSubjectTerm ?subject ;
             crm:P2_has_type ?artworkType .
                 
    # ?artworkType rdfs:label ?artworkTypeLabel .
    FILTER(LANG(?artworkTypeLabel) = 'en')

    # ?subject rdfs:label ?subjectLabel .
                 
    # ?creation crm:P4_has_time_span ?timeSpan .
    # ?timeSpan ti:hasIntervalStartDate ?startDate .
    
    FILTER(
    xsd:dateTime(?startDate) >= xsd:dateTime("1400-01-01T00:00:00Z") &&
    xsd:dateTime(?startDate) <= xsd:dateTime("1600-12-31T23:59:59Z")
    )

} ORDER BY ?startDate
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:

        # Convert SPARQL results to a pandas DataFrame
        subject_df = pd.DataFrame(results, columns=results.vars)

        subject_df = subject_df.set_axis(['artwork','artworkLabel', 'subjectLabel', 'artworkTypeLabel', 'year'], axis='columns')

    else:
        
        print("No results returned from the SPARQL query")

except Exception as e:
    print("An error occurred:", e)

subject_df = subject_df.drop_duplicates(['artwork'])

# Reindex the DataFrame to create a continuous index sequence
subject_df = subject_df.reset_index(drop=True)

subject_df.info()
subject_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18528 entries, 0 to 18527
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artwork           18528 non-null  object
#  1   artworkLabel      18528 non-null  object
#  2   subjectLabel      18528 non-null  object
#  3   artworkTypeLabel  18528 non-null  object
#  4   year              18528 non-null  object
# dtypes: object(5)
# memory usage: 723.9+ KB
#                                       artwork  \
# 0  https://w3id.org/zericatalog/artwork/29205
# 1  https://w3id.org/zericatalog/artwork/29470
# 2  https://w3id.org/zericatalog/artwork/29471
# 3  https://w3id.org/zericatalog/artwork/29473
# 4  https://w3id.org/zericatalog/artwork/29472
# 5  https://w3id.org/zericatalog/artwork/29489
# 6  https://w3id.org/zericatalog/artwork/29461
# 7  https://w3id.org/zericatalog/artwork/29449
# 8  https://w3id.org/zericatalog/artwork/29448
# 9  https://w3id.org/zericatalog/artwork/29451
#
#                                         artworkLabel  \
# 0  Artwork "Anonimo umbro sec. XV , San Nicola di...
# 1  Artwork "Anonimo umbro sec. XV , Sant'Antonio ...
# 2  Artwork "Anonimo umbro sec. XV , Sant'Antonio ...
# 3  Artwork "Anonimo umbro sec. XV , Santi" , (fra...
# 4  Artwork "Anonimo umbro sec. XV , Cristo giudic...
# 5  Artwork "Anonimo umbro sec. XV , Santo" , (fra...
# 6  Artwork "Anonimo umbro sec. XV , Persona a tre...
# 7  Artwork "Anonimo umbro sec. XV , San Giorgio e...
# 8  Artwork "Anonimo umbro sec. XV , Sant'Antonio ...
# 9  Artwork "Anonimo umbro sec. XV , Testa d'uomo ...
#
#                                         subjectLabel artworkTypeLabel  year
# 0                                 san Nicola di Bari           fresco  1400
# 1                                 Sant'Antonio Abate           fresco  1400
# 2                                 Sant'Antonio Abate           fresco  1400
# 3                                              Santi           fresco  1400
# 4   Cristo giudice in trono e angeli tra sant'Andrea           fresco  1400
# 5                                              Santo           fresco  1400
# 6  Persona a tre teste come simbolo della Trinità...           fresco  1400
# 7                             San Giorgio e il drago           fresco  1400
# 8                                 Sant'Antonio Abate           fresco  1400
# 9                    Testa d'uomo e testa di cavallo    mural drawing  1400

# %% [markdown]
# As the Zeri dataset lacks the three levels of interpretation present in the icon dataset, we resort to string searches, extracting key descriptive terms identified in the Iconology dataset. **Our aim is to quantify the occurrences of these selected terms within the 'subject' descriptions of artworks cataloged in the Zeri dataset.**

# %%
# Count occurrences of 'Cristo' and 'Cupido' in the 'artworkLabel' column
count_cristo = subject_df['subjectLabel'].str.contains('Cristo', case=False).sum()
count_cupido = subject_df['subjectLabel'].str.contains('Cupido', case=False).sum()
count_madonna = subject_df['subjectLabel'].str.contains('Madonna', case=False).sum()
count_madonna_con_bambino = subject_df['subjectLabel'].str.contains('Madonna con Bambino', case=False).sum()
count_venere = subject_df['subjectLabel'].str.contains('Venere', case=False).sum()
count_vulcano = subject_df['subjectLabel'].str.contains('Vulcano', case=False).sum()

print(f"Occurrences of 'Cristo': {count_cristo}")
print(f"Occurrences of 'Cupido': {count_cupido}")
print(f"Occurrences of 'Madonna': {count_madonna}")
print(f"Occurrences of 'Madonna con Bambino': {count_madonna_con_bambino}")
print(f"Occurrences of 'Venere': {count_venere}")
print(f"Occurrences of 'Vulcano': {count_vulcano}")
# Out:
# Occurrences of 'Cristo': 1669
# Occurrences of 'Cupido': 93
# Occurrences of 'Madonna': 3342
# Occurrences of 'Madonna con Bambino': 2886
# Occurrences of 'Venere': 194
# Occurrences of 'Vulcano': 16

# %% [markdown]
# **We observe a shift in thematic trends compared to those identified during our exploration of the Iconology dataset.**
#
# Hence, our approach involves conducting **natural language processing to ascertain the most frequently occurring word within the 'subject' field of artwork descriptions.** To achieve this, we will utilize the NLTK library, excluding common Italian stop-words from our analysis.

# %%
# Setting the stop-words
stop_words = set(stopwords.words('italian'))

# Tokenize the text and count occurrences after removing stop words
word_counts = subject_df['subjectLabel'].str.lower().str.split().explode()
word_counts = word_counts[~word_counts.isin(stop_words)].value_counts()

# Plot the top 20 most common words
top_words = word_counts.head(20)
top_words[::-1].plot(kind='barh', color='skyblue')

plt.grid(axis='x', linestyle='--', alpha=0.5)  # Add grid lines on the x-axis

plt.xlabel('Count')
plt.ylabel('Words')
plt.title('Top 20 Most Common Non-stopwords in Subjects')
plt.show()

# %% [markdown]
# # 4. Refine
#
# This stage involves merging datasets and executing extensive data cleaning procedures. Emphasis is placed on harmonizing information, rectifying inconsistencies, and managing missing data. The primary goal is to create a unified dataset, laying the groundwork for subsequent processes like web visualization.
#
# To begin, **let's examine the various types of artworks within the dataset that contains a larger collection, namely Zeri's dataset.**
#
# ### Zeri Photo Archive Collection

# %%
# Define the SPARQL query
query = """
PREFIX zeri1: <http://www.w3.org/ns/prov-o#>
PREFIX pro: <http://purl.org/spar/pro/>
PREFIX : <http://www.essepuntato.it/2014/03/fentry-abox/>
PREFIX fentry: <http://www.essepuntato.it/2014/03/fentry/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX frbr: <http://purl.org/vocab/frbr/core#>
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX emmedi: <http://purl.org/emmedi/>
PREFIX hico: <http://purl.org/emmedi/hico/>
PREFIX terms: <http://purl.org/dc/terms/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?artwork ?artworkLabel ?artworkTypeLabel ?startDate
WHERE {

    # ?artwork a fabio:ArtisticWork ;
             rdfs:label ?artworkLabel ;
             crm:P94i_was_created_by ?creation ;
             fabio:hasManifestation ?manifestation ;
             crm:P2_has_type ?artworkType .

    # ?artworkType rdfs:label ?artworkTypeLabel .
    FILTER(LANG(?artworkTypeLabel) = 'en')
                 
    # ?creation crm:P4_has_time_span ?timeSpan .
    # ?timeSpan ti:hasIntervalStartDate ?startDate .
 
    FILTER(
    xsd:dateTime(?startDate) >= xsd:dateTime("1400-01-01T00:00:00Z") &&
    xsd:dateTime(?startDate) <= xsd:dateTime("1600-12-31T23:59:59Z")
    )

} ORDER BY ?startDate
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:

        # Convert SPARQL results to a pandas DataFrame
        zeri_artworks_type_df = pd.DataFrame(results, columns=results.vars)

        zeri_artworks_type_df = zeri_artworks_type_df.set_axis(['artwork', 'artworkLabel', 'artworkTypeLabel', 'startDate'], axis='columns')

        # Extracting text within quotes from 'artworkLabel' column
        zeri_artworks_type_df['artworkLabel'] = zeri_artworks_type_df['artworkLabel'].str.extract(r'"([^"]*)"')

except Exception as e:
    print("An error occurred:", e)

zeri_artworks_type_df = zeri_artworks_type_df.drop_duplicates(['artwork'])

# Reindex the DataFrame to create a continuous index sequence
zeri_artworks_type_df = zeri_artworks_type_df.reset_index(drop=True)

zeri_artworks_type_df.info()
zeri_artworks_type_df.head(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17881 entries, 0 to 17880
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artwork           17881 non-null  object
#  1   artworkLabel      17881 non-null  object
#  2   artworkTypeLabel  17881 non-null  object
#  3   startDate         17881 non-null  object
# dtypes: object(4)
# memory usage: 558.9+ KB
#                                        artwork  \
# 0   https://w3id.org/zericatalog/artwork/29205
# 1   https://w3id.org/zericatalog/artwork/29470
# 2   https://w3id.org/zericatalog/artwork/29471
# 3   https://w3id.org/zericatalog/artwork/29473
# 4   https://w3id.org/zericatalog/artwork/29472
# 5   https://w3id.org/zericatalog/artwork/29489
# 6   https://w3id.org/zericatalog/artwork/29461
# 7   https://w3id.org/zericatalog/artwork/29449
# 8   https://w3id.org/zericatalog/artwork/29448
# 9   https://w3id.org/zericatalog/artwork/29451
# 10  https://w3id.org/zericatalog/artwork/29445
# 11  https://w3id.org/zericatalog/artwork/29487
# 12  https://w3id.org/zericatalog/artwork/29452
# 13  https://w3id.org/zericatalog/artwork/29480
# 14  https://w3id.org/zericatalog/artwork/29483
# 15  https://w3id.org/zericatalog/artwork/29454
# 16  https://w3id.org/zericatalog/artwork/29440
# 17  https://w3id.org/zericatalog/artwork/29468
# 18  https://w3id.org/zericatalog/artwork/29441
# 19  https://w3id.org/zericatalog/artwork/29437
# 20  https://w3id.org/zericatalog/artwork/47041
# 21  https://w3id.org/zericatalog/artwork/29003
# 22  https://w3id.org/zericatalog/artwork/29567
# 23  https://w3id.org/zericatalog/artwork/29572
# 24  https://w3id.org/zericatalog/artwork/29566
# 25  https://w3id.org/zericatalog/artwork/29389
# 26  https://w3id.org/zericatalog/artwork/29364
# 27  https://w3id.org/zericatalog/artwork/29370
# 28  https://w3id.org/zericatalog/artwork/29378
# 29  https://w3id.org/zericatalog/artwork/29387
# 30  https://w3id.org/zericatalog/artwork/29392
# 31  https://w3id.org/zericatalog/artwork/29397
# 32  https://w3id.org/zericatalog/artwork/29410
# 33  https://w3id.org/zericatalog/artwork/29418
# 34  https://w3id.org/zericatalog/artwork/29421
# 35  https://w3id.org/zericatalog/artwork/29425
# 36  https://w3id.org/zericatalog/artwork/29362
# 37  https://w3id.org/zericatalog/artwork/29570
# 38  https://w3id.org/zericatalog/artwork/29564
# 39  https://w3id.org/zericatalog/artwork/29565
# 40  https://w3id.org/zericatalog/artwork/29428
# 41  https://w3id.org/zericatalog/artwork/29562
# 42  https://w3id.org/zericatalog/artwork/28735
# 43  https://w3id.org/zericatalog/artwork/28949
# 44  https://w3id.org/zericatalog/artwork/29316
# 45  https://w3id.org/zericatalog/artwork/27878
# 46  https://w3id.org/zericatalog/artwork/27877
# 47  https://w3id.org/zericatalog/artwork/27844
# 48  https://w3id.org/zericatalog/artwork/27879
# 49  https://w3id.org/zericatalog/artwork/35477
#
#                                          artworkLabel artworkTypeLabel  \
# 0          Anonimo umbro sec. XV , San Nicola di Bari           fresco
# 1          Anonimo umbro sec. XV , Sant'Antonio Abate           fresco
# 2          Anonimo umbro sec. XV , Sant'Antonio Abate           fresco
# 3                       Anonimo umbro sec. XV , Santi           fresco
# 4   Anonimo umbro sec. XV , Cristo giudice in tron...           fresco
# 5                       Anonimo umbro sec. XV , Santo           fresco
# 6   Anonimo umbro sec. XV , Persona a tre teste co...           fresco
# 7      Anonimo umbro sec. XV , San Giorgio e il drago           fresco
# 8          Anonimo umbro sec. XV , Sant'Antonio Abate           fresco
# 9   Anonimo umbro sec. XV , Testa d'uomo e testa d...    mural drawing
# 10     Anonimo umbro sec. XV , San Giorgio e il drago           fresco
# 11  Anonimo umbro sec. XV , Santo cavaliere e una ...           fresco
# 12  Anonimo umbro sec. XV , San Bartolomeo, San Gi...           fresco
# 13  Anonimo umbro sec. XV , Sant'Orsola e le compagne           fresco
# 14  Anonimo umbro sec. XV , Sant'Antonio Abate (?)...           fresco
# 15  Anonimo umbro sec. XV , Madonna con Bambino, M...           fresco
# 16          Anonimo umbro sec. XV , Sant'Ugo in trono           fresco
# 17             Anonimo umbro sec. XV , Testa di santo           fresco
# 18    Anonimo umbro sec. XV , Crocifissione di Cristo           fresco
# 19  Anonimo umbro sec. XV , Madonna con Bambino tr...           fresco
# 20  Antonio di Puccio Pisano , Cupido insegna il c...            medal
# 21                  Anonimo umbro sec. XV , Dio Padre          lunette
# 22  Antonio del Massaro , Madonna con Bambino tra ...         painting
# 23  Antonio del Massaro , Madonna con Bambino in t...         painting
# 24  Antonio del Massaro , Madonna con Bambino tra ...         painting
# 25  Antonio del Massaro , Madonna con Bambino in m...         painting
# 26  Antonio del Massaro , Madonna con Bambino in m...         painting
# 27  Antonio del Massaro , Madonna con Bambino in m...         painting
# 28  Antonio del Massaro , Madonna con Bambino in m...         painting
# 29  Antonio del Massaro , Madonna con Bambino in m...         painting
# 30  Antonio del Massaro , Madonna con Bambino in m...         painting
# 31  Antonio del Massaro , Madonna con Bambino in m...         painting
# 32          Antonio del Massaro , Madonna con Bambino         painting
# 33  Antonio del Massaro , Madonna con Bambino in m...         painting
# 34          Antonio del Massaro , Madonna con Bambino         painting
# 35          Antonio del Massaro , Madonna con Bambino         painting
# 36  Antonio del Massaro , Madonna con Bambino in t...         painting
# 37          Antonio del Massaro , Madonna con Bambino         painting
# 38  Antonio del Massaro , Madonna con Bambino tra ...         painting
# 39          Antonio del Massaro , Madonna con Bambino         painting
# 40  Antonio del Massaro , Madonna con Bambino in m...         painting
# 41  Antonio del Massaro , Adorazione del Bambino c...         painting
# 42  Anonimo umbro sec. XV/ XVI , Madonna con Bambi...         painting
# 43        Anonimo umbro sec. XV , Madonna con Bambino         painting
# 44               Antonio del Massaro , San Sebastiano           fresco
# 45    Maestro della Madonna di Liverpool , San Pietro   polyptych wing
# 46  Maestro della Madonna di Liverpool , Santa Cat...   polyptych wing
# 47  Maestro della Madonna di Liverpool , Madonna c...         painting
# 48  Maestro della Madonna di Liverpool , Madonna c...         painting
# 49  Anonimo lombardo sec. XV/ XVI , Visione di san...         painting
#
#                startDate
# 0   1400-01-01T00:00:00Z
# 1   1400-01-01T00:00:00Z
# 2   1400-01-01T00:00:00Z
# 3   1400-01-01T00:00:00Z
# 4   1400-01-01T00:00:00Z
# 5   1400-01-01T00:00:00Z
# 6   1400-01-01T00:00:00Z
# 7   1400-01-01T00:00:00Z
# 8   1400-01-01T00:00:00Z
# 9   1400-01-01T00:00:00Z
# 10  1400-01-01T00:00:00Z
# 11  1400-01-01T00:00:00Z
# 12  1400-01-01T00:00:00Z
# 13  1400-01-01T00:00:00Z
# 14  1400-01-01T00:00:00Z
# 15  1400-01-01T00:00:00Z
# 16  1400-01-01T00:00:00Z
# 17  1400-01-01T00:00:00Z
# 18  1400-01-01T00:00:00Z
# 19  1400-01-01T00:00:00Z
# 20  1444-01-01T00:00:00Z
# 21  1450-01-01T00:00:00Z
# 22  1450-01-01T00:00:00Z
# 23  1450-01-01T00:00:00Z
# 24  1450-01-01T00:00:00Z
# 25  1450-01-01T00:00:00Z
# 26  1450-01-01T00:00:00Z
# 27  1450-01-01T00:00:00Z
# 28  1450-01-01T00:00:00Z
# 29  1450-01-01T00:00:00Z
# 30  1450-01-01T00:00:00Z
# 31  1450-01-01T00:00:00Z
# 32  1450-01-01T00:00:00Z
# 33  1450-01-01T00:00:00Z
# 34  1450-01-01T00:00:00Z
# 35  1450-01-01T00:00:00Z
# 36  1450-01-01T00:00:00Z
# 37  1450-01-01T00:00:00Z
# 38  1450-01-01T00:00:00Z
# 39  1450-01-01T00:00:00Z
# 40  1450-01-01T00:00:00Z
# 41  1450-01-01T00:00:00Z
# 42  1450-01-01T00:00:00Z
# 43  1450-01-01T00:00:00Z
# 44  1450-01-01T00:00:00Z
# 45  1450-01-01T00:00:00Z
# 46  1450-01-01T00:00:00Z
# 47  1450-01-01T00:00:00Z
# 48  1450-01-01T00:00:00Z
# 49  1450-01-01T00:00:00Z

# %% [markdown]
# Now we save the result as JSON

# %%
# Convert DataFrame to list of dictionaries
result = []
for i in range(len(zeri_artworks_type_df['artwork'])):
    entry = {
        "year": int(zeri_artworks_type_df['startDate'][i][:4]),
        "artwork_type": zeri_artworks_type_df['artworkTypeLabel'][i],
        "artwork": zeri_artworks_type_df['artworkLabel'][i]
    }
    result.append(entry)

# Create a directory named '_clean' if it doesn't exist
output_folder = '_clean'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Save fetched results to JSON
output_file_path = os.path.join(output_folder, 'artwork_type.json')
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(result, json_file, ensure_ascii=False, indent=4)

print(f"Artwork type data saved in {output_folder}")
# Out:
# Artwork type data saved in _clean

# %% [markdown]
# **Let's now consolidate the Renaissance artists found in both datasets and combine them into a single dataframe.**
#
# ### Iconology Dataset¶

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/>
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX psv: <http://www.wikidata.org/prop/statement/value/>
PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX wds: <http://www.wikidata.org/entity/statement/>
PREFIX wdv: <http://www.wikidata.org/value/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX p: <http://www.wikidata.org/prop/>
PREFIX ps: <http://www.wikidata.org/prop/statement/>
PREFIX pq: <http://www.wikidata.org/prop/qualifier/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX bd: <http://www.bigdata.com/rdf#>

SELECT ?artist ?artistLabel ?otherInstances
WHERE {
    # ?production crm:P108_has_produced ?object ;
                crm:P14_carried_out_by ?artist .

    # ?object crm:P65_shows_visual_item ?artwork ; 
            crm:P102_has_title ?title ; 
            ^crm:P108_has_produced / crm:P4_has_time_span ?time . 

    # ?time crm:P82a_begin_of_the_begin ?startDate .

    FILTER (xsd:dateTime(?startDate) >= "1400-01-01T00:00:00"^^xsd:dateTime &&
            xsd:dateTime(?startDate) <= "1600-12-31T23:59:59"^^xsd:dateTime)

    # ?artist a crm:E21_Person ;
            rdfs:label ?artistLabel ;
            owl:sameAs ?otherInstances . # We want just artist that has other instances of entity
            
}
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)
    
    if results:

        # Convert SPARQL results to a pandas DataFrame
        icon_artists_df = pd.DataFrame(results, columns=results.vars)

        icon_artists_df = icon_artists_df.set_axis(['artist','artistLabel', 'otherInstances'], axis='columns')

    else:
        
        print("No results returned from the SPARQL query")

except Exception as e:
    print("An error occurred:", e)

icon_artists_df.info()
icon_artists_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   artist          316 non-null    object
#  1   artistLabel     316 non-null    object
#  2   otherInstances  316 non-null    object
# dtypes: object(3)
# memory usage: 7.5+ KB
#                                               artist            artistLabel  \
# 0  https://w3id.org/icon/data/person/andrea-del-c...    Andrea del Castagno
# 1  https://w3id.org/icon/data/person/andrea-del-c...    Andrea del Castagno
# 2  https://w3id.org/icon/data/person/andrea-del-c...    Andrea del Castagno
# 3  https://w3id.org/icon/data/person/apollonio-di...  Apollonio di Giovanni
# 4  https://w3id.org/icon/data/person/apollonio-di...  Apollonio di Giovanni
# 5  https://w3id.org/icon/data/person/apollonio-di...  Apollonio di Giovanni
# 6  https://w3id.org/icon/data/person/cyriacus-of-...     Cyriacus of Ancona
# 7  https://w3id.org/icon/data/person/cyriacus-of-...     Cyriacus of Ancona
# 8  https://w3id.org/icon/data/person/cyriacus-of-...     Cyriacus of Ancona
# 9  https://w3id.org/icon/data/person/cyriacus-of-...     Cyriacus of Ancona
#
#                             otherInstances
# 0            http://viaf.org/viaf/95708912
# 1    http://vocab.getty.edu/ulan/500004603
# 2   http://www.wikidata.org/entity/Q240737
# 3            http://viaf.org/viaf/95798943
# 4    http://vocab.getty.edu/ulan/500019165
# 5  http://www.wikidata.org/entity/Q2858468
# 6           http://viaf.org/viaf/120696433
# 7            http://viaf.org/viaf/95878508
# 8     http://vocab.getty.edu/ulan/00031944
# 9    http://vocab.getty.edu/ulan/500031944

# %% [markdown]
# Next, we will follow the same procedure for the Zeri Dataset and subsequently merge the resultant dataframes to eliminate any duplicates.

# %% [markdown]
# ### Zeri Photo Archive Collection
# As made for artist from Iconology dataset we look know at them present in the Zeri RDF.

# %%
# Define the SPARQL query
query = """
PREFIX zeri1: <http://www.w3.org/ns/prov-o#>
PREFIX pro: <http://purl.org/spar/pro/>
PREFIX : <http://www.essepuntato.it/2014/03/fentry-abox/>
PREFIX fentry: <http://www.essepuntato.it/2014/03/fentry/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX frbr: <http://purl.org/vocab/frbr/core#>
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX emmedi: <http://purl.org/emmedi/>
PREFIX hico: <http://purl.org/emmedi/hico/>
PREFIX terms: <http://purl.org/dc/terms/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?artwork ?artist ?artistLabel
WHERE {
    # ?artwork a fabio:ArtisticWork  ;
             crm:P94i_was_created_by ?creation .

    # ?creation crm:P14_carried_out_by ?artist ;
              crm:P4_has_time_span ?timeSpan .

    # ?artist crm:P131_is_identified_by ?actorAppellation .
            # owl:sameAs ?otherInstances . # We want just artist that has other instances of entity but not working directly connected like this
            
    # ?actorAppellation rdfs:label ?artistLabel .

    # ?timeSpan ti:hasIntervalStartDate ?startDate .

    FILTER(
    xsd:dateTime(?startDate) >= xsd:dateTime("1400-01-01T00:00:00Z") &&
    xsd:dateTime(?startDate) <= xsd:dateTime("1600-12-31T23:59:59Z")
    )

}
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:

        # Convert SPARQL results to a pandas DataFrame
        zeri_artists_no_sameAs_df = pd.DataFrame(results, columns=results.vars)

        zeri_artists_no_sameAs_df = zeri_artists_no_sameAs_df.set_axis(['artwork','artist', 'artistLabel'], axis='columns')

    else:
        
        print("No results returned from the SPARQL query")

except Exception as e:
    
    print("An error occurred:", e)

zeri_artists_no_sameAs_df.info()
zeri_artists_no_sameAs_df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39265 entries, 0 to 39264
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artwork      39265 non-null  object
#  1   artist       39265 non-null  object
#  2   artistLabel  39265 non-null  object
# dtypes: object(3)
# memory usage: 920.4+ KB
#                                        artwork  \
# 0   https://w3id.org/zericatalog/artwork/18157
# 1   https://w3id.org/zericatalog/artwork/18157
# 2   https://w3id.org/zericatalog/artwork/18157
# 3   https://w3id.org/zericatalog/artwork/18156
# 4   https://w3id.org/zericatalog/artwork/18156
# 5   https://w3id.org/zericatalog/artwork/18156
# 6   https://w3id.org/zericatalog/artwork/38287
# 7   https://w3id.org/zericatalog/artwork/38287
# 8   https://w3id.org/zericatalog/artwork/41022
# 9   https://w3id.org/zericatalog/artwork/41022
# 10  https://w3id.org/zericatalog/artwork/46995
# 11  https://w3id.org/zericatalog/artwork/46995
# 12  https://w3id.org/zericatalog/artwork/39199
# 13  https://w3id.org/zericatalog/artwork/39199
# 14  https://w3id.org/zericatalog/artwork/39199
# 15  https://w3id.org/zericatalog/artwork/39201
# 16  https://w3id.org/zericatalog/artwork/39201
# 17  https://w3id.org/zericatalog/artwork/39201
# 18  https://w3id.org/zericatalog/artwork/43635
# 19  https://w3id.org/zericatalog/artwork/43635
#
#                                                artist  \
# 0   https://w3id.org/zericatalog/person/x/vasari-g...
# 1   https://w3id.org/zericatalog/person/x/vasari-g...
# 2   https://w3id.org/zericatalog/person/x/vasari-g...
# 3   https://w3id.org/zericatalog/person/x/vasari-g...
# 4   https://w3id.org/zericatalog/person/x/vasari-g...
# 5   https://w3id.org/zericatalog/person/x/vasari-g...
# 6   https://w3id.org/zericatalog/person/x/anonimo-...
# 7   https://w3id.org/zericatalog/person/x/anonimo-...
# 8   https://w3id.org/zericatalog/person/x/anonimo-...
# 9   https://w3id.org/zericatalog/person/x/anonimo-...
# 10  https://w3id.org/zericatalog/person/x/moroni-g...
# 11  https://w3id.org/zericatalog/person/x/moroni-g...
# 12  https://w3id.org/zericatalog/person/x/piccinel...
# 13  https://w3id.org/zericatalog/person/x/piccinel...
# 14  https://w3id.org/zericatalog/person/x/piccinel...
# 15  https://w3id.org/zericatalog/person/x/piccinel...
# 16  https://w3id.org/zericatalog/person/x/piccinel...
# 17  https://w3id.org/zericatalog/person/x/piccinel...
# 18  https://w3id.org/zericatalog/person/x/robusti-...
# 19  https://w3id.org/zericatalog/person/x/robusti-...
#
#                     artistLabel
# 0                Vasari Giorgio
# 1                Vasari Giorgio
# 2               Vasari, Giorgio
# 3                Vasari Giorgio
# 4                Vasari Giorgio
# 5               Vasari, Giorgio
# 6   Anonimo fiorentino sec. XVI
# 7   Anonimo fiorentino sec. XVI
# 8    Anonimo bolognese sec. XVI
# 9    Anonimo bolognese sec. XVI
# 10       Moroni Giovan Battista
# 11       Moroni Giovan Battista
# 12            Piccinelli Andrea
# 13            Piccinelli Andrea
# 14                  Brescianino
# 15            Piccinelli Andrea
# 16            Piccinelli Andrea
# 17                  Brescianino
# 18               Robusti Jacopo
# 19               Robusti Jacopo

# %% [markdown]
# Given the dataset's structure limitations preventing the identification of other instances of the artist within the same query, our next step involves retrieving all Wikidata (or VIAF) recognitions associated with the artists. Subsequently, we will merge the two dataframes into a unified dataset, eliminating any duplicates.

# %%
# Define the SPARQL query
query = """
    PREFIX zeri1: <http://www.w3.org/ns/prov-o#>
    PREFIX pro: <http://purl.org/spar/pro/>
    PREFIX : <http://www.essepuntato.it/2014/03/fentry-abox/>
    PREFIX fentry: <http://www.essepuntato.it/2014/03/fentry/>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
    PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX frbr: <http://purl.org/vocab/frbr/core#>
    PREFIX prov: <http://www.w3.org/ns/prov#>
    PREFIX fabio: <http://purl.org/spar/fabio/>
    PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
    PREFIX dc: <http://purl.org/dc/elements/1.1/>
    PREFIX emmedi: <http://purl.org/emmedi/>
    PREFIX hico: <http://purl.org/emmedi/hico/>
    PREFIX terms: <http://purl.org/dc/terms/>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

    SELECT DISTINCT ?artist ?artistLabel ?otherInstances
    WHERE {
    
        # ?artist a crm:E21_Person;
                crm:P131_is_identified_by ?actorAppellation ;
                owl:sameAs ?otherInstances . # We want just artist that has other instances of entity
                
        # ?actorAppellation rdfs:label ?artistLabel .
    }
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:

        # Convert SPARQL results to a pandas DataFrame
        zeri_all_artists_df = pd.DataFrame(results, columns=results.vars)

        zeri_all_artists_df = zeri_all_artists_df.set_axis(['artist', 'artistLabel', 'otherInstances'], axis='columns')

    else:
        
        print("No results returned from the SPARQL query")

except Exception as e:
    
    print("An error occurred:", e)

zeri_all_artists_df.info()
zeri_all_artists_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14608 entries, 0 to 14607
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   artist          14608 non-null  object
#  1   artistLabel     14608 non-null  object
#  2   otherInstances  14608 non-null  object
# dtypes: object(3)
# memory usage: 342.5+ KB
#                                               artist  \
# 0  https://w3id.org/zericatalog/person/329/amendo...
# 1  https://w3id.org/zericatalog/person/329/amendo...
# 2  https://w3id.org/zericatalog/person/329/amendo...
# 3  https://w3id.org/zericatalog/person/329/amendo...
# 4  https://w3id.org/zericatalog/person/15844/cast...
# 5  https://w3id.org/zericatalog/person/15844/cast...
# 6  https://w3id.org/zericatalog/person/15844/cast...
# 7  https://w3id.org/zericatalog/person/15844/cast...
# 8  https://w3id.org/zericatalog/person/15844/cast...
# 9  https://w3id.org/zericatalog/person/15844/cast...
#
#                   artistLabel  \
# 0  Amendola Giovanni Battista
# 1  Amendola Giovanni Battista
# 2  Amendola Giovanni Battista
# 3  Amendola Giovanni Battista
# 4       Castello Giambattista
# 5       Castello Giambattista
# 6       Castello Giambattista
# 7       Castello Giambattista
# 8                    Genovese
# 9                    Genovese
#
#                                       otherInstances
# 0                      http://viaf.org/viaf/27021154
# 1              http://vocab.getty.edu/ulan/500081479
# 2            http://www.wikidata.org/entity/Q3766559
# 3  http://dbpedia.org/resource/Giovanni_Battista_...
# 4                      http://viaf.org/viaf/22018619
# 5                      http://viaf.org/viaf/22018619
# 6              http://vocab.getty.edu/ulan/500032810
# 7              http://vocab.getty.edu/ulan/500032810
# 8                      http://viaf.org/viaf/22018619
# 9              http://vocab.getty.edu/ulan/500032810

# %% [markdown]
# The dataframes will be cross-referenced to detect the `owl:sameAs` association connecting to the Wikidata entity. Although this approach might not be the most efficient, it remains one of the feasible alternatives due to the lack of a direct link between the artwork and the artists' profiles in Zeri's dataset.

# %%
# Filter unique artists from zeri_artists_no_sameAs_df
unique_artists_no_sameAs = zeri_artists_no_sameAs_df.drop_duplicates(subset=['artistLabel'])

# Filter unique artists from zeri_all_artists_df that have 'otherInstances' containing wikidata.org
unique_artists_wikidata = zeri_all_artists_df[zeri_all_artists_df['otherInstances'].str.contains('wikidata.org')]

# Drop duplicate rows based on 'artistLabel' column
unique_artists_wikidata = unique_artists_wikidata.drop_duplicates(subset=['artistLabel'])

# Merge the dataframes on the 'artistLabel' column
zeri_artists_df = pd.merge(unique_artists_no_sameAs, unique_artists_wikidata, on='artistLabel', how='inner')

# Filter for rows with non-null 'otherInstances' (Wikidata)
zeri_artists_df = zeri_artists_df[zeri_artists_df['otherInstances'].notnull()]

# Drop the duplicates based on the Wikidata URI
zeri_artists_df.drop_duplicates(subset=['otherInstances'], inplace=True)

# Drop the 'artwork' column
zeri_artists_df.drop(columns=['artwork'], inplace=True)

# Reindex the DataFrame to create a continuous index sequence
zeri_artists_df = zeri_artists_df.reset_index(drop=True)

zeri_artists_df.info()
zeri_artists_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   artist_x        302 non-null    object
#  1   artistLabel     302 non-null    object
#  2   artist_y        302 non-null    object
#  3   otherInstances  302 non-null    object
# dtypes: object(4)
# memory usage: 9.6+ KB
#                                               artist_x          artistLabel  \
# 0    https://w3id.org/zericatalog/person/x/vasari-g...       Vasari Giorgio
# 1    https://w3id.org/zericatalog/person/x/piccinel...    Piccinelli Andrea
# 2    https://w3id.org/zericatalog/person/x/robusti-...       Robusti Jacopo
# 3    https://w3id.org/zericatalog/person/x/bril-mathys          Bril Mathys
# 4    https://w3id.org/zericatalog/person/x/dossi-ba...       Dossi Battista
# ..                                                 ...                  ...
# 297  https://w3id.org/zericatalog/person/x/mazzarop...     Mazzaroppi Marco
# 298  https://w3id.org/zericatalog/person/x/presutti...    Presutti Giuliano
# 299  https://w3id.org/zericatalog/person/x/zelli-co...     Zelli Costantino
# 300  https://w3id.org/zericatalog/person/x/filippi-...       Filippi Cesare
# 301  https://w3id.org/zericatalog/person/x/carli-ra...  Carli Raffaello dei
#
#                                               artist_y  \
# 0    https://w3id.org/zericatalog/person/10244/vasa...
# 1    https://w3id.org/zericatalog/person/8158/picci...
# 2    https://w3id.org/zericatalog/person/8827/robus...
# 3    https://w3id.org/zericatalog/person/14709/bril...
# 4    https://w3id.org/zericatalog/person/4195/dossi...
# ..                                                 ...
# 297  https://w3id.org/zericatalog/person/15350/mazz...
# 298  https://w3id.org/zericatalog/person/8449/presu...
# 299  https://w3id.org/zericatalog/person/13840/zell...
# 300  https://w3id.org/zericatalog/person/4539/filip...
# 301  https://w3id.org/zericatalog/person/2676/carli...
#
#                                otherInstances
# 0      http://www.wikidata.org/entity/Q128027
# 1     http://www.wikidata.org/entity/Q2846393
# 2        http://www.wikidata.org/entity/Q9319
# 3     http://www.wikidata.org/entity/Q1908666
# 4     http://www.wikidata.org/entity/Q2706669
# ..                                        ...
# 297  http://www.wikidata.org/entity/Q16853782
# 298   http://www.wikidata.org/entity/Q3107901
# 299  http://www.wikidata.org/entity/Q21903501
# 300   http://www.wikidata.org/entity/Q5065490
# 301    http://www.wikidata.org/entity/Q954072
#
# [302 rows x 4 columns]

# %% [markdown]
# We amalgamate the results to subsequently extract birth dates, death dates, and places of birth from Wikidata. It's important to highlight that we're executing this process specifically for artists who have an associated Wikidata entity identified in the dataset via the `owl:sameAs` property. The challenge in the previous code lies in the absence of a direct link between the opera and the artist scheda. For instance, in an artwork attributed to Giorgio Vasari, we encounter `crm:P14_carried_out_by <https://w3id.org/zericatalog/person/x/vasari-giorgio>`, while the URI for the artist is `<https://w3id.org/zericatalog/person/10244/vasari-giorgio>`. As it is the opera that holds the date of creation, filtering the artists related to the opera and simultaneously identifying the `owl:sameAs` Wikidata presents a challenge.

# %%
# Concatenate the two dataframes
combined_artist_df = pd.concat([icon_artists_df, zeri_artists_df])

# Extract unique Wikidata URIs from the 'otherInstances' column
unique_wikidata_uris = combined_artist_df[combined_artist_df['otherInstances'].str.contains('wikidata.org/entity/')]['otherInstances'].unique()

# Convert the unique URIs into a set to remove duplicates
unique_wikidata_set = set(unique_wikidata_uris)

# Convert the set back to a list if needed
combined_artists_list = list(unique_wikidata_set)

# Display the unique list of Wikidata URIs
#print(combined_artists_list)
print(len(combined_artists_list))
# Out:
# 328

# %% [markdown]
# In the following code, **we execute a query to the Wikidata endpoint to gather information regarding the artists' birth and death details, their birthplaces, and, if available, their students and mentors.**
#
# Our primary focus centers on artists born in the Italian peninsula during the specific timeframe of 1400-1600.

# %%
# Split the list of artists into smaller chunks to avoid Bad Request
chunk_size = 10 
artists_chunks = [combined_artists_list[i:i + chunk_size] for i in range(0, len(combined_artists_list), chunk_size)]

# Process each chunk separately
all_results = []
for chunk in artists_chunks:
    # Construct a string of artists' URIs from the current chunk
    artists = ' '.join(['wd:' + str(artist_uri.split('/')[-1]) for artist_uri in chunk])

    # SPARQL query to retrieve information for the current chunk of artists from Wikidata
    artist_query = """
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT DISTINCT ?artist ?artistLabel ?birthplace ?birthplaceLabel ?birth_date ?death_date
                (GROUP_CONCAT(DISTINCT ?student; SEPARATOR=", ") AS ?students)
                (GROUP_CONCAT(DISTINCT ?studentLabel; SEPARATOR=", ") AS ?studentsLabel)
                (GROUP_CONCAT(DISTINCT ?master; SEPARATOR=", ") AS ?masters)
                (GROUP_CONCAT(DISTINCT ?masterLabel; SEPARATOR=", ") AS ?mastersLabel)
WHERE {
    VALUES ?artist {""" + artists + """}
    # ?artist wdt:P19 ?birthplace .
    OPTIONAL {
        # ?artist wdt:P802 ?student .
        # ?student rdfs:label ?studentLabel .
        FILTER(LANG(?studentLabel) = 'it')
    }
    OPTIONAL {
        # ?artist wdt:P1066 ?master .
        # ?master rdfs:label ?masterLabel .
        FILTER(LANG(?masterLabel) = 'it')
    }
    OPTIONAL { ?artist wdt:P569 ?birth_date }
    OPTIONAL { ?artist wdt:P570 ?death_date }
    # ?birthplace wdt:P31 wd:Q747074 .  # Filter for artists born in the Italian Peninsula
    SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],it". }
} GROUP BY ?artist ?artistLabel ?birthplace ?birthplaceLabel ?birth_date ?death_date
    """
    
    # Define the Wikidata SPARQL endpoint
    wikidata_endpoint = "https://query.wikidata.org/sparql"
    
    user_agent = 'CoolBot/0.0 (https://example.org/coolbot/; coolbot@example.org)'

    # Set up SPARQLWrapper for Wikidata endpoint
    sparql_wd = SPARQLWrapper(wikidata_endpoint, agent = user_agent)

    sparql_wd.setQuery(artist_query)
    sparql_wd.setReturnFormat(JSON)

    # Get results from Wikidata for the current chunk
    results = sparql_wd.query().convert()
    all_results.extend(results["results"]["bindings"])

# Convert fetched results to JSON
json_artists = json.dumps(all_results, ensure_ascii=False, indent=4).encode('utf-8')

# Create a directory named '_clean' if it doesn't exist
output_folder = '_clean'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Save JSON to a file inside the '_clean' folder
output_file_path = os.path.join(output_folder, 'artists.json')
with open(output_file_path, 'wb') as json_file:
    json_file.write(json_artists)

print(f"Artists data saved in {output_folder}")

# %% [markdown]
# Let's focus on an artwork that is present in both datasets. The objective here is to conduct a comprehensive study on a specific artwork to explore it thoroughly. Throughout this investigation, the challenge of establishing connections between the two datasets became apparent, mainly due to the use of different languages for labeling and the absence of entity recognition tools like Wikidata or similar resources.
#
# **Our goal is to showcase how a unified approach to analyzing a single artwork can significantly enhance our understanding of it.** This research aims to emphasize the importance of aggregating and expanding artwork descriptions. Our primary subject of analysis will be ***'Sacred and Profane Love'*** by ***Titian (Tiziano)***.
#
# ### Iconology Dataset

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/>
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX cito: <http://purl.org/spar/cito/> 
PREFIX dc: <http://purl.org/dc/elements/1.1/> 
PREFIX dct: <http://purl.org/dc/terms/> 
PREFIX foaf1: <http://xmlns.com/foaf/spec/> 
PREFIX ns1: <https://w3id.org/icon/data/relation/> 
PREFIX owl: <http://www.w3.org/2002/07/owl#> 
PREFIX pro: <http://purl.org/spar/pro/> 
PREFIX prov: <http://www.w3.org/ns/prov#> 
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
PREFIX skos: <http://www.w3.org/2004/02/skos/core#> 
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?artwork ?titleLabel ?artistLabel ?startDate ?endDate ?artisticPeriod ?artisticPeriodLabel ?locationLabel ?book ?wikidataEntity ?imageLink
                (GROUP_CONCAT(DISTINCT ?fallWithinLocation; SEPARATOR=", ") AS ?fallWithinLocations)
                (GROUP_CONCAT(DISTINCT ?artistRecognition; SEPARATOR=", ") AS ?artistRecognitions)
WHERE {

    VALUES ?artwork {d:ART1329}
    
    # ?production a crm:E12_Production ;
                crm:P108_has_produced ?object ;
                crm:P10_falls_within ?artisticPeriod ; 
                crm:P14_carried_out_by ?artist ;
                crm:P4_has_time_span ?time .

    # ?artist rdfs:label ?artistLabel .

    # ?artisticPeriod rdfs:label ?artisticPeriodLabel .

    # ?object crm:P102_has_title ?title ;
            crm:P2_has_type ?type ;
            crm:P53_has_former_or_current_location ?location ;
            crm:P67_refers_to ?book ;
            crm:P65_shows_visual_item ?artwork .

    # ?title rdfs:label ?titleLabel .

    # ?location rdfs:label ?locationLabel ;
              crm:P89_falls_within ?fallWithinLocation .

    # ?time crm:P82a_begin_of_the_begin ?startDate .

    OPTIONAL {
        # ?time crm:P82b_end_of_the_end ?endDate .    
    }

    OPTIONAL {
        # ?artist owl:sameAs ?artistRecognition .
    }

    OPTIONAL {
        # ?object owl:sameAs ?wikidataEntity ;
                foaf1:depiction ?imageLink ;
                foaf1:page ?institutionalWebPage .
    }
    
} GROUP BY ?artwork ?titleLabel ?artistLabel ?startDate ?endDate ?artisticPeriod ?artisticPeriodLabel ?locationLabel ?book ?wikidataEntity ?imageLink

"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)
    
    if results:

        # Convert SPARQL results to a pandas DataFrame
        icon_artwork_df = pd.DataFrame(results, columns=results.vars)

        #icon_artwork_df = icon_artwork_df.set_axis(['artist','artistLabel', 'otherInstances'], axis='columns')

    else:
        
        print("No results returned from the SPARQL query")

except Exception as e:
    print("An error occurred:", e)

icon_artwork_df.info()
icon_artwork_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   artwork              1 non-null      object
#  1   titleLabel           1 non-null      object
#  2   artistLabel          1 non-null      object
#  3   startDate            1 non-null      object
#  4   endDate              1 non-null      object
#  5   artisticPeriod       1 non-null      object
#  6   artisticPeriodLabel  1 non-null      object
#  7   locationLabel        1 non-null      object
#  8   book                 1 non-null      object
#  9   wikidataEntity       1 non-null      object
#  10  imageLink            1 non-null      object
#  11  fallWithinLocations  1 non-null      object
#  12  artistRecognitions   1 non-null      object
# dtypes: object(13)
# memory usage: 236.0+ bytes
#                               artwork               titleLabel  \
# 0  https://w3id.org/icon/data/ART1329  Sacred and Profane Love
#
#         artistLabel            startDate              endDate  \
# 0  Tiziano Vecellio  1515-01-01T00:00:00  1515-12-31T23:59:59
#
#                                       artisticPeriod  \
# 0  https://w3id.org/icon/data/period/venetian-hig...
#
#          artisticPeriodLabel            locationLabel  \
# 0  Venetian High Renaissance  Galleria Borghese, Rome
#
#                                      book  \
# 0  http://www.worldcat.org/oclc/265570808
#
#                           wikidataEntity  \
# 0  https://www.wikidata.org/wiki/Q794077
#
#                                            imageLink  \
# 0  https://upload.wikimedia.org/wikipedia/commons...
#
#                                  fallWithinLocations  \
# 0  http://vocab.getty.edu/tgn/1000080, http://voc...
#
#                                   artistRecognitions
# 0  http://viaf.org/viaf/109266837, http://vocab.g...

# %% [markdown]
# The obtained results will be combined with the artwork information present in the other dataset, specifically the Zeri dataset.
#
# **The goal is to offer an example showcasing how a comprehensive dataset can improve our comprehension of an artwork.** Moving forward, let's proceed with retrieving the different levels of recognition associated with the iconography portrayed in the artwork.
#
# We focus now on **the first level of interpretation of the choosen artwork.**

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/>
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX cito: <http://purl.org/spar/cito/> 
PREFIX dc: <http://purl.org/dc/elements/1.1/> 
PREFIX dct: <http://purl.org/dc/terms/> 
PREFIX foaf1: <http://xmlns.com/foaf/spec/> 
PREFIX ns1: <https://w3id.org/icon/data/relation/> 
PREFIX owl: <http://www.w3.org/2002/07/owl#> 
PREFIX pro: <http://purl.org/spar/pro/> 
PREFIX prov: <http://www.w3.org/ns/prov#> 
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
PREFIX skos: <http://www.w3.org/2004/02/skos/core#> 
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?artwork ?element ?elementLabel ?elementRecognition ?artisticMotif ?motifRecognition ?composition ?book ?artHistorianName
                (GROUP_CONCAT(?artHistorianRecognition; SEPARATOR=", ") AS ?artHistorianRecognitions)
                (GROUP_CONCAT(?dulceQuality ; SEPARATOR=", ") AS ?dulceQualities)
                (GROUP_CONCAT(?dulceQualityLabel ; SEPARATOR=", ") AS ?dulceQualitiesLabel)
WHERE {

    VALUES ?artwork {d:ART1329}

    # ?object crm:P67_refers_to ?book ;
            crm:P65_shows_visual_item ?artwork .

    # ?artwork icon:hasRecogniton ?preicoRecognition ;
             icon:preiconographicallyDepicts ?element .

    # ?preicoRecognition a icon:PreiconographicalRecognition ;
                 crm:P14_carried_out_by ?artHistorian ;
                 icon:preiconographicallyCompliesWith ?interpretationDescription ;
                 icon:recognizedArtisticMotif ?artisticMotif .

    # ?artHistorian rdfs:label ?artHistorianName .
    
    # ?artisticMotif icon:isCopiedMotifOf ?motifRecognition .

    # ?element rdfs:label ?elementLabel .

    OPTIONAL {
        # ?artHistorian owl:sameAs ?artHistorianRecognition .
    }
  
  	OPTIONAL {
  		# ?artisticMotif icon:partOf ?composition .
  	}

    OPTIONAL {
        # ?artisticMotif dul:hasQuality ?dulceQuality .
        # ?dulceQuality rdfs:label ?dulceQualitiesLabel .
    }
                   
    OPTIONAL {
        # ?element owl:sameAs ?elementRecognition .
    }       
} GROUP BY ?artwork ?element ?elementLabel ?elementRecognition ?artisticMotif ?motifRecognition ?composition ?book ?artHistorianName 
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)

    print("Query done")
    
    if results:

        # Convert SPARQL results to a pandas DataFrame
        preico_icon_df = pd.DataFrame(results, columns=results.vars)

        preico_icon_df = preico_icon_df.set_axis([
                            'artwork',
                            'element',
                            'elementLabel',
                            'elementRecognition',
                            'artisticMotif',
                            'motifRecognition',
                            'composition',
                            'book',
                            'artHistorianName',
                            'artHistorianRecognitions',
                            'dulceQualities',
                            'dulceQualitiesLabel'
                        ], axis='columns')

    else:
        
        print("No results returned from the SPARQL query")

except Exception as e:
    print("An error occurred:", e)

preico_icon_df.info()
preico_icon_df.head(10)
# Out:
# Query done
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   artwork                   40 non-null     object
#  1   element                   40 non-null     object
#  2   elementLabel              40 non-null     object
#  3   elementRecognition        16 non-null     object
#  4   artisticMotif             40 non-null     object
#  5   motifRecognition          40 non-null     object
#  6   composition               20 non-null     object
#  7   book                      40 non-null     object
#  8   artHistorianName          40 non-null     object
#  9   artHistorianRecognitions  40 non-null     object
#  10  dulceQualities            40 non-null     object
#  11  dulceQualitiesLabel       40 non-null     object
# dtypes: object(12)
# memory usage: 3.9+ KB
#                               artwork  \
# 0  https://w3id.org/icon/data/ART1329
# 1  https://w3id.org/icon/data/ART1329
# 2  https://w3id.org/icon/data/ART1329
# 3  https://w3id.org/icon/data/ART1329
# 4  https://w3id.org/icon/data/ART1329
# 5  https://w3id.org/icon/data/ART1329
# 6  https://w3id.org/icon/data/ART1329
# 7  https://w3id.org/icon/data/ART1329
# 8  https://w3id.org/icon/data/ART1329
# 9  https://w3id.org/icon/data/ART1329
#
#                                              element  \
# 0        https://w3id.org/icon/data/classical-relief
# 1                   https://w3id.org/icon/data/cloth
# 2          https://w3id.org/icon/data/country-church
# 3                   https://w3id.org/icon/data/dress
# 4          https://w3id.org/icon/data/flock-of-sheep
# 5          https://w3id.org/icon/data/fortified-town
# 6                    https://w3id.org/icon/data/hair
# 7                    https://w3id.org/icon/data/hair
# 8                    https://w3id.org/icon/data/hare
# 9  https://w3id.org/icon/data/holding-with-the-le...
#
#                  elementLabel                 elementRecognition  \
# 0            classical relief                               None
# 1                       cloth         https://iconclass.org/47H6
# 2              country church                               None
# 3                       dress       https://iconclass.org/41D211
# 4              flock of sheep                               None
# 5              fortified town                               None
# 6                        hair     https://iconclass.org/31A22621
# 7                        hair     https://iconclass.org/31A22622
# 8                        hare  https://iconclass.org/25F26(HARE)
# 9  holding with the left hand                               None
#
#                             artisticMotif  \
# 0  https://w3id.org/icon/data/ART1329-AM1
# 1  https://w3id.org/icon/data/ART1329-AM1
# 2  https://w3id.org/icon/data/ART1329-AM1
# 3  https://w3id.org/icon/data/ART1329-AM1
# 4  https://w3id.org/icon/data/ART1329-AM1
# 5  https://w3id.org/icon/data/ART1329-AM1
# 6  https://w3id.org/icon/data/ART1329-AM1
# 7  https://w3id.org/icon/data/ART1329-AM1
# 8  https://w3id.org/icon/data/ART1329-AM1
# 9  https://w3id.org/icon/data/ART1329-AM1
#
#                                motifRecognition composition  \
# 0  https://w3id.org/icon/data/ART1329-MOTIFREC2        None
# 1  https://w3id.org/icon/data/ART1329-MOTIFREC2        None
# 2  https://w3id.org/icon/data/ART1329-MOTIFREC2        None
# 3  https://w3id.org/icon/data/ART1329-MOTIFREC2        None
# 4  https://w3id.org/icon/data/ART1329-MOTIFREC2        None
# 5  https://w3id.org/icon/data/ART1329-MOTIFREC2        None
# 6  https://w3id.org/icon/data/ART1329-MOTIFREC2        None
# 7  https://w3id.org/icon/data/ART1329-MOTIFREC2        None
# 8  https://w3id.org/icon/data/ART1329-MOTIFREC2        None
# 9  https://w3id.org/icon/data/ART1329-MOTIFREC2        None
#
#                                      book artHistorianName  \
# 0  http://www.worldcat.org/oclc/265570808   Erwin Panofsky
# 1  http://www.worldcat.org/oclc/265570808   Erwin Panofsky
# 2  http://www.worldcat.org/oclc/265570808   Erwin Panofsky
# 3  http://www.worldcat.org/oclc/265570808   Erwin Panofsky
# 4  http://www.worldcat.org/oclc/265570808   Erwin Panofsky
# 5  http://www.worldcat.org/oclc/265570808   Erwin Panofsky
# 6  http://www.worldcat.org/oclc/265570808   Erwin Panofsky
# 7  http://www.worldcat.org/oclc/265570808   Erwin Panofsky
# 8  http://www.worldcat.org/oclc/265570808   Erwin Panofsky
# 9  http://www.worldcat.org/oclc/265570808   Erwin Panofsky
#
#                             artHistorianRecognitions  \
# 0  http://viaf.org/viaf/76321051, http://viaf.org...
# 1  http://viaf.org/viaf/76321051, http://viaf.org...
# 2  http://viaf.org/viaf/76321051, http://viaf.org...
# 3  http://viaf.org/viaf/76321051, http://viaf.org...
# 4  http://viaf.org/viaf/76321051, http://viaf.org...
# 5  http://viaf.org/viaf/76321051, http://viaf.org...
# 6  http://viaf.org/viaf/76321051, http://viaf.org...
# 7  http://viaf.org/viaf/76321051, http://viaf.org...
# 8  http://viaf.org/viaf/76321051, http://viaf.org...
# 9  http://viaf.org/viaf/76321051, http://viaf.org...
#
#                                       dulceQualities dulceQualitiesLabel
# 0  https://w3id.org/icon/data/quality/beautiful, ...
# 1  https://w3id.org/icon/data/quality/beautiful, ...
# 2  https://w3id.org/icon/data/quality/beautiful, ...
# 3  https://w3id.org/icon/data/quality/beautiful, ...
# 4  https://w3id.org/icon/data/quality/beautiful, ...
# 5  https://w3id.org/icon/data/quality/beautiful, ...
# 6  https://w3id.org/icon/data/quality/beautiful, ...
# 7  https://w3id.org/icon/data/quality/beautiful, ...
# 8  https://w3id.org/icon/data/quality/beautiful, ...
# 9  https://w3id.org/icon/data/quality/beautiful, ...

# %% [markdown]
# We save the JSON of the table and we save it in our `_clean` folder.

# %%
# Convert the DataFrame to a dictionary
json_dict = preico_icon_df.to_dict(orient='records')

# Process the dictionary to format values as needed
for record in json_dict:
    for key, value in record.items():
        # Convert multiple values separated by commas to a list and remove duplicates
        if isinstance(value, str) and ', ' in value:
            value_list = list(set(value.split(', ')))
            record[key] = list(dict.fromkeys(value_list))
        else:
            record[key] = value

# Convert the processed dictionary to JSON with indentation for readability
json_output = json.dumps(json_dict, indent=4, ensure_ascii=False)

# Create a directory named '_clean' if it doesn't exist
output_folder = '_clean'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Save JSON to a file inside the '_clean' folder with UTF-8 encoding
output_file_path = os.path.join(output_folder, 'preico_artwork.json')
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json_file.write(json_output)

print(f"The final pre-iconographical recognition of the artwork is printed in {output_folder}")
# Out:
# The final pre-iconographical recognition of the artwork is printed in _clean

# %% [markdown]
# **Let's now delve into the second level of interpretation, which pertains to the subjects as an extension of the first level interpretation.**

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/>
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX cito: <http://purl.org/spar/cito/> 
PREFIX dc: <http://purl.org/dc/elements/1.1/> 
PREFIX dct: <http://purl.org/dc/terms/> 
PREFIX foaf1: <http://xmlns.com/foaf/spec/> 
PREFIX ns1: <https://w3id.org/icon/data/relation/> 
PREFIX owl: <http://www.w3.org/2002/07/owl#> 
PREFIX pro: <http://purl.org/spar/pro/> 
PREFIX prov: <http://www.w3.org/ns/prov#> 
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
PREFIX skos: <http://www.w3.org/2004/02/skos/core#> 
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT *
WHERE {

    VALUES ?artwork {d:ART1329}

    # ?object crm:P67_refers_to ?book ;
            crm:P65_shows_visual_item ?artwork .

    # ?artwork icon:hasRecogniton ?iconographRecognition ;
             icon:iconographicallyDepicts ?element .

    # ?element a ?elementType .

    # ?iconographRecognition a icon:IconographicalRecognition ;
                           crm:P14_carried_out_by ?artHistorian ;
                           icon:iconographicallyCompliesWith ?interpretationDescription ;
                           icon:recognizedImage ?image .
    
    # ?image a icon:Image ;
           icon:hasSymbol ?symbol ;
           # ?relation ?lev2 .

    # ?lev2 rdfs:label ?lev2Label .

    OPTIONAL {
        # ?symbol sim:hasSimulacrum ?simulacrum
    }
}
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)

    print("Query done")
    
    if results:

        # Convert SPARQL results to a pandas DataFrame
        iconograph_icon_df = pd.DataFrame(results, columns=results.vars)

        #iconograph_icon_df = iconograph_icon_df.set_axis(['artist','artistLabel', 'otherInstances'], axis='columns')

    else:
        
        print("No results returned from the SPARQL query")

except Exception as e:
    print("An error occurred:", e)

iconograph_icon_df.info()
iconograph_icon_df.head(10)
# Out:
# Query done
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   simulacrum                 180 non-null    object
#  1   symbol                     180 non-null    object
#  2   book                       180 non-null    object
#  3   artHistorian               180 non-null    object
#  4   lev2                       180 non-null    object
#  5   artwork                    180 non-null    object
#  6   interpretationDescription  180 non-null    object
#  7   image                      180 non-null    object
#  8   lev2Label                  180 non-null    object
#  9   element                    180 non-null    object
#  10  object                     180 non-null    object
#  11  elementType                180 non-null    object
#  12  iconographRecognition      180 non-null    object
#  13  relation                   180 non-null    object
# dtypes: object(14)
# memory usage: 19.8+ KB
#                          simulacrum  \
# 0  https://w3id.org/icon/data/hares
# 1  https://w3id.org/icon/data/hares
# 2  https://w3id.org/icon/data/hares
# 3  https://w3id.org/icon/data/hares
# 4  https://w3id.org/icon/data/hares
# 5  https://w3id.org/icon/data/hares
# 6  https://w3id.org/icon/data/hares
# 7  https://w3id.org/icon/data/hares
# 8  https://w3id.org/icon/data/hares
# 9  https://w3id.org/icon/data/hares
#
#                                               symbol  \
# 0  https://w3id.org/icon/data/hares-animal-love-f...
# 1  https://w3id.org/icon/data/hares-animal-love-f...
# 2  https://w3id.org/icon/data/hares-animal-love-f...
# 3  https://w3id.org/icon/data/hares-animal-love-f...
# 4  https://w3id.org/icon/data/hares-animal-love-f...
# 5  https://w3id.org/icon/data/hares-animal-love-f...
# 6  https://w3id.org/icon/data/hares-animal-love-f...
# 7  https://w3id.org/icon/data/hares-animal-love-f...
# 8  https://w3id.org/icon/data/hares-animal-love-f...
# 9  https://w3id.org/icon/data/hares-animal-love-f...
#
#                                      book  \
# 0  http://www.worldcat.org/oclc/265570808
# 1  http://www.worldcat.org/oclc/265570808
# 2  http://www.worldcat.org/oclc/265570808
# 3  http://www.worldcat.org/oclc/265570808
# 4  http://www.worldcat.org/oclc/265570808
# 5  http://www.worldcat.org/oclc/265570808
# 6  http://www.worldcat.org/oclc/265570808
# 7  http://www.worldcat.org/oclc/265570808
# 8  http://www.worldcat.org/oclc/265570808
# 9  http://www.worldcat.org/oclc/265570808
#
#                                        artHistorian  \
# 0  https://w3id.org/icon/data/person/erwin-panofsky
# 1  https://w3id.org/icon/data/person/erwin-panofsky
# 2  https://w3id.org/icon/data/person/erwin-panofsky
# 3  https://w3id.org/icon/data/person/erwin-panofsky
# 4  https://w3id.org/icon/data/person/erwin-panofsky
# 5  https://w3id.org/icon/data/person/erwin-panofsky
# 6  https://w3id.org/icon/data/person/erwin-panofsky
# 7  https://w3id.org/icon/data/person/erwin-panofsky
# 8  https://w3id.org/icon/data/person/erwin-panofsky
# 9  https://w3id.org/icon/data/person/erwin-panofsky
#
#                                                 lev2  \
# 0  https://w3id.org/icon/data/hares-animal-love-f...
# 1               https://w3id.org/icon/ontology/Image
# 2  https://w3id.org/icon/data/hares-animal-love-f...
# 3               https://w3id.org/icon/ontology/Image
# 4  https://w3id.org/icon/data/hares-animal-love-f...
# 5               https://w3id.org/icon/ontology/Image
# 6  https://w3id.org/icon/data/hares-animal-love-f...
# 7               https://w3id.org/icon/ontology/Image
# 8  https://w3id.org/icon/data/hares-animal-love-f...
# 9               https://w3id.org/icon/ontology/Image
#
#                               artwork  \
# 0  https://w3id.org/icon/data/ART1329
# 1  https://w3id.org/icon/data/ART1329
# 2  https://w3id.org/icon/data/ART1329
# 3  https://w3id.org/icon/data/ART1329
# 4  https://w3id.org/icon/data/ART1329
# 5  https://w3id.org/icon/data/ART1329
# 6  https://w3id.org/icon/data/ART1329
# 7  https://w3id.org/icon/data/ART1329
# 8  https://w3id.org/icon/data/ART1329
# 9  https://w3id.org/icon/data/ART1329
#
#                  interpretationDescription  \
# 0  https://w3id.org/icon/data/ART1329-DESC
# 1  https://w3id.org/icon/data/ART1329-DESC
# 2  https://w3id.org/icon/data/ART1329-DESC
# 3  https://w3id.org/icon/data/ART1329-DESC
# 4  https://w3id.org/icon/data/ART1329-DESC
# 5  https://w3id.org/icon/data/ART1329-DESC
# 6  https://w3id.org/icon/data/ART1329-DESC
# 7  https://w3id.org/icon/data/ART1329-DESC
# 8  https://w3id.org/icon/data/ART1329-DESC
# 9  https://w3id.org/icon/data/ART1329-DESC
#
#                                       image                     lev2Label  \
# 0  https://w3id.org/icon/data/ART1329-IMG10  hares-animal love, fertility
# 1  https://w3id.org/icon/data/ART1329-IMG10                         Image
# 2  https://w3id.org/icon/data/ART1329-IMG10  hares-animal love, fertility
# 3  https://w3id.org/icon/data/ART1329-IMG10                         Image
# 4  https://w3id.org/icon/data/ART1329-IMG10  hares-animal love, fertility
# 5  https://w3id.org/icon/data/ART1329-IMG10                         Image
# 6  https://w3id.org/icon/data/ART1329-IMG10  hares-animal love, fertility
# 7  https://w3id.org/icon/data/ART1329-IMG10                         Image
# 8  https://w3id.org/icon/data/ART1329-IMG10  hares-animal love, fertility
# 9  https://w3id.org/icon/data/ART1329-IMG10                         Image
#
#                                              element  \
# 0                   https://w3id.org/icon/data/cupid
# 1                   https://w3id.org/icon/data/cupid
# 2                   https://w3id.org/icon/data/cupid
# 3                   https://w3id.org/icon/data/cupid
# 4  https://w3id.org/icon/data/cupid-between-venus...
# 5  https://w3id.org/icon/data/cupid-between-venus...
# 6  https://w3id.org/icon/data/cupid-between-venus...
# 7  https://w3id.org/icon/data/cupid-between-venus...
# 8         https://w3id.org/icon/data/geminae-veneres
# 9         https://w3id.org/icon/data/geminae-veneres
#
#                                object  \
# 0  https://w3id.org/icon/data/OBJ1329
# 1  https://w3id.org/icon/data/OBJ1329
# 2  https://w3id.org/icon/data/OBJ1329
# 3  https://w3id.org/icon/data/OBJ1329
# 4  https://w3id.org/icon/data/OBJ1329
# 5  https://w3id.org/icon/data/OBJ1329
# 6  https://w3id.org/icon/data/OBJ1329
# 7  https://w3id.org/icon/data/OBJ1329
# 8  https://w3id.org/icon/data/OBJ1329
# 9  https://w3id.org/icon/data/OBJ1329
#
#                                        elementType  \
# 0         https://w3id.org/icon/ontology/Character
# 1         https://w3id.org/icon/ontology/Character
# 2  https://w3id.org/simulation/ontology/Simulacrum
# 3  https://w3id.org/simulation/ontology/Simulacrum
# 4            https://w3id.org/icon/ontology/Symbol
# 5            https://w3id.org/icon/ontology/Symbol
# 6  https://w3id.org/simulation/ontology/Simulation
# 7  https://w3id.org/simulation/ontology/Simulation
# 8         https://w3id.org/icon/ontology/Character
# 9         https://w3id.org/icon/ontology/Character
#
#                         iconographRecognition  \
# 0  https://w3id.org/icon/data/ART1329-ICREC10
# 1  https://w3id.org/icon/data/ART1329-ICREC10
# 2  https://w3id.org/icon/data/ART1329-ICREC10
# 3  https://w3id.org/icon/data/ART1329-ICREC10
# 4  https://w3id.org/icon/data/ART1329-ICREC10
# 5  https://w3id.org/icon/data/ART1329-ICREC10
# 6  https://w3id.org/icon/data/ART1329-ICREC10
# 7  https://w3id.org/icon/data/ART1329-ICREC10
# 8  https://w3id.org/icon/data/ART1329-ICREC10
# 9  https://w3id.org/icon/data/ART1329-ICREC10
#
#                                           relation
# 0         https://w3id.org/icon/ontology/hasSymbol
# 1  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2         https://w3id.org/icon/ontology/hasSymbol
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4         https://w3id.org/icon/ontology/hasSymbol
# 5  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 6         https://w3id.org/icon/ontology/hasSymbol
# 7  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 8         https://w3id.org/icon/ontology/hasSymbol
# 9  http://www.w3.org/1999/02/22-rdf-syntax-ns#type

# %% [markdown]
# ### Zeri Photo Archive Collection
#
# We are currently extracting data pertaining to the artwork using the information available in the Zeri RDF. The objective is to merge the two sets of information concerning the same artwork to create a comprehensive description of it.

# %%
# Define the SPARQL query
query = """
PREFIX zeri1: <http://www.w3.org/ns/prov-o#>
PREFIX zeri: <https://w3id.org/zericatalog/>
PREFIX pro: <http://purl.org/spar/pro/>
PREFIX : <http://www.essepuntato.it/2014/03/fentry-abox/>
PREFIX fentry: <http://www.essepuntato.it/2014/03/fentry/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX oaentry: <http://purl.org/emmedi/oaentry/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX frbr: <http://purl.org/vocab/frbr/core#>
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX fabio: <http://purl.org/spar/fabio/>
PREFIX ti: <http://www.ontologydesignpatterns.org/cp/owl/timeinterval.owl#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX emmedi: <http://purl.org/emmedi/>
PREFIX hico: <http://purl.org/emmedi/hico/>
PREFIX terms: <http://purl.org/dc/terms/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?artwork ?artworkTitleLabel ?subjectLabel ?artworkTypeLabel ?startDate ?dimensionType ?dimensionValue
       (GROUP_CONCAT(DISTINCT ?depiction; SEPARATOR=", ") AS ?depictions)

WHERE {

    VALUES ?artwork {<https://w3id.org/zericatalog/artwork/43527>} # the id of the OA Entry is 42011

    # ?oaentry a oaentry:OAEntry ;
             oaentry:describes ?artwork .
        
    # ?artwork a fabio:ArtisticWork  ;
             crm:P102_has_title ?artworkTitle ;
             rdfs:label ?artworkLabel ;
             crm:P94i_was_created_by ?creation ;
             fabio:hasSubjectTerm ?subject ;
             fabio:hasManifestation ?analogManifestation ;
             crm:P2_has_type ?artworkType .

    # ?artworkType rdfs:label ?artworkTypeLabel .
    FILTER(LANG(?artworkTypeLabel) = 'en')

    # ?artworkTitle rdfs:label ?artworkTitleLabel .
    FILTER(LANG(?artworkTitleLabel) = 'en')

    # ?subject rdfs:label ?subjectLabel .
                 
    # ?creation crm:P4_has_time_span ?timeSpan .
    # ?timeSpan ti:hasIntervalStartDate ?startDate .

    # ?analogManifestation crm:P45_consists_of ?material ;
                         crm:P39i_was_measured_by ?measures .

    # ?measures crm:P40_observed_dimension ?dimension .

    # ?dimension crm:P2_has_type ?dimensionType .

    # ?analogManifestation frbr:exemplar ?analogItem .

    # ?analogItem a fabio:AnalogItem ;
                foaf:depiction ?depiction .
    
    OPTIONAL {
        # ?dimension crm:P2_has_type ?dimensionType ;
                   crm:P90_has_value ?dimensionValue ;
                   crm:P91_has_unit ?unit .

    }
        
} GROUP BY ?artwork ?artworkTitleLabel ?subjectLabel ?artworkTypeLabel ?startDate ?dimensionType ?dimensionValue
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = zeri_graph.query(query_obj)

    if results:

        # Convert SPARQL results to a pandas DataFrame
        zeri_artwork_df = pd.DataFrame(results, columns=results.vars)

        zeri_artwork_df = zeri_artwork_df.set_axis([
                                'artwork',
                                'artworkTitleLabel',
                                'subjectLabel',
                                'artworkTypeLabel',
                                'startDate',
                                'dimensionType',
                                'dimensionValue',
                                'depictions'
                            ], axis='columns')

        # Extracting text within quotes from 'artworkTitleLabel' column
        zeri_artwork_df['artworkTitleLabel'] = zeri_artwork_df['artworkTitleLabel'].str.extract(r'"([^"]*)"')

    else:
        
        print("No results returned from the SPARQL query")

except Exception as e:
    
    print("An error occurred:", e)

zeri_artwork_df.head(10)
# Out:
#                                       artwork          artworkTitleLabel  \
# 0  https://w3id.org/zericatalog/artwork/43527  Amor sacro e Amor profano
# 1  https://w3id.org/zericatalog/artwork/43527  Amor sacro e Amor profano
#
#            subjectLabel artworkTypeLabel             startDate  \
# 0  Allegoria dell'Amore         painting  1514-01-01T00:00:00Z
# 1  Allegoria dell'Amore         painting  1514-01-01T00:00:00Z
#
#                          dimensionType dimensionValue  \
# 0  https://w3id.org/zericatalog/height            118
# 1  https://w3id.org/zericatalog/length            279
#
#                                           depictions
# 0  http://catalogo.fondazionezeri.unibo.it/foto/1...
# 1  http://catalogo.fondazionezeri.unibo.it/foto/1...

# %% [markdown]
# As length and height share the same property, the query result will be organized into two rows. However, the code below enables us to create a single row by splitting the values into two separate columns.

# %%
# Filter rows with dimensionType, dimensionValue, and other necessary columns
filtered_zeri_artwork_df = zeri_artwork_df[['artwork', 'artworkTitleLabel', 'subjectLabel', 'artworkTypeLabel', 'startDate', 'dimensionType', 'dimensionValue']]

# Pivot the data to reshape the dataframe
pivoted_zeri_artwork_df = filtered_zeri_artwork_df.pivot(index='artwork', columns='dimensionType', values='dimensionValue').reset_index()

# Merge pivot results back to a single row per artwork
result_zeri_artwork_df = zeri_artwork_df.drop(columns=['dimensionType', 'dimensionValue']).merge(pivoted_zeri_artwork_df, on='artwork')

result_zeri_artwork_df = result_zeri_artwork_df.drop_duplicates()

result_zeri_artwork_df
# Out:
#                                       artwork          artworkTitleLabel  \
# 0  https://w3id.org/zericatalog/artwork/43527  Amor sacro e Amor profano
#
#            subjectLabel artworkTypeLabel             startDate  \
# 0  Allegoria dell'Amore         painting  1514-01-01T00:00:00Z
#
#                                           depictions  \
# 0  http://catalogo.fondazionezeri.unibo.it/foto/1...
#
#   https://w3id.org/zericatalog/height https://w3id.org/zericatalog/length
# 0                                 118                                 279

# %%
# Concatenate the two dataframes horizontally
combined_artwork_df = icon_artwork_df.join(result_zeri_artwork_df, lsuffix='_icon', rsuffix='_zeri')

combined_artwork_df = combined_artwork_df.set_axis([
                            'artwork_icon',
                            'titleLabel_icon',
                            'artistLabel_icon',
                            'startDate_icon',
                            'endDate_icon',
                            'artisticPeriod_icon',
                            'artisticPeriodLabel_icon',
                            'locationLabel_icon',
                            'book_icon',
                            'wikidataEntity_icon',
                            'imageLink_icon',
                            'fallWithinLocations_icon',
                            'artistRecognitions_icon',
                            'artwork_zeri',
                            'artworkTitleLabel_zeri',
                            'subjectLabel_zeri',
                            'artworkTypeLabel_zeri',
                            'startDate_zeri',
                            'depictions_zeri',
                            'height_zeri',
                            'length_zeri',
                        ], axis='columns')

combined_artwork_df.info()
combined_artwork_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   artwork_icon              1 non-null      object
#  1   titleLabel_icon           1 non-null      object
#  2   artistLabel_icon          1 non-null      object
#  3   startDate_icon            1 non-null      object
#  4   endDate_icon              1 non-null      object
#  5   artisticPeriod_icon       1 non-null      object
#  6   artisticPeriodLabel_icon  1 non-null      object
#  7   locationLabel_icon        1 non-null      object
#  8   book_icon                 1 non-null      object
#  9   wikidataEntity_icon       1 non-null      object
#  10  imageLink_icon            1 non-null      object
#  11  fallWithinLocations_icon  1 non-null      object
#  12  artistRecognitions_icon   1 non-null      object
#  13  artwork_zeri              1 non-null      object
#  14  artworkTitleLabel_zeri    1 non-null      object
#  15  subjectLabel_zeri         1 non-null      object
#  16  artworkTypeLabel_zeri     1 non-null      object
#  17  startDate_zeri            1 non-null      object
#  18  depictions_zeri           1 non-null      object
#  19  height_zeri               1 non-null      object
#  20  length_zeri               1 non-null      object
# dtypes: object(21)
# memory usage: 300.0+ bytes
#                          artwork_icon          titleLabel_icon  \
# 0  https://w3id.org/icon/data/ART1329  Sacred and Profane Love
#
#    artistLabel_icon       startDate_icon         endDate_icon  \
# 0  Tiziano Vecellio  1515-01-01T00:00:00  1515-12-31T23:59:59
#
#                                  artisticPeriod_icon  \
# 0  https://w3id.org/icon/data/period/venetian-hig...
#
#     artisticPeriodLabel_icon       locationLabel_icon  \
# 0  Venetian High Renaissance  Galleria Borghese, Rome
#
#                                 book_icon  \
# 0  http://www.worldcat.org/oclc/265570808
#
#                      wikidataEntity_icon  ...  \
# 0  https://www.wikidata.org/wiki/Q794077  ...
#
#                             fallWithinLocations_icon  \
# 0  http://vocab.getty.edu/tgn/1000080, http://voc...
#
#                              artistRecognitions_icon  \
# 0  http://viaf.org/viaf/109266837, http://vocab.g...
#
#                                  artwork_zeri     artworkTitleLabel_zeri  \
# 0  https://w3id.org/zericatalog/artwork/43527  Amor sacro e Amor profano
#
#       subjectLabel_zeri artworkTypeLabel_zeri        startDate_zeri  \
# 0  Allegoria dell'Amore              painting  1514-01-01T00:00:00Z
#
#                                      depictions_zeri height_zeri length_zeri
# 0  http://catalogo.fondazionezeri.unibo.it/foto/1...         118         279
#
# [1 rows x 21 columns]

# %% [markdown]
# Now, we can save the artwork as a JSON object containing properties derived from both datasets. This results in a comprehensive example of an object encapsulating all the retrieved information.

# %%
# Convert the DataFrame to a dictionary
json_dict = combined_artwork_df.to_dict(orient='records')

# Process the dictionary to format values as needed
for record in json_dict:
    for key, value in record.items():
        # Convert multiple values separated by commas to a list and remove duplicates
        if isinstance(value, str) and ',' in value:
            value_list = list(set(value.split(', ')))
            record[key] = list(dict.fromkeys(value_list))
        else:
            record[key] = value

# Convert the processed dictionary to JSON with indentation for readability
json_output = json.dumps(json_dict, indent=4)

# Create a directory named '_clean' if it doesn't exist
output_folder = '_clean'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Save JSON to a file inside the '_clean' folder
output_file_path = os.path.join(output_folder, 'artwork_output.json')
with open(output_file_path, 'w') as json_file:
    json_file.write(json_output)

print(f"The final artwork record is printed in {output_folder}")
# Out:
# The final artwork record is printed in _clean

# %% [markdown]
# ## Exporting JSON Containing Artworks' Locations
#
# We have the capability to export a JSON file containing the precise locations of the artworks housed within Zeri's Archive. To accomplish this, we'll utilize the previously generated `artwork_location_merged_df` dataframe.

# %%
# Convert latitude and longitude to a 'geocode' list
artwork_location_merged_df['geocode'] = artwork_location_merged_df[['lat', 'long']].apply(lambda x: [x['lat'], x['long']], axis=1)

# Convert 'year' column to numeric type
artwork_location_merged_df['year'] = pd.to_numeric(artwork_location_merged_df['year'], errors='coerce')

# Select necessary columns and rename them to match the desired structure
result = artwork_location_merged_df[['geocode', 'artworkLabel', 'year', 'keeperLabel']].rename(columns={'artworkLabel': 'artwork_title', 'keeperLabel': 'keeper'})

# Convert the dataframe to a list of dictionaries
result_json = result.to_dict(orient='records')

# Create a directory named '_clean' if it doesn't exist
output_folder = '_clean'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Save JSON to a file inside the '_clean' folder
output_file_path = os.path.join(output_folder, 'artworks_location.json')
with open(output_file_path, 'w', encoding='utf-8') as json_file:
    json.dump(result_json, json_file, ensure_ascii=False, indent=4)

print(f"The final artworks locations is printed in {output_folder}")
# Out:
# The final artworks locations is printed in _clean

# %% [markdown]
# ## Implementing the Apriori Algorithm on Level 1 Icons using the `preicon_df`.
#
# Our aim is to identify potential co-occurrences among pre-iconographical subjects. To accomplish this, we must generate a customized dataset tailored to meet the specifications of a function designed for computing association rules.
#
# Specifically, we require a list of lists, where each individual list encompasses all subjects depicted within an artwork. This dataset structure will facilitate the analysis necessary for exploring associations among these subjects using the Apriori Algorithm.

# %%
# Initialize a dictionary to store elements by artwork
artwork_elements = {}

# Iterate through the DataFrame and group elements by artwork
for _, row in df_level1.iterrows():
    artwork = row['artwork']  # Get the artwork identifier
    element = str(row['level1_label'])  # Convert the RDFLib term to a string
    if artwork not in artwork_elements:
        # Create a new list if the artwork is not in the dictionary
        artwork_elements[artwork] = [element]
    else:
        # Append the element to the existing list for the artwork
        artwork_elements[artwork].append(element)

# Convert the dictionary values to a list of lists
lists_of_lists = list(artwork_elements.values())

# Display the lists of lists
#print(lists_of_lists)
# Out:
# [['woman', 'woman', 'sitting on', 'fountain', 'cross'], ['man', 'Pluto', 'lending both hands to a woman', 'woman', 'court dress', 'gathering flowers', 'flower', 'lending one hand to a man', 'sitting down', 'Preserpine', 'three dog heads', 'natural landscape', 'armor', 'Cerberus', 'courteous attitude', 'knight', 'cart', 'armor'], ['constellation', 'concentric circle', 'central circle'], ['boy', 'girl', 'book', 'holding a book', 'right hand on the heart', 'looking at', 'smiling', 'man', 'blowing in a tube', 'wings', 'holding a globe', 'globe', 'tube', 'act of blessing', 'scroll', 'cloak', 'looking at', 'smiling'], ['man', 'bathing trunks', 'tree', 'lion', 'scimitar', 'serpent', 'grabbing with one hand', 'constellation'], ['putto', 'wings', 'bow', 'arrow', 'shooting an arrow', 'animal', 'natural landscape', 'mantle'], ['putto', 'shield', 'man', 'appearing in the sky', 'man', 'aguing', 'wings', 'court official', 'lady', 'looking out of a window', 'woman', 'halo', 'clothes', 'veil', 'human figure with animal legs', 'bow', 'attacking', 'arrow', 'shooting an arrow', 'mantle', 'group of figures', 'woman', 'spear'], ['rude branches and twigs', 'seat', 'woman'], ['cleric', 'reading', 'book', 'holding', 'musical instrument'], ['king', 'sitting on', 'throne', 'crown', 'gloomy', 'spade'], ['home interior', 'outdoors'], ['staff', 'playing music', 'cock', 'flying towards', 'merchant', 'tief', 'cutting the purse', 'purse', 'serpent', 'man', 'cutten head', 'eye', 'wings', 'man', 'staff', 'lance', 'sword', 'flute'], ['men in different activities'], ['woman', 'crown', 'woman', 'woman', 'woman', 'water', 'bathing'], ['man', 'pressing with feet', 'bellow'], ['three headed serpent', 'head of a dog', 'head of a wolf', 'head of a lion', 'man', 'crown', 'cithara', 'throne', 'sun'], ['architecture'], ['man', 'sickle', 'cloth'], ['throne', 'mantle', 'holding in her arms', 'child', 'halo', 'holding with a hand', 'grape', 'child', 'halo', 'wings', 'playing music', 'base with strigilated motif', 'musical instrument', 'two-storied superstructure', 'column', 'column', 'column', 'woman', 'halo'], ['man', 'turban', 'sickle', 'grabbing with one hand', 'constellation'], ['boy', 'clothes', 'lilies', 'raising open hands to chest height', 'looking at the sky', 'ecce ancilla d[omi]ni', 'book', 'dove', 'crown', 'beams of light', 'dove flying in the beams of light', 'floor decoration', 'floor decoration', 'church interior', 'wings', 'cloak', 'ave gra[tia] plena', 'indicating the ceiling with the right hand', 'speaking', 'girl'], ['man', 'shield', 'cloak', 'spear', 'backward turning movement', 'hat'], ['man', 'profile standing pose', 'chlamys', 'stretching out the left hand', 'taking', 'stick with two coiled snakes'], ['peasant', 'crutch', 'support oneself with', 'lumberjak', 'prisoner', 'cripple', 'criminal', 'monk', 'man', 'sickle'], ['child', 'appearing', 'hovering in mid-air', 'sky', 'halo of rays'], ['architecture'], ['boy', 'pathos', 'drapery', 'agitated movement', 'victorious', 'natural landscape'], ['classical setting', 'triumphal arch', 'medallion', 'relief representing a profile head', 'inscription', 'figure'], ['man', 'classical setting', 'temple', 'Burgundian dignity', 'relief of putti', 'classical pathos', 'clothes', 'woman', 'clothes', 'taking the arm of the girl', 'looking at each other', 'ELENA RAPITA DA PARIS'], ['man', 'profile standing pose', 'flute', 'cock', 'cutten head', 'chlamys'], ['three headed serpent', 'head of a dog', 'head of a wolf', 'head of a lion', 'man', 'crown', 'bow', 'arrow'], ['woman', 'woman', 'woman'], ['practitioner of la haute couture', 'finishing a dress', 'statue of a woman', 'court dress'], ['boy', 'face', 'thoughtfulness', 'sensuality', 'cameo', 'winged horse', 'charioteer', 'winged horse'], ['man', 'erecting', 'building', 'putting up', 'tree trunk', 'interweaving', 'branch'], ['man', 'cornucopia', 'bunch of grapes', 'holding with a hand', 'lifting one hand'], ['woman', 'man', 'indifference', 'raising the right hand', 'stic ...

# %% [markdown]
# Now that we possess our list of lists containing subjects depicted in artworks, we employ methods from the 'mlxtend' library to calculate frequent itemsets, signifying the common occurrences among these subjects. Utilizing the Apriori algorithm, we generate a table comprising two columns:
#
# 1. **Itemsets**: These represent the co-occurring subject items or independent subjects.
# 2. **Support**: Representing a normalized frequency range between 0 and 1, this column indicates the prevalence or frequency of co-occurrence within the dataset.

# %%
# Apply Apriori algorithm
te = TransactionEncoder()
te_ary = te.fit(lists_of_lists).transform(lists_of_lists)
df = pd.DataFrame(te_ary, columns=te.columns_)

# Set minimum support threshold and find frequent itemsets
min_support = 0.1  # Set your desired support threshold
frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)

# Explore the frequent itemsets to understand co-occurrence patterns
print(frequent_itemsets)
# Analyze the frequent itemsets to understand associations between subjects/iconography
# Out:
#     support        itemsets
# 0  0.122642         (arrow)
# 1  0.122642           (bow)
# 2  0.103774           (boy)
# 3  0.575472           (man)
# 4  0.113208         (putto)
# 5  0.216981         (wings)
# 6  0.320755         (woman)
# 7  0.103774    (bow, arrow)
# 8  0.150943    (man, woman)
# 9  0.103774  (woman, wings)

# %% [markdown]
# The analysis reveals notable patterns:
#
# - Individual Subjects: The most prevalent individual subjects depicted in the artworks include 'man', 'woman', 'wings', 'arrow', 'bow', 'putto', and 'boy'. Among these, 'man' appears to be the most frequently depicted subject, followed by 'woman' and 'wings'.
#
# - Co-occurring Subjects: Certain pairs of subjects show considerable co-occurrence within the artworks, such as 'bow' and 'arrow', 'man' and 'woman', and 'woman' and 'wings'. These associations indicate a tendency for these subjects to be depicted together in the same artworks.
#
# - Interpretation: The identified co-occurrences suggest potential thematic or symbolic connections among these subjects in the context of artworks. For instance, the presence of 'bow' and 'arrow' together or 'woman' and 'wings' might imply specific narratives, themes, or artistic motifs prevalent in these artworks.
#
# - Frequency Insights: The support values, normalized between 0 and 1, indicate the frequency of these co-occurrences within the dataset. Notably, 'man' and 'woman' appear together more frequently than other pairs, followed by 'bow' and 'arrow'.
#
# In conclusion, this analysis provides valuable insights into the prevalent subjects and their co-occurrences within the examined artworks. These identified associations could potentially aid art historians or researchers in exploring and interpreting recurring themes or narratives across these artworks.

# %% [markdown]
# ## Conclusions
#
# In this exploration of artwork datasets, while striving to unravel insights regarding subject recognition, the limitations posed by the inability to seamlessly merge the two inspected datasets hindered a comprehensive response to our initial inquiry. The disparity in the quantity and nature of artworks within the Iconology and Zeri datasets underscored the variance in outcomes when examining subject recognition.
#
# Notably, distinct results emerged from the analyses conducted on the Iconology and Zeri datasets, shedding light on how the diversity and abundance of artworks can influence and shape conclusions drawn from such studies. This divergence in findings accentuates the significance of consolidating diverse datasets and underlines the necessity of a complete RDF description of art.
#
# This investigation emphasized the intrinsic link between data comprehensiveness and the depth of understanding in art history. It highlighted the pivotal role of a comprehensive RDF description of artworks in unlocking new discoveries and making the history of art more intriguing and receptive to novel revelations.
#
# Therefore, this study serves not only as an exploration of subject recognition but also as a testament to the crucial need for holistic and comprehensive datasets in enriching the realm of art historical research. By advocating for a more comprehensive approach to documenting art, it encourages a broader and more nuanced understanding of artistic expression, cultural narratives, and historical context, ultimately fostering a more dynamic and captivating history of art.

# %% [markdown]
# # 5. Interact
#
# Culminating from these discoveries and recognizing the value of this extensive exploration, the intention is to present these findings through a dedicated website. This platform will serve as a repository, showcasing the identified patterns, insights, and correlations gleaned from the diverse datasets. Beyond a mere display, the website aims to act as a blueprint for a more interactive and immersive platform dedicated to the history of art. It aspires to offer a dynamic space, inviting enthusiasts, researchers, and art historians to engage with the rich tapestry of art history, fostering exploration, dialogue, and a deeper appreciation of artistic narratives across diverse cultures and periods.

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/>
PREFIX icon: <https://w3id.org/icon/ontology/>
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX cito: <http://purl.org/spar/cito/> 
PREFIX dc: <http://purl.org/dc/elements/1.1/> 
PREFIX dcat: <http://www.w3.org/ns/dcat#> 
PREFIX dcatapit: <http://dati.gov.it/onto/dcatapit> 
PREFIX dct: <http://purl.org/dc/terms/> 
PREFIX foaf1: <http://xmlns.com/foaf/spec/> 
PREFIX ns1: <https://w3id.org/icon/data/relation/> 
PREFIX owl: <http://www.w3.org/2002/07/owl#> 
PREFIX pro: <http://purl.org/spar/pro/> 
PREFIX prov: <http://www.w3.org/ns/prov#> 
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
PREFIX skos: <http://www.w3.org/2004/02/skos/core#> 
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 

SELECT DISTINCT *
WHERE {
    # ?production a crm:E12_Production ;
                crm:P108_has_produced ?object ;
                crm:P10_falls_within ?artisticPeriod ; 
                crm:P14_carried_out_by ?artist ;
                crm:P4_has_time_span ?time .

    # ?time crm:P82a_begin_of_the_begin ?startDate .

    # ?object rdfs:label ?title ;
            crm:P102_has_title <https://w3id.org/icon/data/title/sacred-and-profane-love> ;
            crm:P2_has_type ?type ;
            crm:P53_has_former_or_current_location ?location ;
            crm:P67_refers_to ?book ;
            crm:P65_shows_visual_item ?artwork ;
            owl:sameAs ?wikidataEntity ;
            foaf1:depiction ?imageLink ;
            foaf1:page ?institutionalWebPage .

    # ?artwork icon:hasRecogniton ?preIconRecognition  ;
             icon:hasRecogniton ?iconographicalRecognition ;
             icon:hasRecogniton ?iconologicalRecognition .
                                
                                
    # ?preIconRecognition a icon:PreiconographicalRecognition ;
                        crm:P14_carried_out_by ?artHistorian ;
                        icon:preiconographicallyCompliesWith ?interpretationDescription ;
                        icon:recognizedArtisticMotif ?artisticMotif .


    # ?iconographicalRecognition a icon:IconographicalRecognition ;
                                crm:P14_carried_out_by ?artHistorian ;
                                icon:iconographicallyCompliesWith ?interpretationDescription;
                                icon:recognizedImage ?image .

    # ?iconologicalRecognition a icon:IconologicalRecognition;
                             icon:iconologicallyCompliesWith ?interpretationDescription ;
                             icon:recognizedIntrinsicMeaning ?intrinsicMeaning .

    # ?intrinsicMeaning  a icon:IntrinsicMeaning ;
                       icon:recognizedCulturalPhenomenon ?culturalPhenomenon .

    # ?culturalPhenomenon a icon:CulturalPhenomenon ;
                        rdfs:label ?culturalPhenomenonLabel ;
                        crm:P2_has_type ?culturalPhenomenonType  .

    # ?artisticMotif a icon:ArtisticMotif ;
                    dul:hasQuality ?quality ;
                    icon:hasFactualMeaning ?depiction .

    # ?image a icon:Image ;
            icon:hasSymbol ?symbol .

    # ?symbol a icon:Symbol ;
            rdfs:label ?symbolLabel ;
            icon:isSymbolOf ?image ;
            sim:hasRealityCounterpart ?realityCounterpart ;
            sim:hasSimulacrum ?similacrum ;
            sim:hasSimulationType ?similacrumType .

    # ?realityCounterpart a sim:RealityCounterpart ;
                        rdfs:label ?realityCounterpartLabel .
}

"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)
    
    if results:


        # Convert SPARQL results to a pandas DataFrame and process the title URIs
        df = pd.DataFrame(results, columns=results.vars)

        #df = df.set_axis(['artwork', 'title', 'typeLabel', 'locationLabel', 'motivatorLabel', 'startDate'], axis='columns')


except Exception as e:
    print("An error occurred:", e)

df.info()
df.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  292 non-null    object
#  1   startDate             292 non-null    object
#  2   artwork               292 non-null    object
#  3   artist                292 non-null    object
#  4   time                  292 non-null    object
#  5   artisticPeriod        292 non-null    object
#  6   object                292 non-null    object
#  7   location              292 non-null    object
#  8   p                     292 non-null    object
#  9   recognition           292 non-null    object
#  10  book                  292 non-null    object
#  11  wikidataEntity        292 non-null    object
#  12  iimageLink            292 non-null    object
#  13  artHistorian          292 non-null    object
#  14  production            292 non-null    object
#  15  institutionalWebPage  292 non-null    object
#  16  title                 292 non-null    object
#  17  o                     292 non-null    object
# dtypes: object(18)
# memory usage: 41.2+ KB
#                                     type            startDate  \
# 0   http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 1   http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 2   http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 3   http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 4   http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 5   http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 6   http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 7   http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 8   http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 9   http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 10  http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 11  http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 12  http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 13  http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 14  http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 15  http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 16  http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 17  http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 18  http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
# 19  http://vocab.getty.edu/aat/300033799  1515-01-01T00:00:00
#
#                                artwork  \
# 0   https://w3id.org/icon/data/ART1329
# 1   https://w3id.org/icon/data/ART1329
# 2   https://w3id.org/icon/data/ART1329
# 3   https://w3id.org/icon/data/ART1329
# 4   https://w3id.org/icon/data/ART1329
# 5   https://w3id.org/icon/data/ART1329
# 6   https://w3id.org/icon/data/ART1329
# 7   https://w3id.org/icon/data/ART1329
# 8   https://w3id.org/icon/data/ART1329
# 9   https://w3id.org/icon/data/ART1329
# 10  https://w3id.org/icon/data/ART1329
# 11  https://w3id.org/icon/data/ART1329
# 12  https://w3id.org/icon/data/ART1329
# 13  https://w3id.org/icon/data/ART1329
# 14  https://w3id.org/icon/data/ART1329
# 15  https://w3id.org/icon/data/ART1329
# 16  https://w3id.org/icon/data/ART1329
# 17  https://w3id.org/icon/data/ART1329
# 18  https://w3id.org/icon/data/ART1329
# 19  https://w3id.org/icon/data/ART1329
#
#                                                artist  \
# 0   https://w3id.org/icon/data/person/tiziano-vece...
# 1   https://w3id.org/icon/data/person/tiziano-vece...
# 2   https://w3id.org/icon/data/person/tiziano-vece...
# 3   https://w3id.org/icon/data/person/tiziano-vece...
# 4   https://w3id.org/icon/data/person/tiziano-vece...
# 5   https://w3id.org/icon/data/person/tiziano-vece...
# 6   https://w3id.org/icon/data/person/tiziano-vece...
# 7   https://w3id.org/icon/data/person/tiziano-vece...
# 8   https://w3id.org/icon/data/person/tiziano-vece...
# 9   https://w3id.org/icon/data/person/tiziano-vece...
# 10  https://w3id.org/icon/data/person/tiziano-vece...
# 11  https://w3id.org/icon/data/person/tiziano-vece...
# 12  https://w3id.org/icon/data/person/tiziano-vece...
# 13  https://w3id.org/icon/data/person/tiziano-vece...
# 14  https://w3id.org/icon/data/person/tiziano-vece...
# 15  https://w3id.org/icon/data/person/tiziano-vece...
# 16  https://w3id.org/icon/data/person/tiziano-vece...
# 17  https://w3id.org/icon/data/person/tiziano-vece...
# 18  https://w3id.org/icon/data/person/tiziano-vece...
# 19  https://w3id.org/icon/data/person/tiziano-vece...
#
#                                time  \
# 0   https://w3id.org/icon/data/1515
# 1   https://w3id.org/icon/data/1515
# 2   https://w3id.org/icon/data/1515
# 3   https://w3id.org/icon/data/1515
# 4   https://w3id.org/icon/data/1515
# 5   https://w3id.org/icon/data/1515
# 6   https://w3id.org/icon/data/1515
# 7   https://w3id.org/icon/data/1515
# 8   https://w3id.org/icon/data/1515
# 9   https://w3id.org/icon/data/1515
# 10  https://w3id.org/icon/data/1515
# 11  https://w3id.org/icon/data/1515
# 12  https://w3id.org/icon/data/1515
# 13  https://w3id.org/icon/data/1515
# 14  https://w3id.org/icon/data/1515
# 15  https://w3id.org/icon/data/1515
# 16  https://w3id.org/icon/data/1515
# 17  https://w3id.org/icon/data/1515
# 18  https://w3id.org/icon/data/1515
# 19  https://w3id.org/icon/data/1515
#
#                                        artisticPeriod  \
# 0   https://w3id.org/icon/data/period/venetian-hig...
# 1   https://w3id.org/icon/data/period/venetian-hig...
# 2   https://w3id.org/icon/data/period/venetian-hig...
# 3   https://w3id.org/icon/data/period/venetian-hig...
# 4   https://w3id.org/icon/data/period/venetian-hig...
# 5   https://w3id.org/icon/data/period/venetian-hig...
# 6   https://w3id.org/icon/data/period/venetian-hig...
# 7   https://w3id.org/icon/data/period/venetian-hig...
# 8   https://w3id.org/icon/data/period/venetian-hig...
# 9   https://w3id.org/icon/data/period/venetian-hig...
# 10  https://w3id.org/icon/data/period/venetian-hig...
# 11  https://w3id.org/icon/data/period/venetian-hig...
# 12  https://w3id.org/icon/data/period/venetian-hig...
# 13  https://w3id.org/icon/data/period/venetian-hig...
# 14  https://w3id.org/icon/data/period/venetian-hig...
# 15  https://w3id.org/icon/data/period/venetian-hig...
# 16  https://w3id.org/icon/data/period/venetian-hig...
# 17  https://w3id.org/icon/data/period/venetian-hig...
# 18  https://w3id.org/icon/data/period/venetian-hig...
# 19  https://w3id.org/icon/data/period/venetian-hig...
#
#                                 object  \
# 0   https://w3id.org/icon/data/OBJ1329
# 1   https://w3id.org/icon/data/OBJ1329
# 2   https://w3id.org/icon/data/OBJ1329
# 3   https://w3id.org/icon/data/OBJ1329
# 4   https://w3id.org/icon/data/OBJ1329
# 5   https://w3id.org/icon/data/OBJ1329
# 6   https://w3id.org/icon/data/OBJ1329
# 7   https://w3id.org/icon/data/OBJ1329
# 8   https://w3id.org/icon/data/OBJ1329
# 9   https://w3id.org/icon/data/OBJ1329
# 10  https://w3id.org/icon/data/OBJ1329
# 11  https://w3id.org/icon/data/OBJ1329
# 12  https://w3id.org/icon/data/OBJ1329
# 13  https://w3id.org/icon/data/OBJ1329
# 14  https://w3id.org/icon/data/OBJ1329
# 15  https://w3id.org/icon/data/OBJ1329
# 16  https://w3id.org/icon/data/OBJ1329
# 17  https://w3id.org/icon/data/OBJ1329
# 18  https://w3id.org/icon/data/OBJ1329
# 19  https://w3id.org/icon/data/OBJ1329
#
#                                              location  \
# 0   https://w3id.org/icon/data/place/rome-galleria...
# 1   https://w3id.org/icon/data/place/rome-galleria...
# 2   https://w3id.org/icon/data/place/rome-galleria...
# 3   https://w3id.org/icon/data/place/rome-galleria...
# 4   https://w3id.org/icon/data/place/rome-galleria...
# 5   https://w3id.org/icon/data/place/rome-galleria...
# 6   https://w3id.org/icon/data/place/rome-galleria...
# 7   https://w3id.org/icon/data/place/rome-galleria...
# 8   https://w3id.org/icon/data/place/rome-galleria...
# 9   https://w3id.org/icon/data/place/rome-galleria...
# 10  https://w3id.org/icon/data/place/rome-galleria...
# 11  https://w3id.org/icon/data/place/rome-galleria...
# 12  https://w3id.org/icon/data/place/rome-galleria...
# 13  https://w3id.org/icon/data/place/rome-galleria...
# 14  https://w3id.org/icon/data/place/rome-galleria...
# 15  https://w3id.org/icon/data/place/rome-galleria...
# 16  https://w3id.org/icon/data/place/rome-galleria...
# 17  https://w3id.org/icon/data/place/rome-galleria...
# 18  https://w3id.org/icon/data/place/rome-galleria...
# 19  https://w3id.org/icon/data/place/rome-galleria...
#
#                                                     p  \
# 0     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1       http://purl.org/spar/cito/citesForInformation
# 2   http://www.cidoc-crm.org/cidoc-crm/P14_carried...
# 3       https://w3id.org/icon/ontology/aboutWorkOfArt
# 4   https://w3id.org/icon/ontology/iconologicallyC...
# 5   https://w3id.org/icon/ontology/recognizedIntri...
# 6     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 7       http://purl.org/spar/cito/citesForInformation
# 8   http://www.cidoc-crm.org/cidoc-crm/P14_carried...
# 9       https://w3id.org/icon/ontology/aboutWorkOfArt
# 10  https://w3id.org/icon/ontology/iconographicall...
# 11     https://w3id.org/icon/ontology/recognizedImage
# 12  https://w3id.org/icon/ontology/refersToArtisti...
# 13    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 14          http://purl.org/spar/cito/citesAsEvidence
# 15          http://purl.org/spar/cito/citesAsEvidence
# 16      http://purl.org/spar/cito/citesForInformation
# 17  http://www.cidoc-crm.org/cidoc-crm/P14_carried...
# 18      https://w3id.org/icon/ontology/aboutWorkOfArt
# 19  https://w3id.org/icon/ontology/iconographicall...
#
#                                       recognition  \
# 0   https://w3id.org/icon/data/ART1329-ICONOLREC1
# 1   https://w3id.org/icon/data/ART1329-ICONOLREC1
# 2   https://w3id.org/icon/data/ART1329-ICONOLREC1
# 3   https://w3id.org/icon/data/ART1329-ICONOLREC1
# 4   https://w3id.org/icon/data/ART1329-ICONOLREC1
# 5   https://w3id.org/icon/data/ART1329-ICONOLREC1
# 6       https://w3id.org/icon/data/ART1329-ICREC1
# 7       https://w3id.org/icon/data/ART1329-ICREC1
# 8       https://w3id.org/icon/data/ART1329-ICREC1
# 9       https://w3id.org/icon/data/ART1329-ICREC1
# 10      https://w3id.org/icon/data/ART1329-ICREC1
# 11      https://w3id.org/icon/data/ART1329-ICREC1
# 12      https://w3id.org/icon/data/ART1329-ICREC1
# 13     https://w3id.org/icon/data/ART1329-ICREC10
# 14     https://w3id.org/icon/data/ART1329-ICREC10
# 15     https://w3id.org/icon/data/ART1329-ICREC10
# 16     https://w3id.org/icon/data/ART1329-ICREC10
# 17     https://w3id.org/icon/data/ART1329-ICREC10
# 18     https://w3id.org/icon/data/ART1329-ICREC10
# 19     https://w3id.org/icon/data/ART1329-ICREC10
#
#                                       book  \
# 0   http://www.worldcat.org/oclc/265570808
# 1   http://www.worldcat.org/oclc/265570808
# 2   http://www.worldcat.org/oclc/265570808
# 3   http://www.worldcat.org/oclc/265570808
# 4   http://www.worldcat.org/oclc/265570808
# 5   http://www.worldcat.org/oclc/265570808
# 6   http://www.worldcat.org/oclc/265570808
# 7   http://www.worldcat.org/oclc/265570808
# 8   http://www.worldcat.org/oclc/265570808
# 9   http://www.worldcat.org/oclc/265570808
# 10  http://www.worldcat.org/oclc/265570808
# 11  http://www.worldcat.org/oclc/265570808
# 12  http://www.worldcat.org/oclc/265570808
# 13  http://www.worldcat.org/oclc/265570808
# 14  http://www.worldcat.org/oclc/265570808
# 15  http://www.worldcat.org/oclc/265570808
# 16  http://www.worldcat.org/oclc/265570808
# 17  http://www.worldcat.org/oclc/265570808
# 18  http://www.worldcat.org/oclc/265570808
# 19  http://www.worldcat.org/oclc/265570808
#
#                            wikidataEntity  \
# 0   https://www.wikidata.org/wiki/Q794077
# 1   https://www.wikidata.org/wiki/Q794077
# 2   https://www.wikidata.org/wiki/Q794077
# 3   https://www.wikidata.org/wiki/Q794077
# 4   https://www.wikidata.org/wiki/Q794077
# 5   https://www.wikidata.org/wiki/Q794077
# 6   https://www.wikidata.org/wiki/Q794077
# 7   https://www.wikidata.org/wiki/Q794077
# 8   https://www.wikidata.org/wiki/Q794077
# 9   https://www.wikidata.org/wiki/Q794077
# 10  https://www.wikidata.org/wiki/Q794077
# 11  https://www.wikidata.org/wiki/Q794077
# 12  https://www.wikidata.org/wiki/Q794077
# 13  https://www.wikidata.org/wiki/Q794077
# 14  https://www.wikidata.org/wiki/Q794077
# 15  https://www.wikidata.org/wiki/Q794077
# 16  https://www.wikidata.org/wiki/Q794077
# 17  https://www.wikidata.org/wiki/Q794077
# 18  https://www.wikidata.org/wiki/Q794077
# 19  https://www.wikidata.org/wiki/Q794077
#
#                                            iimageLink  \
# 0   https://upload.wikimedia.org/wikipedia/commons...
# 1   https://upload.wikimedia.org/wikipedia/commons...
# 2   https://upload.wikimedia.org/wikipedia/commons...
# 3   https://upload.wikimedia.org/wikipedia/commons...
# 4   https://upload.wikimedia.org/wikipedia/commons...
# 5   https://upload.wikimedia.org/wikipedia/commons...
# 6   https://upload.wikimedia.org/wikipedia/commons...
# 7   https://upload.wikimedia.org/wikipedia/commons...
# 8   https://upload.wikimedia.org/wikipedia/commons...
# 9   https://upload.wikimedia.org/wikipedia/commons...
# 10  https://upload.wikimedia.org/wikipedia/commons...
# 11  https://upload.wikimedia.org/wikipedia/commons...
# 12  https://upload.wikimedia.org/wikipedia/commons...
# 13  https://upload.wikimedia.org/wikipedia/commons...
# 14  https://upload.wikimedia.org/wikipedia/commons...
# 15  https://upload.wikimedia.org/wikipedia/commons...
# 16  https://upload.wikimedia.org/wikipedia/commons...
# 17  https://upload.wikimedia.org/wikipedia/commons...
# 18  https://upload.wikimedia.org/wikipedia/commons...
# 19  https://upload.wikimedia.org/wikipedia/commons...
#
#                                         artHistorian  \
# 0   https://w3id.org/icon/data/person/erwin-panofsky
# 1   https://w3id.org/icon/data/person/erwin-panofsky
# 2   https://w3id.org/icon/data/person/erwin-panofsky
# 3   https://w3id.org/icon/data/person/erwin-panofsky
# 4   https://w3id.org/icon/data/person/erwin-panofsky
# 5   https://w3id.org/icon/data/person/erwin-panofsky
# 6   https://w3id.org/icon/data/person/erwin-panofsky
# 7   https://w3id.org/icon/data/person/erwin-panofsky
# 8   https://w3id.org/icon/data/person/erwin-panofsky
# 9   https://w3id.org/icon/data/person/erwin-panofsky
# 10  https://w3id.org/icon/data/person/erwin-panofsky
# 11  https://w3id.org/icon/data/person/erwin-panofsky
# 12  https://w3id.org/icon/data/person/erwin-panofsky
# 13  https://w3id.org/icon/data/person/erwin-panofsky
# 14  https://w3id.org/icon/data/person/erwin-panofsky
# 15  https://w3id.org/icon/data/person/erwin-panofsky
# 16  https://w3id.org/icon/data/person/erwin-panofsky
# 17  https://w3id.org/icon/data/person/erwin-panofsky
# 18  https://w3id.org/icon/data/person/erwin-panofsky
# 19  https://w3id.org/icon/data/person/erwin-panofsky
#
#                              production  \
# 0   https://w3id.org/icon/data/PROD1329
# 1   https://w3id.org/icon/data/PROD1329
# 2   https://w3id.org/icon/data/PROD1329
# 3   https://w3id.org/icon/data/PROD1329
# 4   https://w3id.org/icon/data/PROD1329
# 5   https://w3id.org/icon/data/PROD1329
# 6   https://w3id.org/icon/data/PROD1329
# 7   https://w3id.org/icon/data/PROD1329
# 8   https://w3id.org/icon/data/PROD1329
# 9   https://w3id.org/icon/data/PROD1329
# 10  https://w3id.org/icon/data/PROD1329
# 11  https://w3id.org/icon/data/PROD1329
# 12  https://w3id.org/icon/data/PROD1329
# 13  https://w3id.org/icon/data/PROD1329
# 14  https://w3id.org/icon/data/PROD1329
# 15  https://w3id.org/icon/data/PROD1329
# 16  https://w3id.org/icon/data/PROD1329
# 17  https://w3id.org/icon/data/PROD1329
# 18  https://w3id.org/icon/data/PROD1329
# 19  https://w3id.org/icon/data/PROD1329
#
#                                  institutionalWebPage  \
# 0   https://galleriaborghese.beniculturali.it/oper...
# 1   https://galleriaborghese.beniculturali.it/oper...
# 2   https://galleriaborghese.beniculturali.it/oper...
# 3   https://galleriaborghese.beniculturali.it/oper...
# 4   https://galleriaborghese.beniculturali.it/oper...
# 5   https://galleriaborghese.beniculturali.it/oper...
# 6   https://galleriaborghese.beniculturali.it/oper...
# 7   https://galleriaborghese.beniculturali.it/oper...
# 8   https://galleriaborghese.beniculturali.it/oper...
# 9   https://galleriaborghese.beniculturali.it/oper...
# 10  https://galleriaborghese.beniculturali.it/oper...
# 11  https://galleriaborghese.beniculturali.it/oper...
# 12  https://galleriaborghese.beniculturali.it/oper...
# 13  https://galleriaborghese.beniculturali.it/oper...
# 14  https://galleriaborghese.beniculturali.it/oper...
# 15  https://galleriaborghese.beniculturali.it/oper...
# 16  https://galleriaborghese.beniculturali.it/oper...
# 17  https://galleriaborghese.beniculturali.it/oper...
# 18  https://galleriaborghese.beniculturali.it/oper...
# 19  https://galleriaborghese.beniculturali.it/oper...
#
#                                                 title  \
# 0   Tiziano Vecellio, Sacred and Profane Love, 151...
# 1   Tiziano Vecellio, Sacred and Profane Love, 151...
# 2   Tiziano Vecellio, Sacred and Profane Love, 151...
# 3   Tiziano Vecellio, Sacred and Profane Love, 151...
# 4   Tiziano Vecellio, Sacred and Profane Love, 151...
# 5   Tiziano Vecellio, Sacred and Profane Love, 151...
# 6   Tiziano Vecellio, Sacred and Profane Love, 151...
# 7   Tiziano Vecellio, Sacred and Profane Love, 151...
# 8   Tiziano Vecellio, Sacred and Profane Love, 151...
# 9   Tiziano Vecellio, Sacred and Profane Love, 151...
# 10  Tiziano Vecellio, Sacred and Profane Love, 151...
# 11  Tiziano Vecellio, Sacred and Profane Love, 151...
# 12  Tiziano Vecellio, Sacred and Profane Love, 151...
# 13  Tiziano Vecellio, Sacred and Profane Love, 151...
# 14  Tiziano Vecellio, Sacred and Profane Love, 151...
# 15  Tiziano Vecellio, Sacred and Profane Love, 151...
# 16  Tiziano Vecellio, Sacred and Profane Love, 151...
# 17  Tiziano Vecellio, Sacred and Profane Love, 151...
# 18  Tiziano Vecellio, Sacred and Profane Love, 151...
# 19  Tiziano Vecellio, Sacred and Profane Love, 151...
#
#                                                     o
# 0   https://w3id.org/icon/ontology/IconologicalRec...
# 1              http://www.worldcat.org/oclc/265570808
# 2    https://w3id.org/icon/data/person/erwin-panofsky
# 3                  https://w3id.org/icon/data/ART1329
# 4             https://w3id.org/icon/data/ART1329-DESC
# 5       https://w3id.org/icon/data/ART1329-INTRINSIC1
# 6   https://w3id.org/icon/ontology/IconographicalR...
# 7              http://www.worldcat.org/oclc/265570808
# 8    https://w3id.org/icon/data/person/erwin-panofsky
# 9                  https://w3id.org/icon/data/ART1329
# 10            https://w3id.org/icon/data/ART1329-DESC
# 11            https://w3id.org/icon/data/ART1329-IMG1
# 12           https://w3id.org/icon/data/ART1329-COMP4
# 13  https://w3id.org/icon/ontology/IconographicalR...
# 14        https://w3id.org/icon/data/1151bibl-content
# 15  https://w3id.org/icon/data/1151bibl-content-fe...
# 16             http://www.worldcat.org/oclc/265570808
# 17   https://w3id.org/icon/data/person/erwin-panofsky
# 18                 https://w3id.org/icon/data/ART1329
# 19            https://w3id.org/icon/data/ART1329-DESC

# %% [markdown]
# Let's try to look to **the former or current location of the arteork between 1400 and 1600**

# %%
# Define the SPARQL query
query = """
    PREFIX d: <https://w3id.org/icon/data/> 
    PREFIX icon: <https://w3id.org/icon/ontology/> 
    PREFIX sim: <https://w3id.org/simulation/ontology/>
    PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
    PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
    
    SELECT DISTINCT ?artwork ?title ?locationLabel ?geoRegion ?startDate
    WHERE {
        # ?object crm:P65_shows_visual_item ?artwork ; 
                crm:P102_has_title ?title ; 
                ^crm:P108_has_produced / crm:P4_has_time_span ?time ;
                crm:P53_has_former_or_current_location ?location .

        # ?location rdfs:label ?locationLabel ;
                  crm:P89_falls_within ?geoRegion .

        # ?time crm:P82a_begin_of_the_begin ?startDate ; 
              crm:P82b_end_of_the_end ?endDate .

    FILTER (xsd:dateTime(?startDate) >= "1400-01-01T00:00:00"^^xsd:dateTime &&
                xsd:dateTime(?startDate) <= "1600-12-31T23:59:59"^^xsd:dateTime)
    }
    ORDER BY ?startDate
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)
    
    if results:
        # Retrieve the count of distinct artworks within the specified time span
        count_artworks = sum(1 for _ in results)
        
        if count_artworks > 0:
            print(f"Number of artworks within the period 1400-16000 with place specified: {count_artworks}")
        else:
            print("No artwork within the period 1400-16000 with place specified")

        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results, columns=results.vars)

except Exception as e:
    print("An error occurred:", e)

df.info()
df
# Out:
# Number of artworks within the Italian Renaissance period: 107
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   artwork        107 non-null    object
#  1   title          107 non-null    object
#  2   locationLabel  107 non-null    object
#  3   geoRegion      107 non-null    object
#  4   startDate      107 non-null    object
# dtypes: object(5)
# memory usage: 4.3+ KB
#                                    artwork  \
# 0    https://w3id.org/icon/data/ART1202ext
# 1    https://w3id.org/icon/data/ART1202ext
# 2       https://w3id.org/icon/data/ART1331
# 3       https://w3id.org/icon/data/ART1331
# 4       https://w3id.org/icon/data/ART1184
# ..                                     ...
# 102     https://w3id.org/icon/data/ART1220
# 103     https://w3id.org/icon/data/ART1220
# 104     https://w3id.org/icon/data/ART1380
# 105     https://w3id.org/icon/data/ART1380
# 106     https://w3id.org/icon/data/ART1072
#
#                                                  title  \
# 0    https://w3id.org/icon/data/title/the-medal-of-...
# 1    https://w3id.org/icon/data/title/the-medal-of-...
# 2    https://w3id.org/icon/data/title/nature-and-grace
# 3    https://w3id.org/icon/data/title/nature-and-grace
# 4    https://w3id.org/icon/data/title/annunciation-...
# ..                                                 ...
# 102            https://w3id.org/icon/data/title/summer
# 103            https://w3id.org/icon/data/title/summer
# 104            https://w3id.org/icon/data/title/tityus
# 105            https://w3id.org/icon/data/title/tityus
# 106          https://w3id.org/icon/data/title/s-andrea
#
#                         locationLabel                           geoRegion  \
# 0    Kunsthistorisches Museum, Vienna  http://vocab.getty.edu/tgn/1000062
# 1    Kunsthistorisches Museum, Vienna  http://vocab.getty.edu/tgn/7003321
# 2    Kunsthistorisches Museum, Vienna  http://vocab.getty.edu/tgn/1000062
# 3    Kunsthistorisches Museum, Vienna  http://vocab.getty.edu/tgn/7003321
# 4       Musée Jacquemart-André, Paris  http://vocab.getty.edu/tgn/1000070
# ..                                ...                                 ...
# 102  Kunsthistorisches Museum, Vienna  http://vocab.getty.edu/tgn/1000062
# 103  Kunsthistorisches Museum, Vienna  http://vocab.getty.edu/tgn/7003321
# 104                     Prado, Madrid  http://vocab.getty.edu/tgn/1000095
# 105                     Prado, Madrid  http://vocab.getty.edu/tgn/7010413
# 106                            Mantua  http://vocab.getty.edu/tgn/1000080
#
#                startDate
# 0    1400-01-01T00:00:00
# 1    1400-01-01T00:00:00
# 2    1400-01-01T00:00:00
# 3    1400-01-01T00:00:00
# 4    1410-01-01T00:00:00
# ..                   ...
# 102  1563-01-01T00:00:00
# 103  1563-01-01T00:00:00
# 104  1565-01-01T00:00:00
# 105  1565-01-01T00:00:00
# 106  1567-01-01T00:00:00
#
# [107 rows x 5 columns]

# %% [markdown]
# Let's now count the place that got the highest number of renaissance artworks.

# %%
# Define the SPARQL query
query = """
    PREFIX d: <https://w3id.org/icon/data/> 
    PREFIX icon: <https://w3id.org/icon/ontology/> 
    PREFIX sim: <https://w3id.org/simulation/ontology/>
    PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
    PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
    
    SELECT DISTINCT ?geoRegion (COUNT(?geoRegion) AS ?regionCount)
    WHERE {
        # ?object crm:P65_shows_visual_item ?artwork ; 
                crm:P102_has_title ?title ; 
                ^crm:P108_has_produced / crm:P4_has_time_span ?time ;
                crm:P53_has_former_or_current_location ?location .

        # ?location rdfs:label ?locationLabel ;
                  crm:P89_falls_within ?geoRegion .

        # ?time crm:P82a_begin_of_the_begin ?startDate ; 
              crm:P82b_end_of_the_end ?endDate .

    FILTER (xsd:dateTime(?startDate) >= "1400-01-01T00:00:00"^^xsd:dateTime &&
                xsd:dateTime(?startDate) <= "1600-12-31T23:59:59"^^xsd:dateTime)
    }
    GROUP BY ?geoRegion
    ORDER BY DESC(?regionCount)
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)
    
    if results:
        # Retrieve the count of distinct artworks within the specified time span
        count_places = sum(1 for _ in results)
        
        if count_artworks > 0:
            print(f"Number of distinct places where artworks within the 1400-1600 period are kept: {count_places}")
        else:
            print("No distinct place where artworks are kept within the 1400-1600 period is specified")

        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results, columns=results.vars)

except Exception as e:
    print("An error occurred:", e)

df.info()
df
# Out:
# Number of distinct places where artworks within the 1400-1600 period are kept: 29
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   geoRegion    29 non-null     object
#  1   regionCount  29 non-null     object
# dtypes: object(2)
# memory usage: 596.0+ bytes
#                              geoRegion regionCount
# 0   http://vocab.getty.edu/tgn/1000080          14
# 1   http://vocab.getty.edu/tgn/7003669          12
# 2   http://vocab.getty.edu/tgn/7012149          10
# 3   http://vocab.getty.edu/tgn/7000457           8
# 4   http://vocab.getty.edu/tgn/7008591           6
# 5   http://vocab.getty.edu/tgn/7011781           6
# 6   http://vocab.getty.edu/tgn/7003712           6
# 7   http://vocab.getty.edu/tgn/7001168           5
# 8   http://vocab.getty.edu/tgn/1000062           5
# 9   http://vocab.getty.edu/tgn/7003321           5
# 10  http://vocab.getty.edu/tgn/1000070           4
# 11  http://vocab.getty.edu/tgn/7007567           3
# 12  http://vocab.getty.edu/tgn/7013962           3
# 13  http://vocab.getty.edu/tgn/7000874           3
# 14  http://vocab.getty.edu/tgn/7008038           2
# 15  http://vocab.getty.edu/tgn/7004333           2
# 16  http://vocab.getty.edu/tgn/7010573           1
# 17  http://vocab.getty.edu/tgn/7014210           1
# 18  http://vocab.getty.edu/tgn/7005685           1
# 19  http://vocab.getty.edu/tgn/7013088           1
# 20  http://vocab.getty.edu/tgn/7014647           1
# 21  http://vocab.getty.edu/tgn/7007048           1
# 22  http://vocab.getty.edu/tgn/7016845           1
# 23  http://vocab.getty.edu/tgn/7014406           1
# 24  http://vocab.getty.edu/tgn/7005289           1
# 25  http://vocab.getty.edu/tgn/2215680           1
# 26  http://vocab.getty.edu/tgn/1000095           1
# 27  http://vocab.getty.edu/tgn/7010413           1
# 28  http://vocab.getty.edu/tgn/7008192           1

# %% [markdown]
# Let's see if is it possible to retrieve, from the Getty endpoint the label of the geographical region.

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/> 
PREFIX icon: <https://w3id.org/icon/ontology/> 
PREFIX sim: <https://w3id.org/simulation/ontology/>
PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>

SELECT DISTINCT ?geoRegion (COUNT(?geoRegion) AS ?regionCount) ?label
WHERE {
    # ?object crm:P65_shows_visual_item ?artwork ; 
            crm:P102_has_title ?title ; 
            ^crm:P108_has_produced / crm:P4_has_time_span ?time ;
            crm:P53_has_former_or_current_location ?location .

    # ?location rdfs:label ?locationLabel ;
              crm:P89_falls_within ?geoRegion .

    # Fetching labels for Getty Vocabulary IDs
    SERVICE <http://vocab.getty.edu/sparql> {
        # ?geoRegion skos:prefLabel ?label .
        FILTER(LANG(?label) = 'en')
    }

    # ?time crm:P82a_begin_of_the_begin ?startDate .

    FILTER (xsd:dateTime(?startDate) >= "1400-01-01T00:00:00"^^xsd:dateTime &&
            xsd:dateTime(?startDate) <= "1600-12-31T23:59:59"^^xsd:dateTime)
}
GROUP BY ?geoRegion ?label
ORDER BY DESC(?regionCount)

"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)
    
    if results:
        # Retrieve the count of distinct artworks within the specified time span
        count_places = sum(1 for _ in results)
        
        if count_artworks > 0:
            print(f"Number of distinct places where artworks within the 1400-1600 period are kept: {count_places}")
        else:
            print("No distinct place where artworks are kept within the 1400-1600 period is specified")

        # Convert SPARQL results to a pandas DataFrame
        df = pd.DataFrame(results, columns=results.vars)

except Exception as e:
    print("An error occurred:", e)

df.info()
df
# Out:
# Number of distinct places where artworks within the 1400-1600 period are kept: 25
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   geoRegion    25 non-null     object
#  1   regionCount  25 non-null     object
#  2   label        25 non-null     object
# dtypes: object(3)
# memory usage: 732.0+ bytes
#                              geoRegion regionCount           label
# 0   http://vocab.getty.edu/tgn/1000080          14           Italy
# 1   http://vocab.getty.edu/tgn/7003669          12         Bavaria
# 2   http://vocab.getty.edu/tgn/7012149          10   United States
# 3   http://vocab.getty.edu/tgn/7000457           8        Florence
# 4   http://vocab.getty.edu/tgn/7008591           6  United Kingdom
# 5   http://vocab.getty.edu/tgn/7011781           6          London
# 6   http://vocab.getty.edu/tgn/7003712           6          Berlin
# 7   http://vocab.getty.edu/tgn/7001168           5        Holy See
# 8   http://vocab.getty.edu/tgn/1000062           5         Austria
# 9   http://vocab.getty.edu/tgn/7003321           5          Vienna
# 10  http://vocab.getty.edu/tgn/1000070           4          France
# 11  http://vocab.getty.edu/tgn/7013962           3      Washington
# 12  http://vocab.getty.edu/tgn/7007567           3        New York
# 13  http://vocab.getty.edu/tgn/7000874           3            Rome
# 14  http://vocab.getty.edu/tgn/7008038           2           Paris
# 15  http://vocab.getty.edu/tgn/7004333           2          Munich
# 16  http://vocab.getty.edu/tgn/7014210           1       New Haven
# 17  http://vocab.getty.edu/tgn/7005685           1          Canada
# 18  http://vocab.getty.edu/tgn/7013088           1          Ottawa
# 19  http://vocab.getty.edu/tgn/7007048           1         Haarlem
# 20  http://vocab.getty.edu/tgn/7016845           1     Netherlands
# 21  http://vocab.getty.edu/tgn/7014406           1    Philadelphia
# 22  http://vocab.getty.edu/tgn/1000095           1           Spain
# 23  http://vocab.getty.edu/tgn/2215680           1       Cambridge
# 24  http://vocab.getty.edu/tgn/7008192           1         Bayonne

# %% [markdown]
# Let's try to filter the different places in Italy. Is to be said that for architectonical artworks we don't have the musuem but the city.

# %%
# Define the SPARQL query
query = """
PREFIX d: <https://w3id.org/icon/data/>
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT DISTINCT ?artwork ?title ?museumLabel
WHERE {
    # ?object crm:P65_shows_visual_item ?artwork ;
        crm:P102_has_title ?title ;
        ^crm:P108_has_produced / crm:P4_has_time_span ?time ;
        crm:P53_has_former_or_current_location ?location .

    # ?location rdfs:label ?locationLabel ;
              crm:P89_falls_within ?geoRegion .

    # ?time crm:P82a_begin_of_the_begin ?startDate .

    FILTER (xsd:dateTime(?startDate) >= "1400-01-01T00:00:00"^^xsd:dateTime &&
            xsd:dateTime(?startDate) <= "1600-12-31T23:59:59"^^xsd:dateTime)

    # Filter for artworks in Italy
    FILTER EXISTS {
        # ?location crm:P89_falls_within <http://vocab.getty.edu/tgn/1000080> .
    }
 	
  	# ?museum a crm:E53_Place ;
            rdfs:label ?museumLabel .

    # Retrieve museums/places where artworks are located in Italy
    # ?object crm:P53_has_former_or_current_location ?museum .
    # ?museum crm:P89_falls_within <http://vocab.getty.edu/tgn/1000080> .

}
ORDER BY ?artwork
"""

try:
    # Prepare the SPARQL query
    query_obj = prepareQuery(query)
    
    # Execute the query and retrieve the results
    results = iconology_graph.query(query_obj)
    
    if results:
        # Retrieve the count of distinct artworks within the specified time span
        count_artworks = sum(1 for _ in results)
        
        if count_artworks > 0:
            print(f"Number of distinct places in Itlay where artworks within the 1400-1600 period are kept: {count_artworks}")
        else:
            print("No distinct place where artworks are kept, in Italy, within the 1400-1600 period is specified")

        # Convert SPARQL results to a pandas DataFrame and process the title URIs
        df = pd.DataFrame(results, columns=results.vars)

        df = df.set_axis(['artwork', 'title', 'museumLabel'], axis='columns')
        
        # Extract the last part after the final '/' character in the 'title' column
        df['title'] = df['title'].map(lambda x: x.split('/')[-1])

except Exception as e:
    print("An error occurred:", e)

df.info()
df
# Out:
# Number of distinct places in Itlay where artworks within the 1400-1600 period are kept: 14
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artwork      14 non-null     object
#  1   title        14 non-null     object
#  2   museumLabel  14 non-null     object
# dtypes: object(3)
# memory usage: 468.0+ bytes
#                                   artwork  \
# 0      https://w3id.org/icon/data/ART1068
# 1      https://w3id.org/icon/data/ART1072
# 2      https://w3id.org/icon/data/ART1188
# 3      https://w3id.org/icon/data/ART1194
# 4      https://w3id.org/icon/data/ART1198
# 5      https://w3id.org/icon/data/ART1202
# 6      https://w3id.org/icon/data/ART1203
# 7      https://w3id.org/icon/data/ART1204
# 8   https://w3id.org/icon/data/ART1243ext
# 9   https://w3id.org/icon/data/ART1246ext
# 10     https://w3id.org/icon/data/ART1329
# 11     https://w3id.org/icon/data/ART1339
# 12     https://w3id.org/icon/data/ART1537
# 13     https://w3id.org/icon/data/ART1543
#
#                                                 title  \
# 0                              the-descent-into-limbo
# 1                                            s-andrea
# 2   atys-amorinohere-interpreted-as-time-as-a-play...
# 3                         hercules-fighting-the-hydra
# 4                                 bust-of-a-young-man
# 5                                  the-birth-of-venus
# 6                   the-realm-of-venus-_la-primavera_
# 7                              the-calumny-of-apelles
# 8                                     villa-farnesina
# 9                                        pazzi-chapel
# 10                            sacred-and-profane-love
# 11                                 education-of-cupid
# 12                            christ-descent-to-limbo
# 13                               deposition-of-christ
#
#                         museumLabel
# 0   Museum of Santa Croce, Florence
# 1                            Mantua
# 2                Bargello, Florence
# 3                  Uffizi, Florence
# 4                Bargello, Florence
# 5                  Uffizi, Florence
# 6                  Uffizi, Florence
# 7                  Uffizi, Florence
# 8                              Rome
# 9                          Florence
# 10          Galleria Borghese, Rome
# 11          Galleria Borghese, Rome
# 12  Museum of Santa Croce, Florence
# 13          Galleria Borghese, Rome

# %%
# Define the SPARQL query
query = """
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX d: <https://w3id.org/icon/data/>

SELECT DISTINCT ?producedObject ?objectTitle ?period ?author ?motivator ?startDate 
WHERE {
  # ?production a crm:E12_Production ;
              crm:P108_has_produced ?producedObject ;
              crm:P4_has_time_span ?timeSpan .
  # ?timeSpan crm:P82a_begin_of_the_begin ?startDate .
  BIND (xsd:integer(SUBSTR(?startDate, 1, 4)) AS ?startYear) .
  # ?producedObject crm:P102_has_title ?objectTitle .
  
  OPTIONAL { ?production crm:P10_falls_within ?period }
  OPTIONAL { ?production crm:P14_carried_out_by ?author }
  OPTIONAL { ?production crm:P17_was_motivated_by ?motivator }

  # Filter for start year after 1400
  FILTER (?startYear >= 1400 && ?startYear <= 1600)
}
ORDER BY ?startDate
"""

try:
    # Execute the query and retrieve the results
    print("Before executing SPARQL query")
    results = iconology_graph.query(query)
    print("After executing SPARQL query")
    
    print(results)
    
    # Check if results exist
    if results:
        df1 = pd.DataFrame(results)
        df1 = df1.set_axis(['produced_object', 'object_title', 'period', 'author', 'motivator', 'start_date'], axis='columns')
        print(df1.head(10))  # Show the first 10 rows of the DataFrame
    else:
        print("No results returned from the SPARQL query")
        
except Exception as e:
    print(f"An error occurred: {str(e)}")

df1.info()
df1  # Uncomment for a better reading of the table
# Out:
# Before executing SPARQL query
# After executing SPARQL query
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x49956db10>
#                           produced_object  \
# 0      https://w3id.org/icon/data/OBJ1117
# 1      https://w3id.org/icon/data/OBJ1118
# 2      https://w3id.org/icon/data/OBJ1173
# 3   https://w3id.org/icon/data/OBJ1191ext
# 4   https://w3id.org/icon/data/OBJ1202ext
# 5      https://w3id.org/icon/data/OBJ1331
# 6  https://w3id.org/icon/data/OBJ1004test
# 7      https://w3id.org/icon/data/OBJ1007
# 8  https://w3id.org/icon/data/OBJ1008test
# 9      https://w3id.org/icon/data/OBJ1015
#
#                                         object_title  \
# 0  https://w3id.org/icon/data/title/apollo-minerv...
# 1  https://w3id.org/icon/data/title/orpheus-charm...
# 2  https://w3id.org/icon/data/title/siege-of-a-ci...
# 3  https://w3id.org/icon/data/title/french-miniature
# 4  https://w3id.org/icon/data/title/the-medal-of-...
# 5  https://w3id.org/icon/data/title/nature-and-grace
# 6  https://w3id.org/icon/data/title/the-rape-of-p...
# 7     https://w3id.org/icon/data/title/celestial-map
# 8  https://w3id.org/icon/data/title/the-annunciation
# 9  https://w3id.org/icon/data/title/the-constella...
#
#                                  period author motivator           start_date
# 0                                  None   None      None  1400-01-01T00:00:00
# 1                                  None   None      None  1400-01-01T00:00:00
# 2                                  None   None      None  1400-01-01T00:00:00
# 3                                  None   None      None  1400-01-01T00:00:00
# 4                                  None   None      None  1400-01-01T00:00:00
# 5                                  None   None      None  1400-01-01T00:00:00
# 6                                  None   None      None  1401-01-01T00:00:00
# 7  http://vocab.getty.edu/aat/300021140   None      None  1401-01-01T00:00:00
# 8                                  None   None      None  1401-01-01T00:00:00
# 9  http://vocab.getty.edu/aat/300020756   None      None  1401-01-01T00:00:00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   produced_object  168 non-null    object
#  1   object_title     168 non-null    object
#  2   period           9 non-null      object
#  3   author           93 non-null     object
#  4   motivator        9 non-null      object
#  5   start_date       168 non-null    object
# dtypes: object(6)
# memory usage: 8.0+ KB
#                            produced_object  \
# 0       https://w3id.org/icon/data/OBJ1117
# 1       https://w3id.org/icon/data/OBJ1118
# 2       https://w3id.org/icon/data/OBJ1173
# 3    https://w3id.org/icon/data/OBJ1191ext
# 4    https://w3id.org/icon/data/OBJ1202ext
# ..                                     ...
# 163     https://w3id.org/icon/data/OBJ1258
# 164     https://w3id.org/icon/data/OBJ1426
# 165     https://w3id.org/icon/data/OBJ1322
# 166     https://w3id.org/icon/data/OBJ1389
# 167     https://w3id.org/icon/data/OBJ1308
#
#                                           object_title period  \
# 0    https://w3id.org/icon/data/title/apollo-minerv...   None
# 1    https://w3id.org/icon/data/title/orpheus-charm...   None
# 2    https://w3id.org/icon/data/title/siege-of-a-ci...   None
# 3    https://w3id.org/icon/data/title/french-miniature   None
# 4    https://w3id.org/icon/data/title/the-medal-of-...   None
# ..                                                 ...    ...
# 163  https://w3id.org/icon/data/title/allegory-of-a...   None
# 164  https://w3id.org/icon/data/title/mater-miseric...   None
# 165  https://w3id.org/icon/data/title/platonic-love...   None
# 166          https://w3id.org/icon/data/title/ganymede   None
# 167  https://w3id.org/icon/data/title/eros-and-anteros   None
#
#                                                 author motivator  \
# 0                                                 None      None
# 1                                                 None      None
# 2                                                 None      None
# 3                                                 None      None
# 4                                                 None      None
# ..                                                 ...       ...
# 163  https://w3id.org/icon/data/person/girolamo-olg...      None
# 164  https://w3id.org/icon/data/person/tiziano-vece...      None
# 165                                               None      None
# 166                                               None      None
# 167                                               None      None
#
#               start_date
# 0    1400-01-01T00:00:00
# 1    1400-01-01T00:00:00
# 2    1400-01-01T00:00:00
# 3    1400-01-01T00:00:00
# 4    1400-01-01T00:00:00
# ..                   ...
# 163  1569-01-01T00:00:00
# 164  1573-01-01T00:00:00
# 165  1574-01-01T00:00:00
# 166  1574-01-01T00:00:00
# 167  1584-01-01T00:00:00
#
# [168 rows x 6 columns]

# %%
# Define the SPARQL query
query = """
PREFIX crm: <http://www.cidoc-crm.org/cidoc-crm/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX d: <https://w3id.org/icon/data/>

SELECT ?period ?periodLabel
WHERE {
  # ?period a crm:E4_Period .
  OPTIONAL { ?period rdfs:label ?periodLabel }
}
"""

try:
    # Execute the query and retrieve the results
    print("Before executing SPARQL query")
    results = iconology_graph.query(query)
    print("After executing SPARQL query")
    
    print(results)
    
    # Check if results exist
    if results:
        df2 = pd.DataFrame(results)
        df2 = df2.set_axis(['period', 'period_label'], axis='columns')
        print(df2.head(10))  # Show the first 10 rows of the DataFrame
    else:
        print("No results returned from the SPARQL query")
        
except Exception as e:
    print(f"An error occurred: {str(e)}")

df2  # Uncomment for a better reading of the table
# Out:
# Before executing SPARQL query
# After executing SPARQL query
# <rdflib.plugins.sparql.processor.SPARQLResult object at 0x49cad8ad0>
#                                               period  \
# 0               http://vocab.getty.edu/aat/300022045
# 1  https://w3id.org/icon/data/period/florentine-m...
# 2  https://w3id.org/icon/data/period/venetian-hig...
# 3               http://vocab.getty.edu/aat/300021144
# 4  https://w3id.org/icon/data/period/florentine-r...
# 5  https://w3id.org/icon/data/period/manfredian-o...
# 6               http://vocab.getty.edu/aat/300020072
# 7               http://vocab.getty.edu/aat/300020072
# 8               http://vocab.getty.edu/aat/300020666
# 9               http://vocab.getty.edu/aat/300020666
#
#                                 period_label
# 0                        Counter-Reformation
# 1                       Florentine Mannerism
# 2                  Venetian High Renaissance
# 3                                  Mannerism
# 4                     Florentine Renaissance
# 5            Manfredian or Federician period
# 6                             Ancient Greece
# 7                              Ancient Greek
# 8  Late Antique Roman Style (IV - V Century)
# 9                       Late Roman Antiquity
#                                                period  \
# 0                http://vocab.getty.edu/aat/300022045
# 1   https://w3id.org/icon/data/period/florentine-m...
# 2   https://w3id.org/icon/data/period/venetian-hig...
# 3                http://vocab.getty.edu/aat/300021144
# 4   https://w3id.org/icon/data/period/florentine-r...
# 5   https://w3id.org/icon/data/period/manfredian-o...
# 6                http://vocab.getty.edu/aat/300020072
# 7                http://vocab.getty.edu/aat/300020072
# 8                http://vocab.getty.edu/aat/300020666
# 9                http://vocab.getty.edu/aat/300020666
# 10               http://vocab.getty.edu/aat/300020533
# 11               http://vocab.getty.edu/aat/300020764
# 12               http://vocab.getty.edu/aat/300020764
# 13               http://vocab.getty.edu/aat/300021140
# 14               http://vocab.getty.edu/aat/300020756
# 15               http://vocab.getty.edu/aat/300020756
#
#                                  period_label
# 0                         Counter-Reformation
# 1                        Florentine Mannerism
# 2                   Venetian High Renaissance
# 3                                   Mannerism
# 4                      Florentine Renaissance
# 5             Manfredian or Federician period
# 6                              Ancient Greece
# 7                               Ancient Greek
# 8   Late Antique Roman Style (IV - V Century)
# 9                        Late Roman Antiquity
# 10                                      Roman
# 11                                Carolingian
# 12                       Renovatio Carolingia
# 13                                Renaissance
# 14                                   Medieval
# 15                                Middle Ages

# %%
# Merge both DataFrames on the 'period' column
merged_df = pd.merge(df1, df2, on='period', how='left')

merged_df
# Out:
#                            produced_object  \
# 0       https://w3id.org/icon/data/OBJ1117
# 1       https://w3id.org/icon/data/OBJ1118
# 2       https://w3id.org/icon/data/OBJ1173
# 3    https://w3id.org/icon/data/OBJ1191ext
# 4    https://w3id.org/icon/data/OBJ1202ext
# ..                                     ...
# 164     https://w3id.org/icon/data/OBJ1258
# 165     https://w3id.org/icon/data/OBJ1426
# 166     https://w3id.org/icon/data/OBJ1322
# 167     https://w3id.org/icon/data/OBJ1389
# 168     https://w3id.org/icon/data/OBJ1308
#
#                                           object_title period  \
# 0    https://w3id.org/icon/data/title/apollo-minerv...   None
# 1    https://w3id.org/icon/data/title/orpheus-charm...   None
# 2    https://w3id.org/icon/data/title/siege-of-a-ci...   None
# 3    https://w3id.org/icon/data/title/french-miniature   None
# 4    https://w3id.org/icon/data/title/the-medal-of-...   None
# ..                                                 ...    ...
# 164  https://w3id.org/icon/data/title/allegory-of-a...   None
# 165  https://w3id.org/icon/data/title/mater-miseric...   None
# 166  https://w3id.org/icon/data/title/platonic-love...   None
# 167          https://w3id.org/icon/data/title/ganymede   None
# 168  https://w3id.org/icon/data/title/eros-and-anteros   None
#
#                                                 author motivator  \
# 0                                                 None      None
# 1                                                 None      None
# 2                                                 None      None
# 3                                                 None      None
# 4                                                 None      None
# ..                                                 ...       ...
# 164  https://w3id.org/icon/data/person/girolamo-olg...      None
# 165  https://w3id.org/icon/data/person/tiziano-vece...      None
# 166                                               None      None
# 167                                               None      None
# 168                                               None      None
#
#               start_date period_label
# 0    1400-01-01T00:00:00          NaN
# 1    1400-01-01T00:00:00          NaN
# 2    1400-01-01T00:00:00          NaN
# 3    1400-01-01T00:00:00          NaN
# 4    1400-01-01T00:00:00          NaN
# ..                   ...          ...
# 164  1569-01-01T00:00:00          NaN
# 165  1573-01-01T00:00:00          NaN
# 166  1574-01-01T00:00:00          NaN
# 167  1574-01-01T00:00:00          NaN
# 168  1584-01-01T00:00:00          NaN
#
# [169 rows x 7 columns]

# %% [markdown]
# # References
#
# ## ICON
# https://dl.acm.org/doi/10.1145/3594724
# https://ceur-ws.org/Vol-3540/paper4.pdf
#
# ## Zeri dataset
# https://essepuntato.it/papers/zeri-and-lode-jocch.html
